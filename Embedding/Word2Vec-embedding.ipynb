# %%
import numpy as np
import pandas as pd
from gensim.models import Word2Vec

# %%
DATA_IN_PATH = '../data/preprocess/'

KorQuAd = pd.read_csv(DATA_IN_PATH + 'KorQuAd_preprocess_Okt.csv', encoding = 'UTF8')
naverReview = pd.read_csv(DATA_IN_PATH + 'naverReview_preprocess_Okt.csv', encoding = 'UTF8')
ultraDiary = pd.read_csv(DATA_IN_PATH + 'ultraDiary_preprocess_Okt.csv', encoding = 'UTF8')

# %%
data = KorQuAd.append(naverReview)
data = data.append(ultraDiary)
#데이터 저장

# %%
contexts = list(data['context'])

sentences = []
for context in contexts :
    sentences.append(str(context).split())
#데이터 변환

# %%
sentences
# Out:
# [['년',
#   '바그너',
#   '괴테',
#   '파우스트',
#   '을',
#   '처음',
#   '읽다',
#   '그',
#   '내용',
#   '에',
#   '마음',
#   '끌리다',
#   '이르다',
#   '소재',
#   '로',
#   '하다',
#   '하나',
#   '교향곡',
#   '을',
#   '쓰다',
#   '뜻',
#   '을',
#   '갖다',
#   '시기',
#   '바그너',
#   '년',
#   '에',
#   '빛',
#   '독촉',
#   '으로',
#   '산전수전',
#   '을',
#   '다',
#   '걲',
#   '상황',
#   '이라',
#   '좌절',
#   '과',
#   '실망',
#   '에',
#   '가득하다',
#   '메피스토펠레스',
#   '를',
#   '만나다',
#   '파우스트',
#   '심경',
#   '에',
#   '공감',
#   '하다',
#   '하다',
#   '또한',
#   '파리',
#   '에서',
#   '아브네크',
#   '지휘',
#   '로',
#   '파리',
#   '음악원',
#   '관현악단',
#   '연주',
#   '하다',
#   '베토벤',
#   '교향곡',
#   '번',
#   '을',
#   '듣다',
#   '깊다',
#   '감명',
#   '을',
#   '받다',
#   '이듬해',
#   '월',
#   '에',
#   '파우스트',
#   '서곡',
#   '으로',
#   '쓰이다',
#   '작품',
#   '에',
#   '조금',
#   '이라도',
#   '영향',
#   '을',
#   '끼치다',
#   '의심',
#   '하다',
#   '여지',
#   '없다',
#   '여기',
#   '라단조',
#   '조성',
#   '경우',
#   '에도',
#   '그',
#   '전기',
#   '에',
#   '적히다',
#   '있다',
#   '처럼',
#   '단순하다',
#   '정신',
#   '적',
#   '피로',
#   '나',
#   '실의',
#   '반영',
#   '되다',
#   '아니다',
#   '베토벤',
#   '합창교향곡',
#   '조성',
#   '영향',
#   '을',
#   '받다',
#   '을',
#   '볼',
#   '있다',
#   '그렇게',
#   '교향곡',
#   '작곡',
#   '을',
#   '년',
#   '부터',
#   '년',
#   '에',
#   '걸치다',
#   '파리',
#   '에서',
#   '착수',
#   '하다',
#   '악장',
#   '을',
#   '쓸다',
#   '뒤',
#   '에',
#   '중단',
#   '하다',
#   '또한',
#   '작품',
#   '완성',
#   '과',
#   '동시',
#   '에',
#   '그',
#   '서곡',
#   '악장',
#   '을',
#   '파리',
#   '음악원',
#   '연주회',
#   '에서',
#   '연주',
#   '하다',
#   '파트',
#   '까지',
#   '준비',
#   '하다',
#   '실제',
#   '로는',
#   '이루어지다',
#   '않다',
#   '결국',
#   '초연',
#   '년',
#   '반',
#   '지난',
#   '후',
#   '에',
#   '드레스덴',
#   '에서',
#   '연주',
#   '되어다',
#   '재연',
#   '도',
#   '이루어지다',
#   '이후',
#   '에',
#   '그대로',
#   '방치',
#   '되다',
#   '말다',
#   '그',
#   '사이',
#   '에',
#   '그',
#   '리엔치',
#   '와',
#   '방황',
#   '하다',
#   '네덜란드인',
#   '을',
#   '완성',
#   '하고',
#   '탄호이저',
#   '에도',
#   '착수',
#   '하다',
#   '분주하다',
#   '시간',
#   '을',
#   '보내다',
#   '그렇다',
#   '바쁘다',
#   '생활',
#   '곡',
#   '을',
#   '잊다',
#   '하다',
#   '아니다',
#   '하다',
#   '의견',
#   '도',
#   '있다'],
#  ['한편',
#   '년',
#   '부터',
#   '바그너',
#   '와',
#   '알',
#   '고',
#   '지내다',
#   '리스트',
#   '잊혀지다',
#   '있다',
#   '악장',
#   '을',
#   '부활',
#   '시키다',
#   '년',
#   '에',
#   '바이마르',
#   '에서',
#   '연주',
#   '하다',
#   '을',
#   '계기',
#   '로',
#   '바그너',
#   '도',
#   '작품',
#   '에',
#   '다시',
#   '관심',
#   '을',
#   '갖다',
#   '되어다',
#   '그',
#   '해',
#   '월',
#   '에는',
#   '총보',
#   '반환',
#   '을',
#   '요구',
#   '하다',
#   '이르다',
#   '서곡',
#   '으로',
#   '간추린',
#   '다음',
#   '수정',
#   '을',
#   '하다',
#   '브',
#   '라이트',
#   '코',
#   '프흐',
#   '헤르',
#   '텔',
#   '출판사',
#   '에서',
#   '출판',
#   '하다',
#   '개정판',
#   '도',
#   '준비',
#   '하다',
#   '년',
#   '월',
#   '에는',
#   '리스트',
#   '작품',
#   '수정',
#   '되어다',
#   '을',
#   '인정',
#   '하다',
#   '끝내',
#   '바그너',
#   '출판',
#   '계획',
#   '무산',
#   '되다',
#   '말다',
#   '이후',
#   '년',
#   '에',
#   '리스트',
#   '자신',
#   '작품',
#   '파우스트',
#   '교향곡',
#   '을',
#   '거의',
#   '완성',
#   '하다',
#   '그',
#   '사실',
#   '을',
#   '바그너',
#   '에게',
#   '알리다',
#   '바그너',
#   '다시',
#   '개정',
#   '되다',
#   '총보',
#   '를',
#   '리스트',
#   '에게',
#   '보내다',
#   '브',
#   '라이트',
#   '코',
#   '프흐',
#   '헤르',
#   '텔',
#   '출판사',
#   '에는',
#   '루이',
#   '금',
#   '을',
#   '받다',
#   '파다',
#   '또한',
#   '그',
#   '작품',
#   '을',
#   '하나',
#   '하나',
#   '음표',
#   '시인',
#   '피로',
#   '쓰이다',
#   '극찬',
#   '하다',
#   '한스',
#   '폰',
#   '뷜로',
#   '그것',
#   '을',
#   '피아노',
#   '독주',
#   '용',
#   '으로',
#   '편곡',
#   '하다',
#   '리스트',
#   '그것',
#   '을',
#   '약간',
#   '변형',
#   '되어다',
#   '뿐',
#   '이라고',
#   '지적',
#   '하다',
#   '서곡',
#   '총보',
#   '첫머리',
#   '에는',
#   '파우스트',
#   '부의',
#   '내용',
#   '중',
#   '하다',
#   '구절',
#   '을',
#   '인용',
#   '하고',
#   '있다'],
#  ['작품',
#   '라단조',
#   '아주',
#   '신중하다',
#   '박자',
#   '부드럽다',
#   '서주',
#   '로',
#   '서주',
#   '로',
#   '시작',
#   '되다',
#   '여기',
#   '에는',
#   '주요',
#   '주제',
#   '동기',
#   '대부분',
#   '암시',
#   '예고',
#   '되어다',
#   '있다',
#   '첫',
#   '부분',
#   '저음',
#   '주제',
#   '주요',
#   '제',
#   '고뇌',
#   '와',
#   '갈망',
#   '동기',
#   '청춘',
#   '사랑',
#   '동기',
#   '를',
#   '암시',
#   '하고',
#   '있다',
#   '제',
#   '바이올린',
#   '으로',
#   '더욱',
#   '명확하다',
#   '나타나다',
#   '또한',
#   '그것',
#   '을',
#   '이다',
#   '받다',
#   '동기',
#   '도',
#   '중요하다',
#   '역할',
#   '을',
#   '하다',
#   '여기',
#   '에',
#   '새롭다',
#   '소재',
#   '더하다',
#   '뒤',
#   '에',
#   '새롭다',
#   '주제',
#   '도',
#   '연주',
#   '되다',
#   '주요',
#   '부',
#   '아주',
#   '격동',
#   '적',
#   '으로',
#   '박자',
#   '자유롭다',
#   '소나타',
#   '형식',
#   '으로',
#   '매우',
#   '드라마틱하다',
#   '구상',
#   '과',
#   '유기',
#   '적',
#   '인',
#   '구성',
#   '을',
#   '하다',
#   '있다',
#   '여기',
#   '에는',
#   '지금',
#   '까지의',
#   '주제',
#   '나',
#   '소재',
#   '외',
#   '에도',
#   '오보에',
#   '에',
#   '의하다',
#   '선율',
#   '과',
#   '제',
#   '주제',
#   '를',
#   '떠올리다',
#   '하다',
#   '부차',
#   '적',
#   '인',
#   '주제가',
#   '더하다',
#   '중간',
#   '부',
#   '에서는',
#   '약',
#   '보이',
#   '중심',
#   '되다',
#   '제',
#   '주제',
#   '축소',
#   '되다',
#   '재현',
#   '부',
#   '에서',
#   '장조',
#   '로',
#   '재현',
#   '되다',
#   '마지막',
#   '에는',
#   '주요',
#   '주제',
#   '를',
#   '회상',
#   '하다',
#   '조용하다',
#   '마치다'],
#  ['커닐링구스커닐',
#   '링거',
#   '스',
#   '쿤닐링구스',
#   '영어',
#   '늘다',
#   '입술',
#   '혀',
#   '입',
#   '모든',
#   '구강',
#   '기관',
#   '으로',
#   '여성',
#   '성기',
#   '를',
#   '애무',
#   '하다',
#   '을',
#   '말',
#   '하다',
#   '구강성교',
#   '오럴섹스',
#   '영어',
#   '라고도',
#   '하다',
#   '보통',
#   '남성',
#   '행',
#   '하다',
#   '동성',
#   '여성',
#   '행',
#   '하다',
#   '경우',
#   '도',
#   '있다',
#   '혀',
#   '를',
#   '질',
#   '에',
#   '넣다',
#   '여성',
#   '클리토리스',
#   '외음부',
#   '나',
#   '그',
#   '주변',
#   '을',
#   '핥다',
#   '빨다',
#   '애무',
#   '하다',
#   '받다',
#   '사람',
#   '다양하다',
#   '성감',
#   '을',
#   '느끼다',
#   '원인',
#   '되다',
#   '특히',
#   '클리토리스',
#   '감각',
#   '매우',
#   '중요하다',
#   '타액',
#   '과',
#   '성',
#   '윤활제',
#   '자주',
#   '사용',
#   '되다',
#   '부드럽다',
#   '매끄럽다',
#   '자극',
#   '을',
#   '가능하다',
#   '하다',
#   '파트너',
#   '반응',
#   '에',
#   '귀',
#   '를',
#   '기울이다',
#   '손가락',
#   '과',
#   '같다',
#   '다른',
#   '애무',
#   '와',
#   '함께',
#   '몸',
#   '전체',
#   '에',
#   '다양하다',
#   '자극',
#   '과',
#   '결',
#   '하다',
#   '양',
#   '측',
#   '폭넓다',
#   '즐거움',
#   '을',
#   '나누다',
#   '있다',
#   '하다',
#   '전희',
#   '로서',
#   '하다',
#   '경우',
#   '많다',
#   '오르가즘',
#   '에의',
#   '도달',
#   '여부',
#   '에',
#   '관계없이',
#   '커닐링구스',
#   '자체',
#   '성행위',
#   '이다'],
#  ['일반',
#   '적',
#   '인',
#   '통계',
#   '에',
#   '따르다',
#   '여성',
#   '가다',
#   '오르가슴',
#   '을',
#   '얻다',
#   '위해',
#   '직접',
#   '적',
#   '인',
#   '음핵',
#   '자극',
#   '을',
#   '필요',
#   '로',
#   '하다',
#   '성교육',
#   '학자',
#   '쉐어',
#   '하이트',
#   '여성',
#   '성',
#   '보고서',
#   '에',
#   '따르다',
#   '대부분',
#   '여성',
#   '경우',
#   '오르가슴',
#   '클리토리스',
#   '에',
#   '직접',
#   '적',
#   '인',
#   '자극',
#   '을',
#   '주다',
#   '커닐링구스',
#   '를',
#   '통해',
#   '쉬다',
#   '도달',
#   '하다',
#   '있다',
#   '보고',
#   '하고',
#   '있다',
#   '커닐링구스',
#   '를',
#   '받다',
#   '여성',
#   '파트너',
#   '혀',
#   '클리토리스',
#   '를',
#   '더',
#   '자다',
#   '자극',
#   '하다',
#   '있다',
#   '손가락',
#   '을',
#   '사용',
#   '직접',
#   '음순',
#   '을',
#   '분리',
#   '하다',
#   '있다',
#   '또',
#   '다리',
#   '를',
#   '넓다',
#   '벌리다',
#   '파트너',
#   '클리토리스',
#   '에',
#   '구두',
#   '로',
#   '쉬다',
#   '도달',
#   '하다',
#   '있다',
#   '외음부',
#   '를',
#   '드러내다',
#   '있다',
#   '파트너',
#   '음순',
#   '과',
#   '전체',
#   '생식기',
#   '영역',
#   '에',
#   '대해',
#   '보다',
#   '부드럽다',
#   '집중',
#   '적',
#   '이지',
#   '않다',
#   '자극',
#   '으로',
#   '시작',
#   '하다',
#   '좋다',
#   '여성',
#   '커닐링구스',
#   '를',
#   '하다',
#   '전',
#   '에',
#   '개인',
#   '위생',
#   '을',
#   '중요하다',
#   '생각',
#   '하다',
#   '일부',
#   '여성',
#   '음모',
#   '를',
#   '제거',
#   '거나',
#   '다듬다',
#   '커닐링구스',
#   '경험',
#   '을',
#   '향상',
#   '시키다',
#   '있다'],
#  ['성경',
#   '아가서',
#   '제임스',
#   '왕',
#   '역',
#   '에서',
#   '늘다',
#   '커닐링구스',
#   '에',
#   '대한',
#   '우회',
#   '적',
#   '언급',
#   '포함',
#   '되어다',
#   '있다',
#   '생각',
#   '하다',
#   '있다',
#   '많다',
#   '번역자',
#   '핵심',
#   '단어',
#   '를',
#   '배꼽',
#   '로',
#   '번역',
#   '하고',
#   '있다',
#   '일부',
#   '여성',
#   '웅덩이',
#   '에',
#   '포도주',
#   '가득',
#   '채우다',
#   '있다',
#   '묘사',
#   '육욕',
#   '적',
#   '인',
#   '그릇',
#   '에서',
#   '말다',
#   '싶다',
#   '남자',
#   '욕망',
#   '을',
#   '암시',
#   '하고',
#   '있다',
#   '따라서',
#   '교정',
#   '미묘하다',
#   '깊다',
#   '맛',
#   '귀띔',
#   '인지도',
#   '모르다',
#   '해석',
#   '을',
#   '보여주다',
#   '있다',
#   '다른',
#   '번역',
#   '에서는',
#   '다음',
#   '과',
#   '같이도',
#   '읽다',
#   '있다',
#   '너',
#   '음부',
#   '동그랗다',
#   '컵',
#   '칵테일',
#   '끊어지다',
#   '적',
#   '없다',
#   '샌들',
#   '에서',
#   '출발',
#   '히브리어',
#   '아람어',
#   '비밀',
#   '장소',
#   '라는',
#   '단어',
#   '에서',
#   '파생',
#   '되다',
#   '배',
#   '가슴',
#   '으로',
#   '오르다',
#   '간다',
#   '고',
#   '하다',
#   '문맥',
#   '단어',
#   '의미',
#   '를',
#   '거의',
#   '결정',
#   '짓다',
#   '이다',
#   '기독교',
#   '와',
#   '유대교',
#   '여러',
#   '전통',
#   '에서',
#   '아가',
#   '에',
#   '그려지다',
#   '신랑',
#   '과',
#   '신부',
#   '에',
#   '로',
#   '틱',
#   '친밀',
#   '감',
#   '에',
#   '영적',
#   '인',
#   '의미',
#   '를',
#   '부여',
#   '하고',
#   '있다'],
#  ['서일본',
#   '여객',
#   '철도',
#   '어번',
#   '네트워크',
#   '하다',
#   '축',
#   '을',
#   '구성',
#   '하고',
#   '있다',
#   '오사카',
#   '시가지',
#   '남부',
#   '철도',
#   '교통',
#   '터미널',
#   '인',
#   '덴노',
#   '지다',
#   '남쪽',
#   '으로',
#   '철도',
#   '를',
#   '늘리다',
#   '오사카',
#   '남부',
#   '각',
#   '도시',
#   '를',
#   '경유',
#   '하다',
#   '와카야마',
#   '에',
#   '이르다',
#   '노선',
#   '이다',
#   '하다',
#   '선',
#   '으로부터',
#   '서측',
#   '에',
#   '자리',
#   '난',
#   '카이',
#   '전기',
#   '철도',
#   '본선',
#   '공항선',
#   '과',
#   '경합',
#   '하고',
#   '있다',
#   '이외',
#   '에',
#   '신',
#   '마미야',
#   '역',
#   '모',
#   '즈',
#   '역',
#   '간',
#   '에서는',
#   '난',
#   '카이',
#   '전기',
#   '철도',
#   '고야',
#   '선',
#   '과',
#   '오사카',
#   '시내',
#   '에서는',
#   '오사카',
#   '시',
#   '교통',
#   '국',
#   '미도스지',
#   '다',
#   '니',
#   '마치',
#   '선',
#   '이나',
#   '한카이',
#   '전기',
#   '궤도',
#   '와도',
#   '경합',
#   '이루어지다',
#   '있다',
#   '야마',
#   '나',
#   '카다',
#   '니',
#   '역',
#   '기이',
#   '역',
#   '간의',
#   '오사카부',
#   '와',
#   '와카야마현',
#   '간의',
#   '경계',
#   '에는',
#   '오노',
#   '야마',
#   '고개',
#   '있다',
#   '심하다',
#   '구배',
#   '구간',
#   '존재',
#   '하다',
#   '와카야마',
#   '역',
#   '에서는',
#   '기세',
#   '본선',
#   '과',
#   '접속',
#   '하다',
#   '되어다',
#   '기세',
#   '본선',
#   '을',
#   '통해',
#   '난키',
#   '방면',
#   '으로',
#   '향',
#   '하다',
#   '특급',
#   '열차',
#   '도',
#   '운행',
#   '되다',
#   '있다',
#   '간사이',
#   '국제공항',
#   '개통',
#   '년',
#   '이후',
#   '에는',
#   '간사이',
#   '공항선',
#   '과',
#   '연락',
#   '되어다',
#   '공항',
#   '연락',
#   '노선',
#   '으로서의',
#   '중요하다',
#   '역할',
#   '을',
#   '가지',
#   '게',
#   '되어다'],
#  ['대낮',
#   '시간대',
#   '에는',
#   '덴노',
#   '지',
#   '역',
#   '히',
#   '네',
#   '노',
#   '역',
#   '간',
#   '에서',
#   '쾌속',
#   '과',
#   '보통',
#   '각각',
#   '시간',
#   '당',
#   '편',
#   '씩',
#   '운전',
#   '되다',
#   '있다',
#   '히',
#   '네',
#   '노',
#   '역',
#   '이남',
#   '구간',
#   '와카야마',
#   '역',
#   '운전',
#   '펴다',
#   '오사카',
#   '방면',
#   '에서',
#   '온',
#   '대부분',
#   '열차',
#   '히',
#   '네',
#   '노',
#   '역',
#   '에서',
#   '종착',
#   '하다',
#   '때문',
#   '에',
#   '히',
#   '네',
#   '노',
#   '역',
#   '이북',
#   '구간',
#   '열차',
#   '펴다',
#   '비다',
#   '비교',
#   '적',
#   '적다',
#   '편이',
#   '다',
#   '또',
#   '히',
#   '네',
#   '노',
#   '역',
#   '이남',
#   '지역',
#   '특급',
#   '우선',
#   '도',
#   '높다',
#   '때문',
#   '에',
#   '히',
#   '네',
#   '노',
#   '역',
#   '즈',
#   '미스',
#   '나가다',
#   '역',
#   '에서',
#   '특급',
#   '열차',
#   '와',
#   '보통',
#   '열차',
#   '접속',
#   '이루어지다',
#   '한편',
#   '으로',
#   '쾌속',
#   '열차',
#   '와의',
#   '접속',
#   '환경',
#   '열악하다',
#   '경우',
#   '도',
#   '많다',
#   '때문',
#   '에',
#   '쾌속',
#   '통과',
#   '역',
#   '과의',
#   '격차',
#   '커지다',
#   '있다',
#   '서다',
#   '운전',
#   '되다',
#   '열차',
#   '이외',
#   '에',
#   '오사카',
#   '순환선',
#   '간사이',
#   '공항선',
#   '기세',
#   '본선',
#   '으로',
#   '직결',
#   '운행',
#   '하다',
#   '열차',
#   '도',
#   '설정',
#   '되어다',
#   '있다',
#   '년',
#   '월',
#   '일',
#   '시간표',
#   '개정',
#   '까지는',
#   '간사이',
#   '본선',
#   '난바',
#   '역',
#   '발착',
#   '열차',
#   '도',
#   '존재',
#   '하다'],
#  ['덴노',
#   '지',
#   '역',
#   '구내',
#   '에서는',
#   '야마토',
#   '지',
#   '선',
#   '과',
#   '평면',
#   '교차',
#   '하다',
#   '단선',
#   '으로',
#   '운전',
#   '하다',
#   '하다',
#   '선',
#   '과의',
#   '단락',
#   '선',
#   '을',
#   '복선',
#   '화하다',
#   '공사',
#   '이루어지다',
#   '년',
#   '월',
#   '일',
#   '시간표',
#   '개정',
#   '시',
#   '부터',
#   '사용',
#   '을',
#   '개시',
#   '하다',
#   '대낮',
#   '시간대',
#   '덴노',
#   '지',
#   '역',
#   '와카야마',
#   '역',
#   '간의',
#   '쾌속',
#   '과',
#   '난바',
#   '역',
#   '발착',
#   '간쿠',
#   '쾌속',
#   '오사카',
#   '순환선',
#   '과',
#   '직통',
#   '운전',
#   '하다',
#   '간쿠기슈',
#   '지',
#   '쾌속',
#   '에',
#   '통합',
#   '되어다',
#   '같다',
#   '시간대',
#   '간쿠기슈',
#   '지',
#   '쾌속',
#   '매다',
#   '편',
#   '으로',
#   '증발',
#   '되어다',
#   '복선',
#   '화',
#   '야마토',
#   '지',
#   '선의',
#   '시간표',
#   '혼란',
#   '크다',
#   '영향',
#   '을',
#   '끼치다',
#   '을',
#   '막다',
#   '효과',
#   '를',
#   '가지',
#   '고',
#   '있다',
#   '또',
#   '아침',
#   '출근',
#   '시간대',
#   '에',
#   '오사카',
#   '순환선',
#   '내',
#   '각',
#   '역',
#   '에',
#   '정차',
#   '하다',
#   '직통',
#   '쾌속',
#   '도',
#   '운전',
#   '개시',
#   '되어다',
#   '전반',
#   '적',
#   '으로',
#   '히',
#   '네',
#   '노',
#   '역',
#   '이북',
#   '에서는',
#   '량',
#   '편성',
#   '쾌속',
#   '열차',
#   '대폭',
#   '증가',
#   '되어다',
#   '때문',
#   '에',
#   '난',
#   '카이',
#   '전기',
#   '철도',
#   '본선',
#   '과',
#   '수송',
#   '력',
#   '에서',
#   '차이',
#   '나다',
#   '되어다'],
#  ['기세',
#   '본선',
#   '기노쿠니',
#   '선',
#   '에',
#   '직통',
#   '하다',
#   '특급',
#   '구로',
#   '시',
#   '오',
#   '슈퍼',
#   '구로',
#   '시',
#   '오',
#   '오션',
#   '애로우',
#   '호',
#   '와',
#   '간사이',
#   '공항선',
#   '에',
#   '직통',
#   '하다',
#   '특급',
#   '하루',
#   '카',
#   '호가',
#   '운전',
#   '되다',
#   '있다',
#   '정차',
#   '역다',
#   '덴노',
#   '지',
#   '오',
#   '토리',
#   '오션',
#   '애로우',
#   '루카',
#   '제외',
#   '이즈미',
#   '후추',
#   '오션',
#   '애로우',
#   '제외',
#   '히',
#   '네',
#   '노',
#   '오션',
#   '애로우',
#   '제외',
#   '즈',
#   '미스',
#   '나가다',
#   '오션',
#   '애로우',
#   '제외',
#   '이다',
#   '대낮',
#   '시간대',
#   '이후',
#   '에는',
#   '심야',
#   '시간대',
#   '를',
#   '제외',
#   '하고는',
#   '시간',
#   '당',
#   '편',
#   '난키',
#   '방면',
#   '편',
#   '간사이',
#   '공항',
#   '방면',
#   '편',
#   '으로',
#   '비교',
#   '적',
#   '운행',
#   '펴다',
#   '많다',
#   '승객',
#   '많다',
#   '시기',
#   '에는',
#   '임시',
#   '열차',
#   '도',
#   '운전',
#   '되다',
#   '때문',
#   '에',
#   '시간',
#   '당',
#   '편',
#   '가까이',
#   '펴다',
#   '운전',
#   '되다',
#   '있다',
#   '기본',
#   '적',
#   '으로',
#   '량',
#   '편성',
#   '운전',
#   '되다',
#   '승객',
#   '많다',
#   '때',
#   '에는',
#   '량',
#   '편성',
#   '으로',
#   '울다',
#   '기도',
#   '하다',
#   '덴노',
#   '지',
#   '역',
#   '와카야마',
#   '역',
#   '간',
#   '에서는',
#   '정차',
#   '역',
#   '비교',
#   '적',
#   '적기',
#   '때문',
#   '에',
#   '시판',
#   '되다',
#   '있다',
#   '시간표',
#   '하다',
#   '선',
#   '페이지',
#   '에서는',
#   '생략',
#   '되어다',
#   '있다',
#   '년',
#   '까지의',
#   '서일본',
#   '여객',
#   '철도',
#   '와카야마',
#   '지사',
#   '감수',
#   '하다',
#   '선',
#   '시간표',
#   '에는',
#   '구로',
#   '시오',
#   '시간표',
#   '도',
#   '개제',
#   '되어다',
#   '있다'],
#  ['년',
#   '월',
#   '부터',
#   '덴노',
#   '지',
#   '역',
#   '히',
#   '네',
#   '노',
#   '역',
#   '간',
#   '에',
#   '운전',
#   '을',
#   '개시',
#   '홈',
#   '라이너',
#   '이즈미',
#   '전신',
#   '이다',
#   '특급',
#   '구로',
#   '시오',
#   '계',
#   '전동차',
#   '히',
#   '네',
#   '노',
#   '전차',
#   '구',
#   '입선',
#   '회송',
#   '열차',
#   '를',
#   '좌석',
#   '정리',
#   '권',
#   '을',
#   '필요',
#   '로',
#   '하다',
#   '정원',
#   '제',
#   '열',
#   '차로',
#   '서',
#   '운행',
#   '해오다',
#   '으로',
#   '간사이',
#   '지방',
#   '최초',
#   '홈',
#   '라이너',
#   '이다',
#   '년',
#   '월',
#   '개정',
#   '에',
#   '따르다',
#   '운전',
#   '구간',
#   '와카야마',
#   '역',
#   '까지',
#   '연장',
#   '되어다',
#   '하다',
#   '라이너',
#   '로',
#   '개칭되어',
#   '현재',
#   '에',
#   '이르다',
#   '되어다',
#   '이전',
#   '에는',
#   '평일',
#   '에',
#   '상행',
#   '편',
#   '행',
#   '편이',
#   '운전',
#   '되어다',
#   '일부',
#   '신',
#   '오사카',
#   '역',
#   '이나',
#   '교토',
#   '역',
#   '방면',
#   '발착',
#   '특급',
#   '구로',
#   '시오',
#   '로',
#   '변경',
#   '되어다',
#   '년',
#   '월',
#   '이후',
#   '에는',
#   '상행',
#   '편',
#   '행',
#   '편',
#   '으로',
#   '축소',
#   '되어다',
#   '년',
#   '월',
#   '시간표',
#   '개정',
#   '부터는',
#   '휴일',
#   '시간대',
#   '운전',
#   '중단',
#   '되어다',
#   '같다',
#   '해',
#   '월',
#   '일',
#   '부터는',
#   '전면',
#   '금연',
#   '화',
#   '되어다'],
#  ['간쿠',
#   '쾌속',
#   '또는',
#   '관',
#   '공',
#   '쾌속',
#   '일본어',
#   '칸',
#   '쿠우',
#   '카이',
#   '소',
#   '쿠은',
#   '간사이',
#   '공항',
#   '특급',
#   '하루',
#   '카',
#   '와',
#   '함께',
#   '간사이',
#   '국제공항',
#   '연',
#   '계',
#   '열',
#   '차로',
#   '서',
#   '오사카',
#   '순환선',
#   '덴노',
#   '지',
#   '역',
#   '간사이',
#   '공항역',
#   '에',
#   '한해',
#   '간사이',
#   '국제공항',
#   '개항',
#   '년',
#   '월',
#   '부터',
#   '운행',
#   '개시',
#   '되다',
#   '쾌속',
#   '열차',
#   '이다',
#   '차량',
#   '서일본',
#   '여객',
#   '철도',
#   '계',
#   '전동차',
#   '번',
#   '대',
#   '와',
#   '번',
#   '대가',
#   '사용',
#   '되다',
#   '있다',
#   '대낮',
#   '시간대',
#   '에는',
#   '간사이',
#   '공항역',
#   '오사카',
#   '역',
#   '교바시',
#   '간',
#   '에',
#   '매시간',
#   '편',
#   '정도',
#   '운전',
#   '되다',
#   '있다',
#   '때문',
#   '에',
#   '덴노',
#   '지',
#   '역',
#   '하다',
#   '선',
#   '승강장',
#   '발착',
#   '열차',
#   '조조',
#   '와',
#   '심야',
#   '시간대',
#   '에만',
#   '존재',
#   '하다',
#   '조조',
#   '와',
#   '심야',
#   '시간대',
#   '를',
#   '제외',
#   '모든',
#   '열차',
#   '히',
#   '네',
#   '노',
#   '역',
#   '이북',
#   '전',
#   '구간',
#   '에서',
#   '와카야마',
#   '역',
#   '시발',
#   '기슈',
#   '지',
#   '쾌속',
#   '과',
#   '병',
#   '결하',
#   '여',
#   '량',
#   '편성',
#   '으로',
#   '운행',
#   '되다',
#   '있다',
#   '경우',
#   '에는',
#   '간사이',
#   '공항선',
#   '내',
#   '에서는',
#   '량',
#   '으로',
#   '운전',
#   '되어다',
#   '병결',
#   '시',
#   '에는',
#   '간쿠',
#   '쾌속',
#   '뒷',
#   '부분',
#   '기슈',
#   '지',
#   '쾌속',
#   '앞',
#   '부분',
#   '인',
#   '형태',
#   '로',
#   '연결',
#   '되다',
#   '년',
#   '월',
#   '일',
#   '시간표',
#   '개정',
#   '이후',
#   '에는',
#   '덴마',
#   '역',
#   '과',
#   '사쿠라',
#   '노미',
#   '야',
#   '역',
#   '에도',
#   '정차',
#   '하다',
#   '되어다',
#   '저녁',
#   '이후',
#   '에는',
#   '오사카',
#   '순환선',
#   '을',
#   '일주',
#   '하다',
#   '덴노',
#   '지',
#   '역',
#   '까지',
#   '운전',
#   '되다',
#   '운용',
#   '대폭',
#   '증가',
#   '하다',
#   '또',
#   '난바',
#   '역',
#   '에서',
#   '시발',
#   '하다',
#   '열차',
#   '와',
#   '특별',
#   '쾌속',
#   '윙',
#   '호도',
#   '있다',
#   '년',
#   '월',
#   '일',
#   '이후',
#   '소멸하다'],
#  ['한편',
#   '기슈',
#   '지',
#   '쾌속',
#   '일본어',
#   '키슈',
#   '우지',
#   '카이',
#   '소',
#   '쿠은',
#   '오사카',
#   '방면',
#   '에서',
#   '와카야마',
#   '방면',
#   '에의',
#   '관광객',
#   '및',
#   '통근',
#   '객',
#   '증대',
#   '를',
#   '도모',
#   '하다',
#   '때',
#   '까지',
#   '교토',
#   '역',
#   '신',
#   '오사카',
#   '역',
#   '방면',
#   '에서',
#   '와카야마',
#   '방면',
#   '으로',
#   '운행',
#   '하다',
#   '특급',
#   '열차',
#   '에',
#   '더하다',
#   '년',
#   '월',
#   '부터',
#   '신설',
#   '되다',
#   '쾌속',
#   '열차',
#   '이다',
#   '오사카',
#   '순환선',
#   '에서',
#   '발착',
#   '하다',
#   '덴노',
#   '지',
#   '역',
#   '에서',
#   '교바시',
#   '오사카',
#   '니',
#   '시쿠',
#   '조',
#   '를',
#   '경유',
#   '하다',
#   '다만',
#   '대부분',
#   '교바시',
#   '시발',
#   '운전',
#   '되다',
#   '있다',
#   '간쿠',
#   '쾌속',
#   '과',
#   '같이',
#   '계',
#   '전동차',
#   '번',
#   '대',
#   '와',
#   '번',
#   '대가',
#   '운용',
#   '되다',
#   '히',
#   '네',
#   '노',
#   '역',
#   '이북',
#   '에서는',
#   '전',
#   '열차',
#   '량',
#   '편성',
#   '으로',
#   '기본',
#   '적',
#   '으로',
#   '히',
#   '네',
#   '노',
#   '역',
#   '까지는',
#   '간쿠',
#   '쾌속',
#   '과',
#   '병결',
#   '운전',
#   '을',
#   '행',
#   '하다',
#   '히',
#   '네',
#   '노',
#   '역',
#   '에서',
#   '분할',
#   '과',
#   '병결',
#   '이루어지다',
#   '이전',
#   '에는',
#   '출퇴근',
#   '시간대',
#   '에',
#   '호차',
#   '량',
#   '기슈',
#   '지',
#   '쾌속',
#   '이다',
#   '나머지',
#   '시간대',
#   '에는',
#   '그',
#   '반대',
#   '이다',
#   '년',
#   '월',
#   '일',
#   '시간표',
#   '개정',
#   '에',
#   '따르다',
#   '량',
#   '편성',
#   '을',
#   '간쿠',
#   '와',
#   '기슈',
#   '지',
#   '쾌속',
#   '량씩',
#   '차지',
#   '하다',
#   '형태',
#   '로',
#   '통일',
#   '되어다',
#   '시간대',
#   '에',
#   '따르다',
#   '기슈',
#   '지',
#   '쾌속',
#   '과',
#   '간쿠',
#   '쾌속',
#   '연결',
#   '순서',
#   '바뀌다',
#   '경우',
#   '도',
#   '있다',
#   '휴일',
#   '시간표',
#   '에서',
#   '아침',
#   '상행',
#   '열차',
#   '에는',
#   '간쿠',
#   '쾌속',
#   '병결',
#   '되다',
#   '않다',
#   '채',
#   '기세',
#   '본선',
#   '고',
#   '역',
#   '에서',
#   '시발',
#   '하다',
#   '와카야마',
#   '역',
#   '에서',
#   '량',
#   '으로',
#   '증',
#   '결하',
#   '여',
#   '운행',
#   '하다',
#   '특별하다',
#   '형태',
#   '도',
#   '있다',
#   '오사카',
#   '방면',
#   '으로',
#   '가다',
#   '열차',
#   '와카야마',
#   '역',
#   '히',
#   '네',
#   '노',
#   '역',
#   '간',
#   '에는',
#   '량',
#   '편성',
#   '으로',
#   '운전',
#   '되다',
#   '때문',
#   '에',
#   '시발',
#   '역',
#   '인',
#   '와카야마',
#   '역',
#   '에서부터',
#   '혼잡하다',
#   '경우',
#   '많다'],
#  ['직통',
#   '쾌속',
#   '년',
#   '월',
#   '일',
#   '시간표',
#   '개정',
#   '으로',
#   '평일',
#   '아침',
#   '출근',
#   '시간대',
#   '에',
#   '신설',
#   '되다',
#   '오사카',
#   '순환선',
#   '직통',
#   '열차',
#   '이다',
#   '정차',
#   '역다',
#   '하다',
#   '선',
#   '내',
#   '에서는',
#   '쾌속',
#   '과',
#   '동일하다',
#   '오사카',
#   '순환선',
#   '안',
#   '에서는',
#   '각',
#   '역',
#   '에',
#   '정차',
#   '하다',
#   '차량',
#   '계',
#   '를',
#   '사용',
#   '하고',
#   '있다',
#   '상행',
#   '편이',
#   '오사카',
#   '순환선',
#   '외선',
#   '을',
#   '경',
#   '유해',
#   '오사카',
#   '역',
#   '교바시',
#   '방면',
#   '으로',
#   '운전',
#   '되다',
#   '오사카',
#   '순환선',
#   '을',
#   '일주',
#   '하다',
#   '열차',
#   '과',
#   '같이',
#   '도중',
#   '역',
#   '으로서',
#   '일단',
#   '덴노',
#   '지',
#   '역',
#   '에',
#   '정차',
#   '하다',
#   '에서',
#   '오사카',
#   '방면',
#   '으로',
#   '운행',
#   '하다',
#   '않다',
#   '오해',
#   '를',
#   '피',
#   '하다',
#   '위해',
#   '교바시',
#   '행',
#   '을',
#   '제외',
#   '하고',
#   '오사카',
#   '역',
#   '까지는',
#   '오사카',
#   '순환선',
#   '으로',
#   '안내',
#   '하고',
#   '있다',
#   '행',
#   '오사카',
#   '순환선',
#   '덴노',
#   '지',
#   '역',
#   '에서',
#   '교바시',
#   '역',
#   '을',
#   '경',
#   '유해',
#   '오',
#   '토리',
#   '역',
#   '이나',
#   '와카야마',
#   '역',
#   '행',
#   '각각',
#   '편',
#   '씩',
#   '운행',
#   '하고',
#   '있다'],
#  ['운전',
#   '구간',
#   '내의',
#   '모든',
#   '역',
#   '에',
#   '정차',
#   '하다',
#   '덴노',
#   '지',
#   '역',
#   '및',
#   '히',
#   '네',
#   '노',
#   '역',
#   '에',
#   '시',
#   '시발',
#   '하다',
#   '오',
#   '토리',
#   '역다',
#   '네',
#   '노',
#   '역',
#   '즈',
#   '미스',
#   '나가다',
#   '역',
#   '와카야마',
#   '역',
#   '간',
#   '에',
#   '운전',
#   '되다',
#   '있다',
#   '쓰다',
#   '루',
#   '오카',
#   '역',
#   '스',
#   '기',
#   '모토',
#   '초',
#   '역',
#   '우에노',
#   '시바',
#   '역',
#   '오',
#   '토리',
#   '역',
#   '이즈미',
#   '후추',
#   '역',
#   '히',
#   '가시',
#   '키시',
#   '와',
#   '다',
#   '역',
#   '히',
#   '가시',
#   '카이',
#   '즈',
#   '카',
#   '역',
#   '구마',
#   '토리',
#   '역',
#   '히',
#   '네',
#   '노',
#   '역',
#   '나가다',
#   '타키',
#   '역',
#   '즈',
#   '미스',
#   '나가다',
#   '역',
#   '기이',
#   '역',
#   '에는',
#   '대피',
#   '설비',
#   '있다',
#   '때문',
#   '에',
#   '후속',
#   '쾌속',
#   '및',
#   '특급',
#   '열차',
#   '통과',
#   '를',
#   '위',
#   '대피',
#   '이루어지다',
#   '대낮',
#   '시간대',
#   '에는',
#   '덴노',
#   '지',
#   '역',
#   '히',
#   '네',
#   '노',
#   '역',
#   '와카야마',
#   '역',
#   '간의',
#   '열차',
#   '시간',
#   '당',
#   '편',
#   '씩',
#   '조금',
#   '어긋나다',
#   '형태',
#   '로',
#   '운전',
#   '되다',
#   '차량',
#   '일본',
#   '국유철도',
#   '계',
#   '전동차',
#   '또는',
#   '일본',
#   '국유철도',
#   '계',
#   '전동차',
#   '로',
#   '량',
#   '편성',
#   '중심',
#   '으로',
#   '량',
#   '편성',
#   '열차',
#   '도',
#   '있다',
#   '조조',
#   '오',
#   '토리',
#   '역',
#   '시발',
#   '와카야마',
#   '행',
#   '편',
#   '만',
#   '서일본',
#   '여객',
#   '철도',
#   '계',
#   '전동차',
#   '량',
#   '편성',
#   '으로',
#   '운전',
#   '되다'],
#  ['년',
#   '월',
#   '일',
#   '현지',
#   '시간',
#   '시',
#   '분',
#   '전함',
#   '슐레스비히',
#   '홀슈타인',
#   '폴란드',
#   '주둔군',
#   '명과',
#   '예비군',
#   '명',
#   '머무르다',
#   '병영',
#   '을',
#   '향',
#   '하다',
#   '일',
#   '제',
#   '포격',
#   '을',
#   '시작',
#   '하다',
#   '폴란드',
#   '침공',
#   '과',
#   '함께',
#   '제',
#   '차',
#   '세계',
#   '대전',
#   '시작',
#   '되어다',
#   '수하',
#   '르',
#   '스키',
#   '장군',
#   '급하다',
#   '헬',
#   '반도',
#   '로',
#   '지금',
#   '포격',
#   '을',
#   '받다',
#   '있다',
#   '전신',
#   '을',
#   '보내다',
#   '경계',
#   '벽',
#   '에',
#   '포탄',
#   '맞다',
#   '구멍',
#   '생기',
#   '고',
#   '남',
#   '동부',
#   '지역',
#   '기름',
#   '창고',
#   '에는',
#   '불',
#   '붙다',
#   '폭발',
#   '하다',
#   '분',
#   '후',
#   '슐례스',
#   '비다',
#   '홀슈타인',
#   '전함',
#   '에서',
#   '중위',
#   '빌헬름',
#   '헤닝센',
#   '이끌다',
#   '해병대',
#   '급습',
#   '하고',
#   '독일',
#   '국방군',
#   '공병',
#   '개',
#   '소대',
#   '공세',
#   '를',
#   '펼치다',
#   '폴란드',
#   '본토',
#   '와',
#   '이어진',
#   '철교',
#   '를',
#   '폭파',
#   '시키다',
#   '이렇다',
#   '상황',
#   '에',
#   '독일군',
#   '기습',
#   '을',
#   '받다',
#   '놀란',
#   '폴란드군',
#   '을',
#   '쉬다',
#   '이기다',
#   '이라고',
#   '예상',
#   '하다',
#   '폴란드군',
#   '하사',
#   '보이시',
#   '에',
#   '흐',
#   '나이',
#   '사',
#   '레크',
#   '기관총',
#   '에',
#   '맞다',
#   '사망',
#   '하다',
#   '제',
#   '차',
#   '세계',
#   '대전',
#   '과',
#   '베스테르플라테',
#   '전투',
#   '최초',
#   '사망자',
#   '되어다',
#   '그러나',
#   '포격',
#   '으로',
#   '파괴',
#   '되다',
#   '벽돌',
#   '벽',
#   '을',
#   '넘다',
#   '후',
#   '에는',
#   '독일군',
#   '갑작스럽다',
#   '매복',
#   '공격',
#   '을',
#   '당하다',
#   '독일군',
#   '얽히섥힌',
#   '유자',
#   '철선',
#   '으로',
#   '인하다',
#   '재빠르다',
#   '기동',
#   '을',
#   '하다',
#   '못',
#   '하다',
#   '은폐',
#   '폴란드군',
#   '일제사격',
#   '살상지대',
#   '에',
#   '걸리다',
#   '들다',
#   '되어다',
#   '일부',
#   '나무',
#   '에',
#   '숨다',
#   '저격수',
#   '도',
#   '있다',
#   '하다',
#   '실제',
#   '로는',
#   '없다',
#   '폴란드군',
#   '보안',
#   '경찰',
#   '기관총',
#   '좌',
#   '를',
#   '제압',
#   '하다',
#   '폴란드군',
#   '중위',
#   '레온',
#   '파예',
#   '크다',
#   '전진',
#   '하다',
#   '독일군',
#   '에게',
#   '강력하다',
#   '곡사포',
#   '포격',
#   '을',
#   '하다',
#   '독일군',
#   '공격',
#   '을',
#   '막다',
#   '내다',
#   '항구',
#   '건너편',
#   '창고',
#   '위',
#   '에',
#   '있다',
#   '기관총',
#   '개',
#   '배치',
#   '되다',
#   '기관총',
#   '좌',
#   '도',
#   '제압',
#   '하다',
#   '독일군',
#   '전함',
#   '번의',
#   '포격',
#   '을',
#   '하다',
#   '완전하다',
#   '파괴',
#   '되어다'],
#  ['시',
#   '분',
#   '해병대',
#   '크다',
#   '손실',
#   '을',
#   '입다',
#   '후퇴',
#   '하다',
#   '배',
#   '에게',
#   '통신',
#   '을',
#   '보내다',
#   '단치히',
#   '경찰',
#   '베스테르플라테',
#   '반대편',
#   '항구',
#   '를',
#   '장악',
#   '하다',
#   '시도',
#   '하다',
#   '실패하다',
#   '때',
#   '까지의',
#   '사',
#   '상자',
#   '독일군',
#   '명',
#   '폴란드군',
#   '명',
#   '이다',
#   '독일군',
#   '시',
#   '분',
#   '다시',
#   '전진',
#   '을',
#   '시도',
#   '하다',
#   '지뢰',
#   '쓰러지다',
#   '나무',
#   '철조망',
#   '강력하다',
#   '포화',
#   '을',
#   '만나다',
#   '격전',
#   '을',
#   '벌이다',
#   '정오',
#   '에',
#   '군인',
#   '탈영',
#   '하다',
#   '헤닝센',
#   '치명',
#   '적',
#   '인',
#   '부상',
#   '을',
#   '입다',
#   '초기',
#   '공격',
#   '실패하다',
#   '이후',
#   '아침',
#   '에',
#   '다시',
#   '시작',
#   '두',
#   '번째',
#   '공격',
#   '포탄',
#   '발',
#   '포탄',
#   '발',
#   '포탄',
#   '발의',
#   '포격',
#   '이루어지다',
#   '이후',
#   '독일군',
#   '예',
#   '기',
#   '치',
#   '않다',
#   '크다',
#   '손실',
#   '을',
#   '입다',
#   '격퇴',
#   '당하다',
#   '하지만',
#   '결국',
#   '폴란드군',
#   '바',
#   '우',
#   '지역',
#   '과',
#   '전초',
#   '기지',
#   '프롬',
#   '으로',
#   '후퇴',
#   '하다',
#   '반도',
#   '중앙',
#   '새롭다',
#   '병영',
#   '주변',
#   '에',
#   '방어',
#   '기지',
#   '를',
#   '건설',
#   '하다',
#   '전투',
#   '첫날',
#   '이후',
#   '폴란드군',
#   '명',
#   '사망',
#   '하고',
#   '명',
#   '부상',
#   '을',
#   '입다',
#   '독일군',
#   '포로',
#   '로',
#   '잡고',
#   '병원',
#   '으로',
#   '후송',
#   '되다',
#   '명',
#   '을',
#   '포함',
#   '하다',
#   '명',
#   '나중',
#   '에',
#   '사망',
#   '하다',
#   '한편',
#   '독일',
#   '해군',
#   '보병',
#   '명',
#   '사망',
#   '하고',
#   '명',
#   '부상',
#   '을',
#   '입다',
#   '전체',
#   '명',
#   '중',
#   '대부분',
#   '부상',
#   '을',
#   '입다',
#   '독일군',
#   '손실',
#   '만약',
#   '폴란드',
#   '사령관',
#   '헨리크',
#   '수하',
#   '르',
#   '스키',
#   '탄약',
#   '을',
#   '절약',
#   '하다',
#   '위해',
#   '박격포',
#   '사격',
#   '을',
#   '중지',
#   '시키다',
#   '일제사격',
#   '후',
#   '포격하',
#   '라는',
#   '명령',
#   '을',
#   '하다',
#   '않다',
#   '더',
#   '늘어나다',
#   '이다',
#   '때문',
#   '에',
#   '다음',
#   '날',
#   '박격포',
#   '파괴',
#   '되어다',
#   '때',
#   '박격',
#   '포탄',
#   '개',
#   '중',
#   '개',
#   '만',
#   '쓰이다',
#   '나머지',
#   '무용지물',
#   '되다',
#   '말다'],
#  ['또한',
#   '폴란드',
#   '사령관',
#   '헨리크',
#   '수하',
#   '르',
#   '스키',
#   '와',
#   '부',
#   '사령관',
#   '이자',
#   '제독',
#   '인',
#   '프란치셰크',
#   '동',
#   '브',
#   '로프',
#   '스키',
#   '에',
#   '대한',
#   '논란',
#   '있다',
#   '전후',
#   '까지',
#   '살아나다',
#   '년',
#   '에',
#   '사망',
#   '수하',
#   '르',
#   '스키',
#   '소령',
#   '으로',
#   '진급',
#   '하고',
#   '폴란드',
#   '에서',
#   '가장',
#   '높다',
#   '훈장',
#   '인',
#   '비르',
#   '투티',
#   '밀리',
#   '타다',
#   '훈장',
#   '을',
#   '받다',
#   '에',
#   '대해',
#   '년대',
#   '에',
#   '발견',
#   '전투',
#   '에서',
#   '자신',
#   '역할',
#   '에',
#   '대한',
#   '알',
#   '없다',
#   '판단',
#   '으로',
#   '최근',
#   '매우',
#   '논쟁',
#   '대상',
#   '되어다',
#   '동',
#   '브',
#   '로프',
#   '스키',
#   '사망',
#   '이후',
#   '다른',
#   '폴란드',
#   '장교',
#   '이름',
#   '뿐',
#   '인',
#   '지휘',
#   '관',
#   '전투',
#   '기간',
#   '대부분',
#   '동안',
#   '셸',
#   '쇼크',
#   '상태',
#   '이다',
#   '을',
#   '그',
#   '명예',
#   '를',
#   '위해',
#   '숨다',
#   '맹세',
#   '하다',
#   '진술',
#   '하다',
#   '베스테르플라테',
#   '이후',
#   '박사',
#   '야',
#   '누쉬',
#   '마르',
#   '샬레',
#   '츠',
#   '폴란드',
#   '국립',
#   '추모',
#   '연구소',
#   '에서',
#   '다음',
#   '과',
#   '같이',
#   '요약',
#   '하다'],
#  ['헨리',
#   '구',
#   '스타',
#   '프',
#   '몰래',
#   '슨',
#   '영어',
#   '년',
#   '월',
#   '일',
#   '년',
#   '월',
#   '일',
#   '뇌전증',
#   '을',
#   '치료',
#   '하다',
#   '위해',
#   '서',
#   '수술',
#   '적',
#   '으로',
#   '해마',
#   '를',
#   '포함',
#   '내',
#   '측',
#   '측두엽',
#   '제거',
#   '되다',
#   '미국',
#   '기억',
#   '장애',
#   '환자',
#   '으로',
#   '전',
#   '부터',
#   '이미',
#   '알려지다',
#   '있다',
#   '그',
#   '년',
#   '말',
#   '부터',
#   '그',
#   '죽',
#   '을',
#   '때',
#   '까지',
#   '그',
#   '광범위하다',
#   '연구',
#   '되어다',
#   '그',
#   '경우',
#   '뇌',
#   '기능',
#   '과',
#   '기억',
#   '사이',
#   '링크',
#   '를',
#   '설명',
#   '하다',
#   '이론',
#   '발달',
#   '과',
#   '뇌',
#   '인지심리학',
#   '발달',
#   '뇌',
#   '구조',
#   '와',
#   '기능',
#   '특정',
#   '심리',
#   '적',
#   '과정',
#   '과',
#   '관',
#   '이해',
#   '를',
#   '목표',
#   '로',
#   '하다',
#   '심리학',
#   '하다',
#   '지점',
#   '에',
#   '매우',
#   '중요하다',
#   '역할',
#   '을',
#   '하다',
#   '그',
#   '죽다',
#   '전',
#   '에',
#   '그',
#   '코네티컷',
#   '윈저',
#   '락스',
#   '에',
#   '위치',
#   '관리',
#   '기관',
#   '에',
#   '살다',
#   '지속',
#   '적',
#   '으로',
#   '조사',
#   '되어다',
#   '그',
#   '뇌',
#   '지금',
#   '년',
#   '월',
#   '일',
#   '에',
#   '조직학',
#   '적',
#   '으로',
#   '슬',
#   '라이스',
#   '되어다',
#   '미국',
#   '샌디에이고',
#   '에',
#   '있다'],
#  ['수술',
#   '후',
#   '일차',
#   '적',
#   '인',
#   '목표',
#   '이다',
#   '뇌전증',
#   '을',
#   '조절',
#   '하다',
#   '성공하다',
#   '그',
#   '심하다',
#   '순',
#   '행성',
#   '기억',
#   '상실',
#   '로',
#   '고통',
#   '받다',
#   '비록',
#   '그',
#   '작업',
#   '기억',
#   '이나',
#   '절차',
#   '기억',
#   '괜찮다',
#   '그',
#   '새롭다',
#   '사건',
#   '을',
#   '명시',
#   '적',
#   '기억',
#   '으로',
#   '전환',
#   '하다',
#   '못',
#   '하다',
#   '어떻다',
#   '과학자',
#   '에',
#   '의하다',
#   '몰래슨',
#   '새롭다',
#   '의미',
#   '지식',
#   '을',
#   '형성',
#   '하다',
#   '능력',
#   '손상',
#   '되어다',
#   '하다',
#   '또',
#   '다른',
#   '연구자',
#   '장애',
#   '정도',
#   '에',
#   '대해',
#   '서',
#   '주장',
#   '을',
#   '하다',
#   '그',
#   '또한',
#   '역행',
#   '성',
#   '기억',
#   '상실',
#   '로',
#   '인하다',
#   '어느',
#   '정도',
#   '고통',
#   '을',
#   '받다',
#   '수술',
#   '전',
#   '년',
#   '동안',
#   '일',
#   '물론',
#   '최대',
#   '년',
#   '전의',
#   '일도',
#   '기억',
#   '하다',
#   '없다',
#   '그',
#   '기억상실증',
#   '시간',
#   '적',
#   '으로',
#   '변하다',
#   '을',
#   '의미',
#   '하다',
#   '그러나',
#   '그',
#   '장기',
#   '절차',
#   '기억',
#   '을',
#   '형성',
#   '하다',
#   '능력',
#   '그대로',
#   '이다',
#   '예',
#   '를',
#   '들다',
#   '새롭다',
#   '동작',
#   '능력',
#   '을',
#   '배우다',
#   '배우다',
#   '을',
#   '기억',
#   '을',
#   '못',
#   '하다',
#   '이다'],
#  ['그',
#   '기억상실증',
#   '상',
#   '에도',
#   '불구',
#   '하고',
#   '몰래슨',
#   '지능',
#   '검사',
#   '에서는',
#   '지극히',
#   '정상',
#   '이다',
#   '어떻다',
#   '기억',
#   '능력',
#   '수술',
#   '에',
#   '의하다',
#   '손상',
#   '되다',
#   '않다',
#   '음',
#   '을',
#   '의미',
#   '하다',
#   '그러나',
#   '문장',
#   '수준',
#   '언어',
#   '이해',
#   '및',
#   '생산',
#   '을',
#   '위해',
#   '몰래슨',
#   '기억',
#   '에서와',
#   '같다',
#   '장애',
#   '를',
#   '보이다',
#   '몰래슨',
#   '짧다',
#   '간격',
#   '시간',
#   '정보',
#   '를',
#   '기억',
#   '하다',
#   '가능하다',
#   '방금',
#   '전',
#   '에',
#   '보여주다',
#   '단어',
#   '를',
#   '바로',
#   '기억',
#   '하다',
#   '작업기억',
#   '실험',
#   '으로',
#   '테스트',
#   '하다',
#   '사실',
#   '그',
#   '정상',
#   '사람',
#   '과',
#   '비교',
#   '하다',
#   '때',
#   '심하다',
#   '나쁘다',
#   '하다',
#   '않다',
#   '이러하다',
#   '발견',
#   '작업기억',
#   '중앙',
#   '측두엽',
#   '구',
#   '조물',
#   '에',
#   '의존',
#   '하다',
#   '않다',
#   '증거',
#   '를',
#   '제공',
#   '하다',
#   '단기기억',
#   '과',
#   '장기기억',
#   '일반',
#   '적',
#   '으로',
#   '다르다',
#   '을',
#   '지지',
#   '하다',
#   '주다',
#   '몰래슨',
#   '대부분',
#   '단어',
#   '검색',
#   '어휘',
#   '메모리',
#   '중앙',
#   '측두엽',
#   '구조',
#   '물이',
#   '독립',
#   '적',
#   '이라는',
#   '증거',
#   '를',
#   '제공',
#   '다'],
#  ['에',
#   '따르다',
#   '몰래슨',
#   '기억',
#   '능력',
#   '실험',
#   '또한',
#   '공',
#   '간기',
#   '억',
#   '과',
#   '공간',
#   '정보',
#   '프로세스',
#   '를',
#   '처리',
#   '하다',
#   '신경',
#   '구조',
#   '에',
#   '대한',
#   '인사이트',
#   '를',
#   '제공',
#   '다',
#   '그',
#   '새롭다',
#   '삽화',
#   '와',
#   '사실',
#   '적',
#   '인',
#   '장기',
#   '기억',
#   '형성',
#   '일반',
#   '적',
#   '인',
#   '장애',
#   '와',
#   '특정',
#   '공간',
#   '기억',
#   '시험',
#   '심하다',
#   '장애',
#   '에도',
#   '불구',
#   '하고',
#   '몰래슨',
#   '그',
#   '거주',
#   '지형',
#   '레이아웃',
#   '매우',
#   '상세',
#   '지도',
#   '를',
#   '그릴',
#   '가다',
#   '있다',
#   '몰래슨',
#   '수술',
#   '후',
#   '년',
#   '후',
#   '에',
#   '이사',
#   '를',
#   '가다',
#   '때문',
#   '에',
#   '놀랍다',
#   '발견',
#   '이다',
#   '따라서',
#   '그',
#   '심하다',
#   '순',
#   '행성',
#   '기억',
#   '상실',
#   '증',
#   '과',
#   '인사이트',
#   '와',
#   '같다',
#   '다른',
#   '케이스',
#   '일반',
#   '적',
#   '인',
#   '기대다',
#   '정밀',
#   '기억',
#   '획득',
#   '에',
#   '장애',
#   '있다',
#   '이다',
#   '몰래슨',
#   '방',
#   '에서',
#   '방',
#   '으로',
#   '매일',
#   '움직이다',
#   '결과',
#   '로',
#   '자신',
#   '집의',
#   '공간',
#   '레이아웃',
#   '인지',
#   '지도',
#   '를',
#   '구축',
#   '하다',
#   '있다',
#   '가정',
#   '하다'],
#  ['인간',
#   '기억',
#   '이해',
#   '에',
#   '대한',
#   '몰래슨',
#   '또',
#   '다른',
#   '기여',
#   '안정',
#   '적',
#   '인',
#   '장기기억',
#   '형성',
#   '역할',
#   '을',
#   '하다',
#   '기억',
#   '통합',
#   '과정',
#   '신',
#   '경구조',
#   '와',
#   '관련',
#   '있다',
#   '몰래슨',
#   '다음',
#   '과',
#   '같이',
#   '어리다',
#   '시절',
#   '기억',
#   '을',
#   '여전하다',
#   '하다',
#   '있다',
#   '수술',
#   '받다',
#   '전',
#   '을',
#   '기억',
#   '하다',
#   '어렵다',
#   '시간',
#   '적',
#   '인',
#   '퇴',
#   '행성',
#   '기억상실증',
#   '을',
#   '보이다',
#   '그',
#   '오래되다',
#   '기억',
#   '장애',
#   '없다',
#   '반면',
#   '비교',
#   '적',
#   '수술',
#   '가까이',
#   '기억',
#   '에는',
#   '장애',
#   '있다',
#   '오래되다',
#   '어리다',
#   '시절',
#   '기억',
#   '내',
#   '측',
#   '측두엽',
#   '에',
#   '의하다',
#   '아니다',
#   '말',
#   '해주다',
#   '반면',
#   '비교',
#   '적',
#   '가깝다',
#   '장기기억',
#   '내',
#   '측',
#   '측두엽',
#   '에',
#   '의하다',
#   '수술',
#   '로',
#   '제거',
#   '되다',
#   '중앙',
#   '측두엽',
#   '구',
#   '조물',
#   '기억',
#   '통합',
#   '에',
#   '수반',
#   '되다',
#   '가정',
#   '되다',
#   '내',
#   '측',
#   '측두엽',
#   '과',
#   '다양하다',
#   '측면',
#   '대뇌피질',
#   '부의',
#   '상호작용',
#   '경험',
#   '피질',
#   '표현',
#   '사이',
#   '에',
#   '천천히',
#   '직접',
#   '적',
#   '인',
#   '링크',
#   '를',
#   '형',
#   '성함',
#   '으로써',
#   '내',
#   '측',
#   '측두엽',
#   '밖에',
#   '기억',
#   '을',
#   '저장',
#   '하다',
#   '으로',
#   '생각',
#   '되다'],
#  ['초',
#   '우라늄',
#   '원소',
#   '존재',
#   '년',
#   '엔',
#   '리코',
#   '페르미',
#   '그',
#   '연구',
#   '를',
#   '바탕',
#   '으로',
#   '제안',
#   '이다',
#   '그러나',
#   '그',
#   '당시',
#   '악티늄족',
#   '개',
#   '원소',
#   '밖에',
#   '존재',
#   '하다',
#   '않다',
#   '란타넘족',
#   '과',
#   '비슷하다',
#   '개념',
#   '을',
#   '사람',
#   '이해',
#   '하다',
#   '못',
#   '하다',
#   '그',
#   '당시',
#   '에',
#   '우세하다',
#   '주장',
#   '초',
#   '우라늄',
#   '악티늄족',
#   '아니다',
#   '주기',
#   '에',
#   '들어가다',
#   '하다',
#   '하다',
#   '이다',
#   '토륨',
#   '과',
#   '프로탁티늄',
#   '우라늄',
#   '각각',
#   '주기',
#   '인',
#   '하프늄',
#   '탄탈럼',
#   '그리고',
#   '텅스텐',
#   '아래',
#   '에',
#   '있다',
#   '한다는',
#   '이다',
#   '초',
#   '우라늄',
#   '합성',
#   '서서히',
#   '악티늄족',
#   '중심',
#   '을',
#   '파헤치다',
#   '가다',
#   '년',
#   '에',
#   '악티늄족',
#   '가설',
#   '을',
#   '완성',
#   '시키다',
#   '위해',
#   '글렌',
#   '시',
#   '보그',
#   '담당',
#   '퀴륨',
#   '산화',
#   '이상',
#   '산화',
#   '상태',
#   '실험',
#   '실패',
#   '를',
#   '관찰',
#   '하다',
#   '주기',
#   '인',
#   '백금',
#   '아래',
#   '에',
#   '있다',
#   '으로',
#   '추정',
#   '되어다',
#   '인데',
#   '백금',
#   '산화',
#   '까지',
#   '가능하다',
#   '때문',
#   '이다',
#   '알려지다',
#   '악티늄족',
#   '가르침',
#   '과',
#   '더',
#   '많다',
#   '초',
#   '우라늄',
#   '원소',
#   '합성',
#   '만들다',
#   '내다',
#   '자료',
#   '중심',
#   '을',
#   '더',
#   '파고',
#   '들어가다',
#   '문장',
#   '악티늄족',
#   '가설',
#   '가설',
#   '영향',
#   '결정',
#   '적',
#   '으로',
#   '입증',
#   '되다',
#   '못',
#   '하다',
#   '남아',
#   '서',
#   '년대',
#   '후반',
#   '에',
#   '과학자',
#   '에',
#   '의하다',
#   '적극',
#   '적',
#   '으로',
#   '활용',
#   '하다',
#   '되다'],
#  ['우라늄',
#   '과',
#   '토륨',
#   '처음',
#   '으로',
#   '발견',
#   '되다',
#   '원소',
#   '이다',
#   '우라늄',
#   '년',
#   '에',
#   '독일',
#   '화학자',
#   '마르틴',
#   '하인리히',
#   '클라프로트',
#   '피치블렌드',
#   '광석',
#   '에서',
#   '발견',
#   '되어다',
#   '인정',
#   '되어다',
#   '그',
#   '천왕성',
#   '에서',
#   '원소',
#   '이름',
#   '을',
#   '고안',
#   '하다',
#   '다른',
#   '과학자',
#   '보다',
#   '단',
#   '년',
#   '빠르다',
#   '발견',
#   '이다',
#   '클라프로트',
#   '피치블렌드',
#   '를',
#   '질산',
#   '에',
#   '담그다',
#   '녹이다',
#   '상태',
#   '에서',
#   '수산화나트륨',
#   '에',
#   '중화',
#   '시키다',
#   '촉진',
#   '시키다',
#   '우라늄',
#   '산',
#   '나트륨',
#   '같다',
#   '노란색',
#   '화합물',
#   '을',
#   '만들다',
#   '그',
#   '목탄',
#   '과',
#   '발견',
#   '노랗다',
#   '가루',
#   '를',
#   '환원',
#   '시키다',
#   '검정색',
#   '물질',
#   '을',
#   '추출',
#   '하다',
#   '년',
#   '지난',
#   '뒤',
#   '에',
#   '프랑스',
#   '과학자',
#   '페리',
#   '고가',
#   '산화',
#   '우라늄',
#   '을',
#   '발견',
#   '하다',
#   '또한',
#   '그',
#   '사',
#   '염화',
#   '우라늄',
#   '과',
#   '칼륨',
#   '을',
#   '함께',
#   '가열',
#   '하다',
#   '금속',
#   '우라늄',
#   '을',
#   '분리',
#   '해내다',
#   '우라늄',
#   '원자량',
#   '으로',
#   '계산',
#   '되어다',
#   '년',
#   '에',
#   '드미트리',
#   '멘델레예프',
#   '그',
#   '기',
#   '율법',
#   '을',
#   '통해',
#   '서',
#   '으로',
#   '밝혀내다',
#   '질량',
#   '년',
#   '에',
#   '지',
#   '머맨',
#   '에',
#   '의하다',
#   '실험',
#   '적',
#   '으로',
#   '밝혀지다'],
#  ['악티늄',
#   '년',
#   '에',
#   '마리',
#   '퀴리',
#   '도움',
#   '으로',
#   '드비에른',
#   '에',
#   '의하다',
#   '발견',
#   '되어다',
#   '라듐',
#   '과',
#   '폴로늄',
#   '을',
#   '빼다',
#   '남다',
#   '피치블렌드',
#   '찌꺼기',
#   '에서',
#   '발견',
#   '되다',
#   '이다',
#   '년',
#   '당시',
#   '그',
#   '물질',
#   '티타늄',
#   '과',
#   '비슷하다',
#   '하다',
#   '또',
#   '년',
#   '당시',
#   '에는',
#   '토륨',
#   '과도',
#   '비슷하다',
#   '하다',
#   '년',
#   '에',
#   '악티늄',
#   '발견',
#   '자',
#   '드비에른',
#   '맞다',
#   '지다',
#   '대한',
#   '논쟁',
#   '일어나다',
#   '하다',
#   '그리고',
#   '년',
#   '에도',
#   '일어나다',
#   '발표',
#   '년',
#   '에',
#   '되어다',
#   '년',
#   '에',
#   '하다',
#   '실험',
#   '모',
#   '순',
#   '점',
#   '이라는',
#   '이다',
#   '악티늄',
#   '어원',
#   '그리스어',
#   '로',
#   '빛',
#   '광선',
#   '을',
#   '뜻',
#   '하다',
#   '를',
#   '사용',
#   '하다',
#   '금속',
#   '자기',
#   '자신',
#   '방사성',
#   '아니다',
#   '딸',
#   '핵종',
#   '방사성',
#   '존재',
#   '하다',
#   '때문',
#   '이다',
#   '란타넘족',
#   '과',
#   '악티늄족',
#   '유사',
#   '점',
#   '서서히',
#   '밝혀지다',
#   '되어다',
#   '자연',
#   '에',
#   '존재',
#   '하다',
#   '적다',
#   '양',
#   '원소',
#   '이다',
#   '이다',
#   '순수하다',
#   '악티늄',
#   '년',
#   '되어다',
#   '만들어지다',
#   '악티늄족',
#   '년',
#   '에',
#   '빅터',
#   '골드',
#   '슈미트',
#   '에',
#   '의하다',
#   '소개',
#   '되어다',
#   '으로',
#   '추정',
#   '되다'],
#  ['프로탁티늄',
#   '년',
#   '에',
#   '윌리엄',
#   '크룩스',
#   '에',
#   '의하다',
#   '분리',
#   '되어다',
#   '년',
#   '에',
#   '카',
#   '지미',
#   '에',
#   '시',
#   '파얀스',
#   '와',
#   '오스',
#   '발트',
#   '헬',
#   '무트',
#   '괴링',
#   '붕괴',
#   '연구',
#   '에서',
#   '짧다',
#   '반감기',
#   '를',
#   '가지다',
#   '반감기',
#   '불다',
#   '발견',
#   '하다',
#   '그',
#   '새롭다',
#   '원소',
#   '이름',
#   '을',
#   '브레븀',
#   '이라고',
#   '명칭',
#   '하다',
#   '라틴어',
#   '로',
#   '짧다',
#   '뜻',
#   '에서',
#   '유래',
#   '되어다',
#   '이름',
#   '후',
#   '에',
#   '프로탁티늄',
#   '으로',
#   '바뀌다',
#   '그리스어',
#   '로',
#   '광선',
#   '원소',
#   '보다',
#   '먼저',
#   '뜻',
#   '을',
#   '가지',
#   '고',
#   '있다',
#   '년',
#   '에',
#   '두',
#   '그룹',
#   '과학자',
#   '를',
#   '발견',
#   '하다',
#   '독일',
#   '오스트리아인',
#   '리제',
#   '마이트너',
#   '와',
#   '오토',
#   '하다',
#   '그리고',
#   '영국',
#   '프레더릭',
#   '소디',
#   '와',
#   '존',
#   '크랜',
#   '스턴',
#   '이름',
#   '년',
#   '에',
#   '프로탁티늄',
#   '으로',
#   '좁히다',
#   '원소',
#   '년',
#   '까지',
#   '특별하다',
#   '일이',
#   '있다',
#   '영국',
#   '에서',
#   '매',
#   '덕',
#   '과',
#   '그',
#   '동',
#   '업자',
#   '우라늄',
#   '을',
#   '추출',
#   '하고',
#   '남다',
#   '톤',
#   '찌꺼기',
#   '을',
#   '분석',
#   '하다',
#   '그램',
#   '프로탁티늄',
#   '을',
#   '만들다',
#   '내다'],
#  ['아인슈타이늄',
#   '과',
#   '페르뮴',
#   '년',
#   '월',
#   '일',
#   '실시',
#   '되다',
#   '소',
#   '폭탄',
#   '첫',
#   '성공',
#   '적',
#   '실험',
#   '인',
#   '아이비',
#   '마이크',
#   '핵실험',
#   '부산물',
#   '로',
#   '각각',
#   '년',
#   '과',
#   '년',
#   '에',
#   '발견',
#   '되어다',
#   '중성자',
#   '폭발',
#   '에',
#   '노출',
#   '되다',
#   '우라늄',
#   '우라늄',
#   '무겁다',
#   '동위',
#   '원소',
#   '를',
#   '생',
#   '성하다',
#   '우라늄',
#   '과',
#   '우라늄',
#   '을',
#   '포함',
#   '그리고',
#   '붕괴',
#   '아인슈타이늄',
#   '과',
#   '페르뮴',
#   '를',
#   '만들다',
#   '새롭다',
#   '원소',
#   '발견',
#   '과',
#   '중성자',
#   '를',
#   '차지',
#   '한다는',
#   '새롭다',
#   '기록',
#   '발견',
#   '되어다',
#   '그런데',
#   '그때',
#   '당시',
#   '년',
#   '까지',
#   '일어나다',
#   '냉전',
#   '시대',
#   '여서',
#   '긴장',
#   '상태',
#   '이다',
#   '미국',
#   '군',
#   '에서는',
#   '완전하다',
#   '비밀',
#   '로',
#   '하다',
#   '그렇다',
#   '불구',
#   '하고',
#   '버클리',
#   '연구소',
#   '에서는',
#   '아인슈타이늄',
#   '과',
#   '페르뮴',
#   '을',
#   '만들다',
#   '있다',
#   '이라고',
#   '생각',
#   '하다',
#   '그래서',
#   '플루토늄',
#   '에',
#   '중성자',
#   '를',
#   '충돌',
#   '시키다',
#   '생각',
#   '을',
#   '하다',
#   '년',
#   '에',
#   '실험',
#   '을',
#   '하다',
#   '만들다',
#   '첫',
#   '발견',
#   '아니다',
#   '에',
#   '대한',
#   '부인',
#   '까지',
#   '합',
#   '하다',
#   '발표',
#   '하다',
#   '아이비',
#   '마이크',
#   '사건',
#   '미등록',
#   '되다',
#   '년',
#   '에서',
#   '승인',
#   '하다',
#   '처음',
#   '으로',
#   '중요하다',
#   '마이크로',
#   '그램',
#   '미만',
#   '아인슈타이늄',
#   '년',
#   '에',
#   '커닝햄',
#   '과',
#   '그',
#   '동료',
#   '만들다',
#   '내다',
#   '페르뮴',
#   '까지는',
#   '끝나다',
#   '않다'],
#  ['년',
#   '기준',
#   '개',
#   '악티늄',
#   '동위',
#   '원소',
#   '와',
#   '개',
#   '들뜨다',
#   '핵',
#   '성',
#   '상태',
#   '와',
#   '그것',
#   '핵종',
#   '인식',
#   '되어다',
#   '그중',
#   '개',
#   '동위원소',
#   '그리고',
#   '늘다',
#   '자연',
#   '에서',
#   '발견',
#   '되어다',
#   '나머지',
#   '인공',
#   '합성',
#   '으로',
#   '만들어지다',
#   '개',
#   '자연',
#   '적',
#   '동위원소',
#   '만',
#   '적용',
#   '에',
#   '사용',
#   '하다',
#   '있다',
#   '악티늄',
#   '늘다',
#   '방사성',
#   '넵투늄',
#   '족',
#   '에',
#   '들어가다',
#   '년',
#   '에',
#   '붕괴하다',
#   '때',
#   '첫',
#   '발견',
#   '되어다',
#   '반감기',
#   '일인',
#   '방사',
#   '체',
#   '이다',
#   '악티늄',
#   '늘다',
#   '악티늄',
#   '보다',
#   '적다',
#   '양',
#   '이지만',
#   '방사성',
#   '트',
#   '레이서',
#   '적용',
#   '에',
#   '수요',
#   '촉망',
#   '되다',
#   '악티늄',
#   '반감기',
#   '년',
#   '모든',
#   '우라늄',
#   '광석',
#   '에',
#   '존재',
#   '지만',
#   '적다',
#   '양',
#   '만',
#   '존재',
#   '하다',
#   '우라늄',
#   '광석',
#   '그램',
#   '방사성',
#   '평형',
#   '일',
#   '때',
#   '오직',
#   '그램',
#   '만',
#   '들다',
#   '악티늄',
#   '방사성',
#   '토륨',
#   '족',
#   '에',
#   '들어가다',
#   '붕괴',
#   '에',
#   '의하다',
#   '생',
#   '성',
#   '되다',
#   '반감기',
#   '시간',
#   '인',
#   '방사',
#   '체',
#   '이다',
#   '톤',
#   '토륨',
#   '에는',
#   '그램',
#   '들다',
#   '년',
#   '에',
#   '오토',
#   '하다',
#   '의하다',
#   '발견',
#   '되어다'],
#  ['개',
#   '퀴륨',
#   '동위',
#   '원소',
#   '중',
#   '가장',
#   '널리',
#   '알려지다',
#   '과',
#   '이다',
#   '입자',
#   '를',
#   '방출',
#   '지만',
#   '아메리슘',
#   '동위',
#   '원소',
#   '보다',
#   '훨씬',
#   '짧다',
#   '반감기',
#   '를',
#   '가지',
#   '고',
#   '있다',
#   '동위',
#   '원소',
#   '선',
#   '을',
#   '거의',
#   '방출',
#   '하다',
#   '않다',
#   '자발',
#   '핵분열',
#   '을',
#   '하다',
#   '때',
#   '중성자',
#   '를',
#   '배출',
#   '하다',
#   '퀴륨',
#   '동위',
#   '원소',
#   '중',
#   '반감기',
#   '기다',
#   '편',
#   '에',
#   '속',
#   '하다',
#   '것은',
#   '이며',
#   '모두',
#   '입자',
#   '를',
#   '방출',
#   '하다',
#   '플루토늄',
#   '이나',
#   '아메리슘',
#   '에',
#   '중성자',
#   '조사',
#   '를',
#   '하다',
#   '혼합물',
#   '로',
#   '생',
#   '성',
#   '되다',
#   '짧다',
#   '조사',
#   '를',
#   '하다',
#   '때',
#   '혼합물',
#   '퀴륨',
#   '으로',
#   '변하다',
#   '퀴륨',
#   '축적',
#   '되다',
#   '시작',
#   '다',
#   '같다',
#   '동위',
#   '원소',
#   '더',
#   '기다',
#   '반감기',
#   '를',
#   '가지',
#   '고',
#   '있다',
#   '년',
#   '과',
#   '보다',
#   '화학',
#   '적',
#   '연구',
#   '에',
#   '크다',
#   '도움',
#   '을',
#   '주다',
#   '그러나',
#   '자발',
#   '핵분열',
#   '확률',
#   '도',
#   '더',
#   '커지다',
#   '퀴륨',
#   '동위',
#   '원소',
#   '중',
#   '가장',
#   '기다',
#   '반감기',
#   '를',
#   '가지',
#   '고',
#   '있다',
#   '년',
#   '많다',
#   '양',
#   '존재',
#   '지는',
#   '않다',
#   '왜냐하면',
#   '열',
#   '중성자',
#   '유도',
#   '에',
#   '의하다',
#   '자발',
#   '핵분열',
#   '을',
#   '하다',
#   '확률',
#   '더',
#   '커지다',
#   '때문',
#   '이다'],
#  ['질량수',
#   '부터',
#   '끄다',
#   '캘리포늄',
#   '동위',
#   '원소',
#   '핵',
#   '반',
#   '응기',
#   '에서',
#   '만들어지다',
#   '캘리포늄',
#   '방사',
#   '를',
#   '하다',
#   '동위',
#   '원소',
#   '이고',
#   '나머지',
#   '방사',
#   '를',
#   '하다',
#   '동위',
#   '원소',
#   '이다',
#   '질량수',
#   '짝수',
#   '인',
#   '동위',
#   '원소',
#   '늘다',
#   '자발',
#   '핵분열',
#   '을',
#   '하다',
#   '확률',
#   '높다',
#   '특히',
#   '늘다',
#   '자발',
#   '핵분열',
#   '하다',
#   '확률',
#   '이다',
#   '캘리포늄',
#   '늘다',
#   '그나마',
#   '기다',
#   '반감기',
#   '년',
#   '을',
#   '가지',
#   '고',
#   '있다',
#   '낮다',
#   '자발',
#   '핵분열',
#   '확률',
#   '과',
#   '강하다',
#   '방사',
#   '를',
#   '하다',
#   '인식',
#   '을',
#   '가능하다',
#   '하다',
#   '늘다',
#   '핵',
#   '반',
#   '응기',
#   '에서',
#   '많이',
#   '만들어지다',
#   '않다',
#   '왜냐하면',
#   '붕괴',
#   '되다',
#   '전',
#   '느리다',
#   '붕괴',
#   '와',
#   '중성자',
#   '와',
#   '상호',
#   '작용',
#   '을',
#   '하다',
#   '때',
#   '크다',
#   '단',
#   '면적',
#   '때문',
#   '에',
#   '만들기',
#   '쉬다',
#   '않다',
#   '그러나',
#   '붕괴',
#   '산물',
#   '로',
#   '인하다',
#   '순수하다',
#   '동위',
#   '원소',
#   '로',
#   '축적',
#   '되다',
#   '캘리포늄',
#   '플루토늄',
#   '반',
#   '응기',
#   '조사',
#   '에',
#   '의하다',
#   '만들어지다',
#   '주로',
#   '과',
#   '가다',
#   '존재',
#   '하다',
#   '후',
#   '에',
#   '크다',
#   '중성자',
#   '영향',
#   '으로',
#   '점점',
#   '뚜렷하다',
#   '특징',
#   '강하다',
#   '중성',
#   '자선',
#   '에',
#   '의하다',
#   '반응',
#   '저해',
#   '되다'],
#  ['개',
#   '로',
#   '알려지다',
#   '멘델레븀',
#   '동위',
#   '원소',
#   '중',
#   '질량수',
#   '에서',
#   '사이',
#   '가장',
#   '알려지다',
#   '이다',
#   '반감기',
#   '분',
#   '이고',
#   '주로',
#   '전자',
#   '포획',
#   '을',
#   '통해',
#   '서',
#   '붕괴하다',
#   '선',
#   '또다른',
#   '알파',
#   '방사',
#   '체',
#   '인데',
#   '일',
#   '반감기',
#   '를',
#   '가지',
#   '고',
#   '있다',
#   '동위',
#   '원소',
#   '희귀',
#   '아인슈타이늄',
#   '과',
#   '에서',
#   '생',
#   '성',
#   '되다',
#   '그러므로',
#   '생',
#   '성',
#   '에',
#   '한계',
#   '존재',
#   '하다',
#   '그나마',
#   '기다',
#   '수명',
#   '을',
#   '가지다',
#   '노벨륨',
#   '동위',
#   '원소',
#   '와',
#   '로렌슘',
#   '동위',
#   '원소',
#   '그리고',
#   '더',
#   '무겁다',
#   '원소',
#   '상대',
#   '적',
#   '으로',
#   '짧다',
#   '반감기',
#   '를',
#   '가지',
#   '고',
#   '있다',
#   '노벨륨',
#   '개',
#   '동위',
#   '원소',
#   '알려지다',
#   '있다',
#   '질량수',
#   '사이',
#   '그리고',
#   '이다',
#   '노벨륨',
#   '과',
#   '로렌슘',
#   '화학',
#   '적',
#   '성질',
#   '분과',
#   '초으',
#   '로',
#   '자다',
#   '알려지다',
#   '있다',
#   '노벨륨',
#   '동위',
#   '원소',
#   '중',
#   '노벨륨',
#   '동위',
#   '원소',
#   '중',
#   '가장',
#   '기다',
#   '시간',
#   '반감기',
#   '를',
#   '가지',
#   '고',
#   '있다'],
#  ['토륨',
#   '과',
#   '우라늄',
#   '자연',
#   '에',
#   '가장',
#   '많다',
#   '악티늄족',
#   '원소',
#   '다',
#   '각',
#   '질량',
#   '집중',
#   '과',
#   '이다',
#   '우라늄',
#   '주로',
#   '지각',
#   '에서',
#   '산화',
#   '되다',
#   '광물',
#   '로',
#   '나오다',
#   '자다',
#   '알려지다',
#   '광석',
#   '피치블렌드',
#   '우라니나이트',
#   '있다',
#   '피치블렌드',
#   '로',
#   '불리',
#   '게',
#   '되다',
#   '이유',
#   '검정색',
#   '이기',
#   '때문',
#   '이다',
#   '분류',
#   '우라늄',
#   '광물',
#   '에서',
#   '더',
#   '많다',
#   '광석',
#   '을',
#   '볼',
#   '있다',
#   '카르노',
#   '타이',
#   '트',
#   '나',
#   '인회',
#   '우라늄',
#   '광',
#   '도',
#   '있다',
#   '천연',
#   '우라늄',
#   '동위원소',
#   '비율',
#   '그리고',
#   '있다',
#   '동위원소',
#   '중',
#   '가장',
#   '기다',
#   '년',
#   '반감기',
#   '를',
#   '가지',
#   '고',
#   '있다',
#   '전',
#   '세계',
#   '적',
#   '으로',
#   '우라늄',
#   '을',
#   '가장',
#   '많이',
#   '생산',
#   '하다',
#   '나라',
#   '카자흐스탄',
#   '이다',
#   '년',
#   '기준',
#   '으로',
#   '톤',
#   '전',
#   '세계',
#   '에서',
#   '약',
#   '우라늄',
#   '광석',
#   '을',
#   '채굴',
#   '하다',
#   '다른',
#   '중요',
#   '우라늄',
#   '채굴',
#   '도시',
#   '캐나다',
#   '호주',
#   '나미비아',
#   '러시아',
#   '그리고',
#   '니제르',
#   '가다',
#   '있다'],
#  ['넵투늄',
#   '중',
#   '반감기',
#   '가장',
#   '기다',
#   '지각',
#   '나이',
#   '와',
#   '비교',
#   '하다',
#   '무시',
#   '하다',
#   '되다',
#   '정도',
#   '로',
#   '짧다',
#   '그래서',
#   '넵투늄',
#   '주로',
#   '다른',
#   '동위',
#   '원소',
#   '붕괴',
#   '중간',
#   '생',
#   '성',
#   '물',
#   '로',
#   '만들어지다',
#   '그',
#   '양은',
#   '무시',
#   '하다',
#   '되다',
#   '정도',
#   '로',
#   '적다',
#   '년',
#   '에',
#   '우라늄',
#   '광물',
#   '에서',
#   '처음',
#   '으로',
#   '자연',
#   '적',
#   '인',
#   '플루토늄',
#   '을',
#   '찾아내다',
#   '합성',
#   '으로는',
#   '처음',
#   '발견',
#   '되어다',
#   '주기율표',
#   '에',
#   '요약',
#   '하다',
#   '등록',
#   '되어다',
#   '있다',
#   '플루토늄',
#   '다른',
#   '어떻다',
#   '동위',
#   '원소',
#   '도',
#   '표본',
#   '에서',
#   '가장',
#   '쉬다',
#   '채취',
#   '하다',
#   '없다',
#   '플루토늄',
#   '동위',
#   '원소',
#   '중',
#   '가장',
#   '오래',
#   '존재',
#   '하다',
#   '동위',
#   '원소',
#   '이다',
#   '확률',
#   '이다',
#   '플루토늄',
#   '달',
#   '표본',
#   '에서는',
#   '발견',
#   '되다',
#   '않다',
#   '때문',
#   '에',
#   '자연',
#   '에서는',
#   '많이',
#   '존재',
#   '하다',
#   '않다',
#   '대부분',
#   '플루토늄',
#   '주로',
#   '합성',
#   '으로',
#   '만들어지다'],
#  ['또다른',
#   '추출',
#   '방법',
#   '으로는',
#   '온도',
#   '일',
#   '때',
#   '농도',
#   '인',
#   '수산화나트륨',
#   '용액',
#   '에서',
#   '분해',
#   '되다',
#   '금속',
#   '산화물',
#   '먼저',
#   '추출',
#   '되다',
#   '에서',
#   '걸다',
#   '지다',
#   '물',
#   '에',
#   '씻기다',
#   '농축',
#   '되다',
#   '염산',
#   '에',
#   '담그다',
#   '용해',
#   '되다',
#   '다음',
#   '으로',
#   '산성',
#   '용액',
#   '산화물',
#   '과',
#   '만나다',
#   '중화',
#   '되다',
#   '결과물',
#   '수산화',
#   '토륨',
#   '침전',
#   '물이',
#   '다',
#   '물질',
#   '산화물',
#   '희토류',
#   '과',
#   '섞이다',
#   '있다',
#   '대부분',
#   '산화물',
#   '희토류',
#   '용액',
#   '에',
#   '남다',
#   '수산화',
#   '토륨',
#   '무기물',
#   '산',
#   '에',
#   '용해',
#   '되다',
#   '과정',
#   '에서',
#   '희토류',
#   '원소',
#   '와',
#   '분리',
#   '되다',
#   '효율',
#   '적',
#   '인',
#   '방법',
#   '수산화',
#   '토륨',
#   '을',
#   '질산',
#   '에',
#   '담그다',
#   '용해',
#   '시키다',
#   '방법',
#   '이다',
#   '왜냐하면',
#   '결과',
#   '로',
#   '나오다',
#   '수용액',
#   '유기',
#   '용제',
#   '와',
#   '추출',
#   '을',
#   '이용',
#   '하다',
#   '정제',
#   '하다',
#   '있다',
#   '때문',
#   '이다'],
#  ['여러',
#   '원소',
#   '를',
#   '포함',
#   '하고',
#   '있다',
#   '돌로마이트',
#   '나',
#   '마',
#   '그',
#   '네',
#   '사이트',
#   '우라늄',
#   '광석',
#   '일',
#   '경우',
#   '산성',
#   '물질',
#   '을',
#   '더',
#   '많이',
#   '필요',
#   '로',
#   '하다',
#   '경우',
#   '에는',
#   '탄산염',
#   '을',
#   '이용',
#   '방법',
#   '우라늄',
#   '추출',
#   '에',
#   '주로',
#   '쓰이다',
#   '방법',
#   '가장',
#   '중요하다',
#   '요소',
#   '탄산나트륨',
#   '수용액',
#   '인데',
#   '우라늄',
#   '을',
#   '복합',
#   '적',
#   '인',
#   '로',
#   '전환',
#   '시키다',
#   '수산화',
#   '이온',
#   '적다',
#   '수용액',
#   '중',
#   '안정',
#   '적',
#   '인',
#   '수용액',
#   '에',
#   '속',
#   '하다',
#   '탄산나트륨',
#   '을',
#   '이용',
#   '방법',
#   '장점',
#   '화합물',
#   '부식',
#   '성',
#   '낮다',
#   '질산염',
#   '과',
#   '비교',
#   '하다',
#   '때',
#   '가장',
#   '좋다',
#   '점',
#   '인',
#   '수용액',
#   '에서',
#   '우라늄',
#   '아니다',
#   '광석',
#   '을',
#   '침전',
#   '시키다',
#   '이다',
#   '단점',
#   '가의',
#   '우라늄',
#   '화합물',
#   '침전',
#   '자다',
#   '되다',
#   '이다',
#   '그러므로',
#   '우라늄',
#   '광석',
#   '높다',
#   '온도',
#   '와',
#   '낮다',
#   '산소',
#   '압력',
#   '일',
#   '때',
#   '에는',
#   '탄산나트륨',
#   '으로',
#   '처리',
#   '하다',
#   '효과',
#   '적',
#   '이다'],
#  ['악티늄족',
#   '전형',
#   '적',
#   '인',
#   '금속',
#   '이다',
#   '모든',
#   '광물',
#   '부드럽다',
#   '은빛',
#   '을',
#   '띄다',
#   '그러나',
#   '공기',
#   '중',
#   '에서는',
#   '변색',
#   '되다',
#   '각각',
#   '크다',
#   '밀도',
#   '와',
#   '가소성',
#   '존재',
#   '하다',
#   '일부',
#   '칼',
#   '로',
#   '자르다',
#   '수도',
#   '있다',
#   '비저항',
#   '에서',
#   '사이',
#   '이다',
#   '토륨',
#   '경도',
#   '마치',
#   '부드럽다',
#   '강철',
#   '과',
#   '비슷하다',
#   '강하다',
#   '가열',
#   '되다',
#   '순수하다',
#   '토륨',
#   '종이',
#   '처럼',
#   '굴릴',
#   '있다',
#   '철사',
#   '로',
#   '만들다',
#   '수도',
#   '있다',
#   '토륨',
#   '밀도',
#   '우라늄',
#   '과',
#   '플루토늄',
#   '절반',
#   '정도',
#   '되다',
#   '그러나',
#   '우라늄',
#   '과',
#   '플루토늄',
#   '보다',
#   '단단하다',
#   '모든',
#   '악티늄족',
#   '방사성',
#   '원소',
#   '이며',
#   '상자성',
#   '을',
#   '띄다',
#   '이례',
#   '적',
#   '인',
#   '경우',
#   '에는',
#   '여러',
#   '결정',
#   '질',
#   '상',
#   '을',
#   '가지',
#   '고',
#   '있다',
#   '플루토늄',
#   '개',
#   '그리고',
#   '우라늄',
#   '넵투늄',
#   '그리고',
#   '캘리포늄',
#   '개',
#   '이다',
#   '프로탁티늄',
#   '우라늄',
#   '넵투늄',
#   '그리고',
#   '플루토늄',
#   '결정',
#   '구조',
#   '란타넘족',
#   '과',
#   '비슷하다',
#   '깨끗하다',
#   '않다',
#   '상사형',
#   '이고',
#   '형태',
#   '를',
#   '가지',
#   '고',
#   '있다',
#   '전이',
#   '금속',
#   '과',
#   '비슷하다'],
#  ['프로트악티늄',
#   '이상',
#   '성질',
#   '을',
#   '보이다',
#   '화합물',
#   '가장',
#   '안정',
#   '적',
#   '이며',
#   '프로트악티늄',
#   '화합물',
#   '쉬다',
#   '산화',
#   '되다',
#   '그러므로',
#   '용액',
#   '에서의',
#   '프로트악티늄',
#   '수소',
#   '대기',
#   '에서',
#   '강하다',
#   '환원제',
#   '에',
#   '의하다',
#   '얻다',
#   '있다',
#   '프로트악티늄',
#   '화학',
#   '적',
#   '으로',
#   '우라늄',
#   '과',
#   '토륨',
#   '과',
#   '비슷하다',
#   '성질',
#   '을',
#   '가지다',
#   '프로트악티늄',
#   '플루',
#   '오',
#   '린산염',
#   '인산염',
#   '차',
#   '인산염',
#   '아이오딘산',
#   '염',
#   '그리고',
#   '페닐',
#   '아르',
#   '손산염',
#   '불',
#   '용성',
#   '이고',
#   '산',
#   '을',
#   '중화',
#   '시키다',
#   '프로트악티늄',
#   '가용성',
#   '있다',
#   '탄산염',
#   '형태',
#   '로',
#   '변하다',
#   '성질',
#   '을',
#   '가지',
#   '고',
#   '있다',
#   '프로트악티늄',
#   '가수분해',
#   '성',
#   '성질',
#   '탄탈럼',
#   '과',
#   '나이오븀',
#   '과',
#   '비슷하다',
#   '프로트악티늄',
#   '복합',
#   '적',
#   '성질',
#   '프로트악티늄',
#   '껍질',
#   '을',
#   '채우다',
#   '결과',
#   '나오다'],
#  ['우라늄',
#   '에서',
#   '까지의',
#   '성질',
#   '을',
#   '보이다',
#   '중',
#   '에서는',
#   '제일',
#   '안정',
#   '하다',
#   '상태',
#   '에서',
#   '우라늄',
#   '족',
#   '원소',
#   '와',
#   '비슷하다',
#   '성질',
#   '을',
#   '가지다',
#   '많다',
#   '양',
#   '우라늄',
#   '과',
#   '우라늄',
#   '화합물',
#   '비화',
#   '학적',
#   '화합물',
#   '이다',
#   '특징',
#   '중',
#   '하나',
#   '다양하다',
#   '구조',
#   '를',
#   '가지',
#   '고',
#   '있다',
#   '예시',
#   '로',
#   '사실',
#   '상',
#   '으로',
#   '이산화우라늄',
#   '화학식',
#   '이다',
#   '상황',
#   '에',
#   '따르다',
#   '가다',
#   '오다',
#   '로',
#   '달라지다',
#   '우라늄',
#   '화합물',
#   '약하다',
#   '산화제',
#   '반응',
#   '을',
#   '가지다',
#   '대부분',
#   '화합물',
#   '선형',
#   '우라닐족',
#   '을',
#   '포함',
#   '하고',
#   '있다',
#   '에서',
#   '사이',
#   '리간드',
#   '우라닐족',
#   '을',
#   '수직',
#   '적다',
#   '수용',
#   '하다',
#   '있다',
#   '우라닐족',
#   '산소',
#   '전자',
#   '개',
#   '와',
#   '질소',
#   '전자',
#   '개',
#   '와',
#   '함께',
#   '굳다',
#   '산',
#   '역할',
#   '을',
#   '하다',
#   '강하다',
#   '복합',
#   '적',
#   '인',
#   '모습',
#   '을',
#   '하다',
#   '과',
#   '역시',
#   '넵투늄',
#   '과',
#   '플루토늄',
#   '상태',
#   '이다',
#   '우라늄',
#   '화합물',
#   '환원',
#   '적',
#   '인',
#   '성질',
#   '을',
#   '보이',
#   '며',
#   '특징',
#   '중',
#   '하나',
#   '대기',
#   '중',
#   '산소',
#   '에',
#   '의하다',
#   '자다',
#   '산화',
#   '되다',
#   '이다',
#   '우라늄',
#   '매우',
#   '강하다',
#   '환원',
#   '물이',
#   '다',
#   '그래서',
#   '껍질',
#   '로',
#   '존재',
#   '하고',
#   '우라늄',
#   '또한',
#   '많다',
#   '악티늄족',
#   '유기',
#   '금속',
#   '화합물',
#   '이다',
#   '대표',
#   '적',
#   '으로',
#   '과',
#   '존재',
#   '하다'],
#  ['악티늄족',
#   '염',
#   '과',
#   '할로겐',
#   '과',
#   '크다',
#   '반응',
#   '을',
#   '일으키다',
#   '공식',
#   '과',
#   '할로겐',
#   '이다',
#   '첫',
#   '버클륨',
#   '화합물',
#   '이다',
#   '물질',
#   '년',
#   '에',
#   '나노',
#   '그램',
#   '정도',
#   '합성',
#   '되어다',
#   '희토류',
#   '원소',
#   '할로겐',
#   '화합물',
#   '같다',
#   '으로는',
#   '악티늄족',
#   '염화물',
#   '브로민화물',
#   '그리고',
#   '아이오딘화물',
#   '수용성',
#   '이고',
#   '플루오린화물',
#   '비수',
#   '용성',
#   '이다',
#   '우라늄',
#   '주로',
#   '육',
#   '플루오린',
#   '화',
#   '를',
#   '하다',
#   '가다',
#   '되다',
#   '승화',
#   '를',
#   '하다',
#   '물질',
#   '휘발',
#   '성은',
#   '기체',
#   '원심',
#   '분',
#   '리기',
#   '또는',
#   '가스',
#   '확산',
#   '법',
#   '으로',
#   '우라늄',
#   '동위원소',
#   '로',
#   '분리',
#   '하다',
#   '있다',
#   '육',
#   '플루오린',
#   '화',
#   '악티늄족',
#   '무수',
#   '물의',
#   '성질',
#   '을',
#   '가지',
#   '고',
#   '있다',
#   '그것',
#   '수분',
#   '에',
#   '매우',
#   '민감하다',
#   '가수분해',
#   '를',
#   '하다',
#   '오염',
#   '화',
#   '우라늄',
#   '과',
#   '흑색',
#   '육',
#   '염화',
#   '우라늄',
#   '인공',
#   '합성',
#   '하다',
#   '둘',
#   '다',
#   '불안정하다'],
#  ['악티늄족',
#   '염',
#   '산화물',
#   '을',
#   '산',
#   '으로',
#   '용해',
#   '하다',
#   '과정',
#   '에서도',
#   '얻다',
#   '있다',
#   '악티늄족',
#   '질산염',
#   '염화물',
#   '황산염',
#   '그리고',
#   '과염소산염',
#   '가용성',
#   '있다',
#   '수용액',
#   '에서',
#   '결정',
#   '을',
#   '만들다',
#   '때',
#   '악티늄족',
#   '염',
#   '수소화물',
#   '형태',
#   '를',
#   '하다',
#   '그리고',
#   '높다',
#   '원',
#   '자가',
#   '를',
#   '지니다',
#   '악티늄족',
#   '염',
#   '쉬다',
#   '가수분해',
#   '되다',
#   '그래서',
#   '토륨',
#   '무색',
#   '황산염',
#   '염화물',
#   '과염소산염',
#   '그리고',
#   '질산염',
#   '화학식',
#   '을',
#   '가지다',
#   '염기성',
#   '염',
#   '으로',
#   '형태',
#   '를',
#   '바꾸다',
#   '악티늄족',
#   '오다',
#   '가용성',
#   '과',
#   '불다',
#   '성은',
#   '란타넘족',
#   '염',
#   '과',
#   '비슷하다',
#   '그래서',
#   '악티늄족',
#   '인산염',
#   '플루오린',
#   '화염',
#   '옥살산',
#   '염',
#   '아인',
#   '오딘',
#   '화염',
#   '그리고',
#   '탄산염',
#   '물',
#   '에',
#   '약하다',
#   '가용성',
#   '을',
#   '가지다',
#   '악티늄족',
#   '염',
#   '수소화물',
#   '같다',
#   '침전',
#   '물이',
#   '생기다',
#   '그리고'],
#  ['양이온',
#   '을',
#   '제외',
#   '하다',
#   '산화',
#   '상태',
#   '인',
#   '악티늄족',
#   '오다',
#   '그리고',
#   '다른',
#   '복합',
#   '적',
#   '음이온',
#   '형태',
#   '를',
#   '하다',
#   '예시',
#   '적',
#   '으로',
#   '우라늄',
#   '넵투늄',
#   '그리고',
#   '플루토늄',
#   '우라늄',
#   '산염',
#   '그리고',
#   '중',
#   '우라늄',
#   '산염',
#   '종류',
#   '형태',
#   '염',
#   '을',
#   '가지다',
#   '란타넘족',
#   '과',
#   '비교',
#   '하다',
#   '악티늄족',
#   '더',
#   '쉬다',
#   '배위',
#   '화합물',
#   '형태',
#   '를',
#   '가지',
#   '고',
#   '능력',
#   '악티늄족',
#   '원',
#   '자가',
#   '를',
#   '늘리다',
#   '악티늄족',
#   '플루오린',
#   '화',
#   '배위',
#   '화합물',
#   '형태',
#   '를',
#   '가지',
#   '지',
#   '않다',
#   '반면',
#   '토륨',
#   '복잡하다',
#   '그리고',
#   '형태',
#   '를',
#   '하다',
#   '또한',
#   '토륨',
#   '황산염',
#   '과',
#   '예시',
#   '로',
#   '질산염',
#   '그리고',
#   '티오시안산',
#   '염',
#   '형태',
#   '도',
#   '가지다',
#   '토륨',
#   '배위수',
#   '일',
#   '때',
#   '일반',
#   '적',
#   '인',
#   '화학식',
#   '인',
#   '염',
#   '배위',
#   '화합물',
#   '로',
#   '존재',
#   '하다',
#   '악티늄족',
#   '오다',
#   '복합',
#   '적',
#   '화합물',
#   '염',
#   '보다',
#   '더욱',
#   '생산',
#   '하다',
#   '쉬다',
#   '악티늄족',
#   '에서',
#   '가장',
#   '안정',
#   '배위',
#   '화합물',
#   '반응',
#   '로',
#   '에서',
#   '디케',
#   '톤',
#   '과',
#   '반응',
#   '하다',
#   '만들어지다',
#   '토륨',
#   '오다',
#   '우라늄',
#   '이다',
#   '또한',
#   '알다',
#   '틸',
#   '아세톤',
#   '과도',
#   '합성',
#   '하다',
#   '생산',
#   '가능하다'],
#  ['플루토늄',
#   '대표',
#   '적',
#   '으로',
#   '핵',
#   '무기',
#   '에',
#   '쓰이다',
#   '플루토늄',
#   '동위',
#   '원소',
#   '핵분열',
# ...
#   '안도',
#   '히로시',
#   '게',
#   '등장',
#   '하다',
#   '우',
#   '키요',
#   '에의',
#   '최',
#   '전성기',
#   '를',
#   '맞다',
#   '우',
#   '키요',
#   '에의',
#   '화법',
#   '서양',
#   '으로',
#   '알려지다',
#   '고흐',
#   '후기',
#   '인상주의',
#   '화가',
#   '에게',
#   '영향',
#   '을',
#   '주기도',
#   '하다'],
#  ['일본',
#   '예능',
#   '공연',
#   '오랜',
#   '역사',
#   '를',
#   '지니다',
#   '무악',
#   '을',
#   '비롯',
#   '하다',
#   '노',
#   '교겐',
#   '인형극',
#   '가부키',
#   '각종',
#   '민속',
#   '예능',
#   '이른바',
#   '전통',
#   '예능',
#   '과',
#   '신파',
#   '오페라',
#   '발레',
#   '대중',
#   '연극',
#   '같다',
#   '현대',
#   '연극',
#   '다양하다',
#   '종류',
#   '있다',
#   '일본',
#   '연극',
#   '오랜',
#   '역사',
#   '속',
#   '에서',
#   '한국',
#   '중국',
#   '주변',
#   '여러',
#   '나라',
#   '로부터',
#   '크게',
#   '영향',
#   '을',
#   '받다',
#   '혼합',
#   '발달',
#   '하다',
#   '온',
#   '것이므',
#   '로',
#   '순',
#   '일본',
#   '적',
#   '인',
#   '요소',
#   '와',
#   '외래',
#   '적',
#   '인',
#   '요소',
#   '를',
#   '구별',
#   '하다',
#   '매우',
#   '어렵다',
#   '무로마치',
#   '시대',
#   '에',
#   '간',
#   '아미',
#   '와',
#   '제아미',
#   '부자',
#   '에',
#   '의하다',
#   '노',
#   '발전',
#   '하다',
#   '고전',
#   '무대',
#   '예술인',
#   '가부키',
#   '경우',
#   '에는',
#   '세기',
#   '에',
#   '등장',
#   '하다',
#   '현대',
#   '에는',
#   '여러',
#   '상설',
#   '극장',
#   '세워지다',
#   '인기',
#   '를',
#   '끌',
#   '고',
#   '있다',
#   '메이지',
#   '시대',
#   '이후',
#   '에는',
#   '서',
#   '양식',
#   '연극',
#   '도입',
#   '되어다',
#   '이외',
#   '에',
#   '라쿠고',
#   '나',
#   '고단',
#   '과',
#   '같다',
#   '대중',
#   '을',
#   '대상',
#   '으로',
#   '하다',
#   '만담',
#   '문화',
#   '도',
#   '유명하다'],
#  ['일본',
#   '만화',
#   '망',
#   '일본어',
#   '만가',
#   '로',
#   '불리',
#   '며',
#   '현대',
#   '일본',
#   '미술',
#   '과',
#   '긴밀하다',
#   '영향',
#   '을',
#   '주다',
#   '받다',
#   '발전',
#   '하다',
#   '그리고',
#   '일본',
#   '만화',
#   '영향',
#   '을',
#   '크게',
#   '받다',
#   '만화',
#   '작품',
#   '을',
#   '원작',
#   '으로',
#   '해',
#   '애니메이션',
#   '으로',
#   '재다',
#   '성하다',
#   '일본',
#   '애니메이션',
#   '즉',
#   '아니메',
#   '미야자키',
#   '하얗다',
#   '영화',
#   '포켓몬스터',
#   '크다',
#   '인기',
#   '를',
#   '끌다',
#   '동시',
#   '에',
#   '망',
#   '오다',
#   '더불다',
#   '일본',
#   '애니메이션',
#   '강국',
#   '이라는',
#   '세계',
#   '적',
#   '인',
#   '명성',
#   '을',
#   '구가',
#   '하다',
#   '만들다',
#   '있다',
#   '일본',
#   '에서',
#   '제작',
#   '되다',
#   '애니메이션',
#   '전',
#   '세계',
#   '텔레비전',
#   '방송국',
#   '에서',
#   '편성',
#   '되다',
#   '비율',
#   '년',
#   '기준',
#   '약',
#   '일본',
#   '경제산업성',
#   '이며',
#   '대한민국',
#   '에서도',
#   '각종',
#   '케이블',
#   '방송국',
#   '만화',
#   '편성',
#   '주요',
#   '시간대',
#   '를',
#   '차지',
#   '하고',
#   '있다',
#   '국제',
#   '적',
#   '으로',
#   '위상',
#   '을',
#   '굳히다',
#   '오다',
#   '하지만',
#   '최근',
#   '만화',
#   '분야',
#   '검열',
#   '논란',
#   '으로',
#   '그',
#   '세',
#   '약해지다',
#   '있다',
#   '망',
#   '오다',
#   '애니메이션',
#   '수년',
#   '간',
#   '모에',
#   '각종',
#   '문화',
#   '적',
#   '요소',
#   '파생',
#   '라이트',
#   '노벨',
#   '발달',
#   '을',
#   '통해',
#   '여전하다',
#   '두텁다',
#   '오타쿠',
#   '계층',
#   '지지',
#   '를',
#   '받다',
#   '있다',
#   '이렇게',
#   '특정',
#   '분야',
#   '에',
#   '심취',
#   '사람',
#   '을',
#   '지칭',
#   '하다',
#   '오타쿠',
#   '일본',
#   '에서',
#   '사회',
#   '문화',
#   '하다',
#   '축',
#   '으로',
#   '자리',
#   '잡다',
#   '뿐',
#   '만',
#   '아니다',
#   '대한민국',
#   '을',
#   '비롯',
#   '하다',
#   '국제',
#   '적',
#   '으로',
#   '그',
#   '범위',
#   '를',
#   '넓히다',
#   '있다',
#   '비판',
#   '활동',
#   '을',
#   '통해',
#   '문화',
#   '질적',
#   '재생산',
#   '이루어지다',
#   '경우',
#   '도',
#   '많다',
#   '히키코모리',
#   '은둔',
#   '형',
#   '외톨이',
#   '자살',
#   '인터넷',
#   '중독',
#   '성범죄',
#   '폐쇄성',
#   '을',
#   '비롯',
#   '정신',
#   '문제',
#   '을',
#   '비롯',
#   '각종',
#   '개인',
#   '적',
#   '사회',
#   '적',
#   '문제',
#   '야기',
#   '되다',
#   '기도',
#   '하다'],
#  ['축구',
#   '년',
#   '리그',
#   '창설',
#   '되다',
#   '이후',
#   '번성',
#   '하고',
#   '있다',
#   '일본',
#   '대표',
#   '적',
#   '인',
#   '자동차',
#   '기업인',
#   '토요타',
#   '년',
#   '에',
#   '창설',
#   '되어다',
#   '년',
#   '에',
#   '폐지',
#   '되다',
#   '인터콘티넨털컵',
#   '대표',
#   '적',
#   '인',
#   '스폰서',
#   '이다',
#   '일본',
#   '아시아',
#   '에서',
#   '높다',
#   '수준',
#   '축구',
#   '클럽',
#   '을',
#   '보유',
#   '나라',
#   '중',
#   '하나로',
#   '아시안컵',
#   '에서',
#   '차례',
#   '년',
#   '년',
#   '년',
#   '년',
#   '나',
#   '우승하다',
#   '전적',
#   '있다',
#   '년',
#   '에는',
#   '대한민국',
#   '과',
#   '월드컵',
#   '을',
#   '공동',
#   '개최',
#   '하다',
#   '일본',
#   '축구',
#   '대표팀',
#   '년',
#   '프랑스',
#   '월드컵',
#   '에',
#   '처음',
#   '출전',
#   '이후',
#   '회',
#   '연속',
#   '년',
#   '프랑스',
#   '월드컵',
#   '년',
#   '한일',
#   '월드컵',
#   '년',
#   '독일',
#   '월드컵',
#   '년',
#   '남아프리카',
#   '공화국',
#   '월드컵',
#   '으로',
#   '월드컵',
#   '본선',
#   '에',
#   '출전',
#   '하다',
#   '년',
#   '한일',
#   '월드컵',
#   '과',
#   '년',
#   '남아프리카',
#   '공화국',
#   '월드컵',
#   '에서',
#   '강',
#   '에',
#   '출전',
#   '하다',
#   '기록',
#   '현재',
#   '까지',
#   '일본',
#   '월드컵',
#   '최고',
#   '성적',
#   '으로',
#   '기록',
#   '되어다',
#   '있다',
#   '여자',
#   '축구',
#   '또한',
#   '일본',
#   '에서',
#   '인기',
#   '높다',
#   '여자',
#   '축구',
#   '대표팀',
#   '나다',
#   '코',
#   '재팬',
#   '이라는',
#   '애칭',
#   '으로',
#   '부르다',
#   '기도',
#   '하다',
#   '일본',
#   '여자',
#   '축구',
#   '국가대표팀',
#   '년',
#   '독일',
#   '여자',
#   '월드컵',
#   '결승전',
#   '에서',
#   '미국',
#   '을',
#   '누르다',
#   '사상',
#   '첫',
#   '여자',
#   '월드컵',
#   '우승',
#   '을',
#   '차지',
#   '하다'],
#  ['현재',
#   '에',
#   '전해지다',
#   '일본',
#   '전통',
#   '요리',
#   '발달',
#   '에도',
#   '시대',
#   '로',
#   '일본',
#   '전통',
#   '요리',
#   '로는',
#   '연회',
#   '용',
#   '정찬',
#   '인',
#   '가이세키',
#   '요리',
#   '와',
#   '혼젠',
#   '요리',
#   '있다',
#   '가이세키',
#   '요리',
#   '경우',
#   '우선',
#   '국',
#   '생선회',
#   '찜',
#   '구이',
#   '먼저',
#   '나오다',
#   '후',
#   '마지막',
#   '에',
#   '밥',
#   '과',
#   '쓰케모노',
#   '나오다',
#   '식단',
#   '에',
#   '따르다',
#   '첩',
#   '첩',
#   '첩',
#   '반상',
#   '되다',
#   '또',
#   '한국',
#   '이나',
#   '중국',
#   '처럼',
#   '젓가락',
#   '을',
#   '사용',
#   '지만',
#   '젓가락',
#   '다른',
#   '나라',
#   '에',
#   '비다',
#   '짧다',
#   '때문',
#   '에',
#   '밥',
#   '이나',
#   '국',
#   '같다',
#   '경우',
#   '에는',
#   '입',
#   '에',
#   '대고',
#   '먹다',
#   '말다',
#   '현대',
#   '요리',
#   '로는',
#   '여러',
#   '인스턴트',
#   '식품',
#   '일본',
#   '에서',
#   '발명',
#   '되어다',
#   '년',
#   '닛신',
#   '식품',
#   '최초',
#   '로',
#   '인스턴트',
#   '치킨',
#   '라면',
#   '을',
#   '발매',
#   '이후',
#   '년',
#   '에는',
#   '컵라면',
#   '등장',
#   '하다',
#   '대한민국',
#   '에까지',
#   '알려지다',
#   '인스턴트',
#   '식품',
#   '인기',
#   '폭발',
#   '이후',
#   '에는',
#   '냉장고',
#   '에',
#   '보관',
#   '하다',
#   '냉동',
#   '식품',
#   '인기',
#   '를',
#   '끌다',
#   '제',
#   '차',
#   '세계',
#   '대전',
#   '이전',
#   '부터',
#   '존재',
#   '하다',
#   '캔',
#   '을',
#   '플라스틱',
#   '포장',
#   '으로',
#   '바꾸다',
#   '레트',
#   '로트',
#   '식품',
#   '도',
#   '발명',
#   '되어다',
#   '이처럼',
#   '현대',
#   '일본',
#   '요리',
#   '간편하다',
#   '요리',
#   '하다',
#   '있다',
#   '간이',
#   '식품',
#   '을',
#   '중심',
#   '으로',
#   '성장하다',
#   '유명하다',
#   '요리',
#   '로는',
#   '스시',
#   '전통',
#   '술',
#   '인',
#   '사케',
#   '라멘',
#   '있다'],
#  ['일본',
#   '에서',
#   '축제',
#   '를',
#   '칭할',
#   '때',
#   '사용',
#   '하다',
#   '말',
#   '인',
#   '마쓰리',
#   '일본어',
#   '늘다',
#   '신',
#   '을',
#   '맞이',
#   '하다',
#   '종교',
#   '적',
#   '인',
#   '행사',
#   '로서',
#   '농경',
#   '사회',
#   '에서',
#   '풍요',
#   '로운',
#   '생산',
#   '을',
#   '기원',
#   '에서',
#   '유래',
#   '하다',
#   '지방',
#   '분권',
#   '전통',
#   '강하다',
#   '일본',
#   '에서',
#   '마쓰리',
#   '지역',
#   '주민',
#   '결속',
#   '을',
#   '강화하다',
#   '위',
#   '수단',
#   '이다',
#   '현대',
#   '로',
#   '접다',
#   '들다',
#   '농촌',
#   '지역',
#   '홍보',
#   '와',
#   '생산품',
#   '판촉',
#   '수단',
#   '으로도',
#   '활용',
#   '되다',
#   '있다',
#   '특히',
#   '년대',
#   '이후',
#   '일본',
#   '농촌',
#   '각지',
#   '에서',
#   '일어나다',
#   '무',
#   '라오',
#   '코시',
#   '운동',
#   '과정',
#   '에서',
#   '지역',
#   '특유',
#   '마쓰리',
#   '도농',
#   '교류',
#   '나',
#   '마을',
#   '홍보',
#   '및',
#   '생산품',
#   '판매촉진',
#   '에',
#   '효과',
#   '적',
#   '이라는',
#   '인식',
#   '확산',
#   '되다',
#   '마쓰리',
#   '부흥',
#   '계기',
#   '를',
#   '제공',
#   '하다',
#   '현재',
#   '마을',
#   '에',
#   '기념',
#   '거나',
#   '축하',
#   '하다',
#   '일이',
#   '있다',
#   '때',
#   '모두',
#   '모이다',
#   '진행',
#   '하다',
#   '행사',
#   '로',
#   '바뀌다',
#   '마을',
#   '친목',
#   '도모',
#   '나',
#   '지역',
#   '페스티벌',
#   '로',
#   '자리',
#   '잡다',
#   '되어다'],
#  ['법정',
#   '공휴일',
#   '개',
#   '와',
#   '연휴',
#   '토요일',
#   '및',
#   '일요일',
#   '을',
#   '합치다',
#   '일본',
#   '휴일',
#   '년',
#   '기준',
#   '일이',
#   '다',
#   '중',
#   '신년',
#   '연휴',
#   '와',
#   '월',
#   '말',
#   '에서',
#   '월',
#   '초',
#   '까지',
#   '이어지다',
#   '골든',
#   '위',
#   '크다',
#   '시기',
#   '에는',
#   '증권',
#   '거래소',
#   '휴장',
#   '하다',
#   '하다',
#   '또',
#   '법정',
#   '공휴일',
#   '과',
#   '일요일',
#   '겹',
#   '치다',
#   '경우',
#   '를',
#   '대비',
#   '하다',
#   '대체',
#   '휴일',
#   '제도',
#   '를',
#   '도입',
#   '하고',
#   '있다',
#   '최근',
#   '에는',
#   '기업',
#   '에서',
#   '골든',
#   '위',
#   '크다',
#   '전후',
#   '며칠',
#   '을',
#   '추가',
#   '로',
#   '쉬다',
#   '하다',
#   '있다',
#   '골든',
#   '위',
#   '크다',
#   '이외',
#   '에',
#   '월',
#   '중순',
#   '실버',
#   '위',
#   '크다',
#   '각광',
#   '받다',
#   '있다',
#   '이러하다',
#   '골든',
#   '위',
#   '크다',
#   '연휴',
#   '주로',
#   '장거리',
#   '휴가',
#   '나',
#   '관광',
#   '을',
#   '위해',
#   '사용',
#   '하다',
#   '경우',
#   '많다',
#   '일본',
#   '국내외',
#   '각종',
#   '기업',
#   '관광객',
#   '유치',
#   '를',
#   '도모',
#   '하고',
#   '있다',
#   '한편',
#   '일본',
#   '정부',
#   '불황',
#   '타개',
#   '를',
#   '위',
#   '수단',
#   '으로서',
#   '휴일',
#   '을',
#   '지속',
#   '적',
#   '으로',
#   '늘리다',
#   '있다',
#   '월',
#   '과',
#   '월',
#   '에',
#   '지역별',
#   '로',
#   '연휴',
#   '를',
#   '분할',
#   '하다',
#   '제도',
#   '도',
#   '추진',
#   '하고',
#   '있다'],
#  ['시민',
#   '교육',
#   '인류',
#   '사회',
#   '를',
#   '형성',
#   '하다',
#   '시작',
#   '되어다',
#   '여러',
#   '사회과학',
#   '학문',
#   '을',
#   '통합',
#   '하다',
#   '사회',
#   '과로',
#   '등장',
#   '세기',
#   '초반',
#   '미국',
#   '사회',
#   '이다',
#   '당시',
#   '미국',
#   '이민자',
#   '를',
#   '미국',
#   '화',
#   '하고',
#   '미국',
#   '남부',
#   '에서',
#   '북부',
#   '로',
#   '이주',
#   '주민',
#   '도시',
#   '에',
#   '적응하다',
#   '교육',
#   '을',
#   '실시',
#   '하다',
#   '필요성',
#   '대두',
#   '되어다',
#   '이러하다',
#   '사회',
#   '적',
#   '요구',
#   '지식',
#   '전달',
#   '중심',
#   '전통',
#   '적',
#   '교육',
#   '에',
#   '대한',
#   '개혁',
#   '을',
#   '요구',
#   '하다',
#   '형태',
#   '로',
#   '나타나다',
#   '요구',
#   '에',
#   '부응',
#   '하다',
#   '년',
#   '전',
#   '밉다',
#   '교육',
#   '협회',
#   '에서',
#   '인',
#   '위원회',
#   '를',
#   '조직',
#   '하다',
#   '직업',
#   '생활',
#   '과',
#   '시민',
#   '교육',
#   '을',
#   '포함',
#   '교육과정',
#   '을',
#   '제시',
#   '하다',
#   '여전하다',
#   '지식',
#   '전달',
#   '중심',
#   '전통',
#   '적',
#   '교육',
#   '을',
#   '벗어나다',
#   '못',
#   '하다',
#   '이러하다',
#   '점',
#   '을',
#   '개선',
#   '하다',
#   '위해',
#   '전',
#   '밉다',
#   '교육',
#   '협회',
#   '인',
#   '위원회',
#   '를',
#   '조직',
#   '하다',
#   '전통',
#   '적',
#   '인',
#   '역사교육',
#   '에서',
#   '벗어나다',
#   '과학',
#   '적',
#   '인',
#   '프로그램',
#   '을',
#   '제시',
#   '하다',
#   '또한',
#   '시민',
#   '교육',
#   '이상',
#   '에',
#   '미치다',
#   '못',
#   '하다',
#   '에',
#   '전',
#   '밉다',
#   '교육',
#   '협회',
#   '에서',
#   '사회',
#   '과',
#   '위원회',
#   '등장',
#   '하다',
#   '년',
#   '에',
#   '중등교육',
#   '사회',
#   '과',
#   '보고서',
#   '를',
#   '통',
#   '하다',
#   '사회',
#   '과',
#   '라는',
#   '교과',
#   '를',
#   '창설',
#   '하다',
#   '을',
#   '주장',
#   '하다'],
#  ['위키',
#   '백',
#   '과',
#   '이전',
#   '에도',
#   '온라인',
#   '백과사전',
#   '을',
#   '운영',
#   '하다',
#   '여러',
#   '시도',
#   '있다',
#   '성공하다',
#   '못',
#   '하다',
#   '위키',
#   '백',
#   '과',
#   '영어',
#   '판',
#   '전문가',
#   '작성',
#   '하다',
#   '백과사전',
#   '인',
#   '누피디아',
#   '지',
#   '금은',
#   '없어지다',
#   '비롯',
#   '하다',
#   '누피디아',
#   '웹',
#   '포털',
#   '회사',
#   '인',
#   '미스',
#   '년',
#   '월',
#   '일',
#   '개시',
#   '하다',
#   '미스',
#   '이다',
#   '지미',
#   '웨일스',
#   '와',
#   '편집장',
#   '래',
#   '리',
#   '생어',
#   '누피디아',
#   '글',
#   '을',
#   '오픈',
#   '콘텐츠',
#   '로',
#   '제시',
#   '하다',
#   '하다',
#   '리처드',
#   '스톨',
#   '멀다',
#   '주도하다',
#   '자유',
#   '문서',
#   '라이선스',
#   '로',
#   '제공',
#   '하다',
#   '누피디아',
#   '알다',
#   '그리다',
#   '성공',
#   '적',
#   '이지',
#   '않다',
#   '지미',
#   '웨일스',
#   '와',
#   '래',
#   '리',
#   '생어',
#   '누구',
#   '나',
#   '참여',
#   '하다',
#   '있다',
#   '백과사전',
#   '으로',
#   '위키',
#   '백',
#   '과를',
#   '개설',
#   '하다',
#   '생어',
#   '모두',
#   '백과사전',
#   '이라는',
#   '목표',
#   '를',
#   '분명하다',
#   '하다',
#   '위해',
#   '이름',
#   '에',
#   '위키',
#   '를',
#   '넣다',
#   '년',
#   '월',
#   '일',
#   '생어',
#   '누피디어',
#   '메일',
#   '링',
#   '리스트',
#   '를',
#   '통해',
#   '누피디어',
#   '프로젝트',
#   '를',
#   '보완',
#   '하다',
#   '위해',
#   '위키',
#   '를',
#   '도입',
#   '하다',
#   '밝히다'],
#  ['년',
#   '월',
#   '스페인',
#   '마드리드',
#   '후안',
#   '카를로스',
#   '국왕',
#   '대학교',
#   '연구자',
#   '년',
#   '분기',
#   '동안',
#   '영어',
#   '위키',
#   '백',
#   '과',
#   '여명',
#   '기',
#   '여자',
#   '를',
#   '잃다',
#   '분석',
#   '을',
#   '내놓다',
#   '년',
#   '같다',
#   '기간',
#   '에',
#   '줄어들다',
#   '기',
#   '여자',
#   '수가',
#   '여명',
#   '이다',
#   '에',
#   '비다',
#   '열',
#   '배',
#   '나',
#   '더',
#   '많다',
#   '수치',
#   '이다',
#   '월스트리트',
#   '저',
#   '널',
#   '까다롭다',
#   '편집',
#   '지침',
#   '증가',
#   '이러하다',
#   '경향',
#   '을',
#   '이끌다',
#   '보도',
#   '하다',
#   '지미',
#   '웨일스',
#   '이러하다',
#   '연구',
#   '잘',
#   '못',
#   '되다',
#   '방법론',
#   '에',
#   '의하다',
#   '라며',
#   '분석',
#   '결과',
#   '를',
#   '거부',
#   '하다',
#   '년',
#   '뒤',
#   '인',
#   '년',
#   '지미',
#   '웨일스',
#   '하다',
#   '인터뷰',
#   '에서',
#   '기',
#   '여자',
#   '감소',
#   '를',
#   '인정',
#   '하다',
#   '년',
#   '월',
#   '최소',
#   '명의',
#   '편집자',
#   '에서',
#   '년',
#   '월',
#   '당시',
#   '명의',
#   '편집자',
#   '사이',
#   '격차',
#   '그리다',
#   '크다',
#   '않다',
#   '주장',
#   '하다',
#   '위키',
#   '백',
#   '과',
#   '편집자',
#   '안정',
#   '적',
#   '이고',
#   '지속',
#   '적',
#   '이라고',
#   '말',
#   '하다',
#   '년',
#   '매사추세츠',
#   '공과대학',
#   '교의',
#   '테크놀로지',
#   '리뷰',
#   '에',
#   '실리다',
#   '위키',
#   '백',
#   '과의',
#   '하락',
#   '지미',
#   '웨일스',
#   '이러하다',
#   '주장',
#   '을',
#   '반박',
#   '하고',
#   '있다',
#   '글',
#   '분석',
#   '에',
#   '따르다',
#   '위키',
#   '백',
#   '과는',
#   '년',
#   '이후',
#   '위키',
#   '백',
#   '과',
#   '문서',
#   '를',
#   '업데이트',
#   '하고',
#   '교정',
#   '하다',
#   '자원',
#   '편집자',
#   '가운데',
#   '분',
#   '을',
#   '잃다',
#   '편집자',
#   '상당수',
#   '사소하다',
#   '편집',
#   '만을',
#   '하다',
#   '으로',
#   '나타나다',
#   '애틀랜틱',
#   '년',
#   '월호',
#   '관리자',
#   '역시',
#   '줄어들다',
#   '보도',
#   '하다',
#   '년',
#   '월',
#   '일',
#   '뉴욕',
#   '캐서린',
#   '워드',
#   '여섯',
#   '번',
#   '째',
#   '로',
#   '많이',
#   '사용',
#   '되다',
#   '웹',
#   '싸이트',
#   '인',
#   '위키',
#   '백',
#   '과',
#   '내부',
#   '비판',
#   '에',
#   '휩싸이다',
#   '기사',
#   '를',
#   '내보내다'],
#  ['년',
#   '월',
#   '일',
#   '보드',
#   '바르다',
#   '늘다',
#   '이코노믹',
#   '타임즈',
#   '에',
#   '투고',
#   '글',
#   '을',
#   '통해',
#   '위키',
#   '백',
#   '과',
#   '년',
#   '월',
#   '에서',
#   '년',
#   '월',
#   '사이',
#   '에',
#   '전체',
#   '적',
#   '으로',
#   '페이지',
#   '뷰',
#   '퍼센트',
#   '에',
#   '달',
#   '하다',
#   '억',
#   '번',
#   '이상',
#   '페이지뷰',
#   '를',
#   '잃다',
#   '발표',
#   '하다',
#   '주요',
#   '언어',
#   '판',
#   '에',
#   '따르다',
#   '나누다',
#   '영어',
#   '위키',
#   '백',
#   '과의',
#   '페이지뷰',
#   '감소',
#   '율',
#   '독일어',
#   '일본어',
#   '이다',
#   '바르다',
#   '마는',
#   '만일',
#   '위키',
#   '백',
#   '과',
#   '운영자',
#   '통계',
#   '집계',
#   '에',
#   '오류',
#   '있다',
#   '주장',
#   '다',
#   '면',
#   '지난해',
#   '도입',
#   '되다',
#   '구글',
#   '지식',
#   '그래프',
#   '그',
#   '입',
#   '을',
#   '다물다',
#   '하다',
#   '이라고',
#   '덧붙이다',
#   '뉴욕',
#   '대학교',
#   '부교수',
#   '클레이',
#   '셔키',
#   '지식',
#   '그래프',
#   '다른',
#   '사이트',
#   '페이지뷰',
#   '를',
#   '잠식',
#   '하고',
#   '있다',
#   '에',
#   '대해',
#   '검색',
#   '페이지',
#   '에서',
#   '당신',
#   '질문',
#   '에',
#   '대한',
#   '답',
#   '을',
#   '바로',
#   '볼',
#   '있다',
#   '굳이',
#   '그',
#   '싸이트',
#   '를',
#   '방문',
#   '하다',
#   '반문',
#   '하다'],
#  ['위키',
#   '백',
#   '과는',
#   '시작',
#   '과',
#   '함께',
#   '문서',
#   '신뢰',
#   '성',
#   '에',
#   '대한',
#   '의문',
#   '따라다니다',
#   '누군가',
#   '보다',
#   '전문가',
#   '적',
#   '인',
#   '입장',
#   '에서',
#   '사용자',
#   '편집',
#   '을',
#   '검토',
#   '하고',
#   '제한',
#   '하다',
#   '있다',
#   '한다는',
#   '주장',
#   '늘',
#   '있다',
#   '위키',
#   '백',
#   '과의',
#   '공',
#   '동',
#   '창립',
#   '자',
#   '인',
#   '래',
#   '리',
#   '생어',
#   '결국',
#   '문제',
#   '로',
#   '인하다',
#   '위키',
#   '백',
#   '과를',
#   '떠나다',
#   '전문가',
#   '검토',
#   '를',
#   '거치다',
#   '시티즌디움',
#   '을',
#   '창립',
#   '하다',
#   '위키',
#   '백',
#   '과',
#   '역시',
#   '몇',
#   '차례',
#   '명백하다',
#   '오류',
#   '와',
#   '특정',
#   '집단',
#   '의도',
#   '적',
#   '인',
#   '개입',
#   '으로',
#   '완전하다',
#   '개방',
#   '정책',
#   '을',
#   '수정',
#   '하다',
#   '않다',
#   '없다',
#   '오랫동안',
#   '투데이',
#   '편집장',
#   '을',
#   '역임',
#   '하다',
#   '존',
#   '시겐설러',
#   '존',
#   '케네디',
#   '암살',
#   '에',
#   '연루',
#   '되어다',
#   '거짓',
#   '정보',
#   '위키',
#   '백',
#   '과',
#   '에',
#   '올라오다',
#   '사례',
#   '오랫동안',
#   '위키',
#   '백',
#   '과',
#   '문서',
#   '오류',
#   '에',
#   '대한',
#   '사례',
#   '로',
#   '거론',
#   '되어다',
#   '년',
#   '월',
#   '에는',
#   '스위스',
#   '정보',
#   '기관',
#   '공무원',
#   '수년',
#   '에',
#   '걸치다',
#   '약',
#   '건',
#   '에',
#   '달',
#   '하다',
#   '문서',
#   '를',
#   '악의',
#   '적',
#   '으로',
#   '편집',
#   '하다',
#   '아이피',
#   '차단',
#   '되다',
#   '일이',
#   '벌어지다',
#   '기도',
#   '하다'],
#  ['위키',
#   '백',
#   '과',
#   '사용자',
#   '위키',
#   '컨퍼런스',
#   '와',
#   '같다',
#   '오프라인',
#   '모임',
#   '을',
#   '통해',
#   '관심사',
#   '를',
#   '공유',
#   '하다',
#   '하다',
#   '위키',
#   '백',
#   '과를',
#   '운영',
#   '하고',
#   '있다',
#   '위키미디어',
#   '재단',
#   '매년',
#   '세계',
#   '적',
#   '인',
#   '컨퍼런스',
#   '인',
#   '위키마니아',
#   '행사',
#   '를',
#   '갖다',
#   '있다',
#   '년',
#   '위키마니아',
#   '이탈리아',
#   '에',
#   '시',
#   '노',
#   '라',
#   '리오',
#   '에서',
#   '열리다',
#   '위키마니아',
#   '에서는',
#   '위키',
#   '백',
#   '과',
#   '뿐',
#   '만',
#   '아니다',
#   '위키미디어',
#   '재단',
#   '운영',
#   '하고',
#   '있다',
#   '위키미디어',
#   '공용',
#   '위키데이터',
#   '위키책',
#   '위키문헌',
#   '위키낱말사전',
#   '과',
#   '같다',
#   '여러',
#   '자매',
#   '프로젝트',
#   '주요',
#   '관심사',
#   '도',
#   '함께',
#   '논의',
#   '되다',
#   '위키미디어',
#   '재단',
#   '여러',
#   '프로젝트',
#   '활성화',
#   '를',
#   '위해',
#   '세계',
#   '각지',
#   '지부',
#   '나',
#   '사용자',
#   '모임',
#   '을',
#   '지원',
#   '하다',
#   '사업',
#   '도',
#   '하다',
#   '있다',
#   '대한민국',
#   '에서는',
#   '한국',
#   '위키미디어',
#   '협회',
#   '자발',
#   '적',
#   '사용자',
#   '모임',
#   '으로',
#   '활동',
#   '중',
#   '이다',
#   '한국',
#   '위키미디어',
#   '협회',
#   '년',
#   '월',
#   '일',
#   '위키',
#   '백',
#   '과',
#   '주년',
#   '기념',
#   '행사',
#   '를',
#   '가지다'],
#  ['위키',
#   '백',
#   '과는',
#   '사용자',
#   '익명성',
#   '을',
#   '보장',
#   '하다',
#   '다중이',
#   '익명',
#   '으로',
#   '참여',
#   '하다',
#   '하다',
#   '커뮤니티',
#   '활',
#   '력',
#   '을',
#   '띄다',
#   '정보',
#   '질',
#   '꾸준하다',
#   '향상',
#   '되다',
#   '위키',
#   '백',
#   '과의',
#   '이러하다',
#   '작업',
#   '방식',
#   '크다',
#   '우드',
#   '소싱',
#   '이라는',
#   '이름',
#   '으로',
#   '다른',
#   '분야',
#   '에서도',
#   '시도',
#   '되다',
#   '있다',
#   '그러나',
#   '실제',
#   '로',
#   '위키',
#   '백',
#   '과',
#   '에',
#   '정보',
#   '를',
#   '추가',
#   '하다',
#   '사람',
#   '전체',
#   '사용자',
#   '가운데',
#   '극히',
#   '소수',
#   '라는',
#   '연구',
#   '있다',
#   '로그인',
#   '하다',
#   '않다',
#   '사용자',
#   '에',
#   '대해',
#   '서다',
#   '위키',
#   '백',
#   '과',
#   '커뮤니티',
#   '시민',
#   '취급',
#   '을',
#   '한다는',
#   '비판',
#   '도',
#   '있다',
#   '다트머스',
#   '대학교',
#   '연',
#   '구진',
#   '이르다',
#   '검증',
#   '하다',
#   '위',
#   '년',
#   '연구',
#   '에서',
#   '로그인',
#   '하다',
#   '않다',
#   '익명',
#   '편집자',
#   '나',
#   '기여',
#   '횟수',
#   '적다',
#   '편집자',
#   '활동',
#   '역시',
#   '로그인',
#   '사용자',
#   '와',
#   '동등',
#   '신뢰',
#   '성',
#   '을',
#   '보이다',
#   '밝히다',
#   '년',
#   '비지니스',
#   '인',
#   '사이더',
#   '편집',
#   '인',
#   '헨리',
#   '블라젯',
#   '위키',
#   '백',
#   '과',
#   '문서',
#   '에',
#   '대한',
#   '표집',
#   '조사',
#   '결과',
#   '대다수',
#   '문서',
#   '아웃사이더',
#   '에',
#   '의하다',
#   '생',
#   '성',
#   '되다',
#   '뒤',
#   '인',
#   '사이더',
#   '에',
#   '의하다',
#   '완성',
#   '되다',
#   '분석',
#   '하다'],
#  ...]

# %%
model = Word2Vec(sentences, size=100, workers=4, sg=1)
model.save('./embedding_data/Word2Vec_embedding.model')
#Word2Vec으로 임베딩

# %%
print(model.wv.most_similar("겨울"))
# Out:
# [('여름', 0.8099713325500488), ('가을', 0.7754981517791748), ('무덥다', 0.6980552673339844), ('성큼', 0.6945973634719849), ('사계절', 0.6940451860427856), ('쌀쌀하다', 0.6640306711196899), ('날씨', 0.6636645793914795), ('더워지다', 0.6568902730941772), ('추위', 0.6487399339675903), ('화창하다', 0.6474161148071289)]

# %%
model.most_similar("기훈")
# Out:
# <ipython-input-11-ae070e0e5008>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   model.most_similar("기훈")
# [('그렇다지금', 0.9577562212944031),
#  ('그런너', 0.9498454332351685),
#  ('요아빠', 0.9490751624107361),
#  ('행복하다너', 0.9467577934265137),
#  ('싫다그래도', 0.9450465440750122),
#  ('힘들다니', 0.9450212121009827),
#  ('에나르다', 0.9435191750526428),
#  ('걸다너', 0.9427775740623474),
#  ('보다날', 0.9424898624420166),
#  ('힘들다그냥', 0.9423236846923828)]

# %%
model.most_similar("성민")
# Out:
# <ipython-input-12-71faf03ef759>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   model.most_similar("성민")
# [('치바', 0.9324221611022949),
#  ('쌍칼', 0.9310321807861328),
#  ('아네트베닝', 0.9308414459228516),
#  ('아이참', 0.9296598434448242),
#  ('천사처럼', 0.9281245470046997),
#  ('멋찌', 0.9274226427078247),
#  ('재밋슴', 0.9263588786125183),
#  ('섬찟하다', 0.9257664680480957),
#  ('요만', 0.9251485466957092),
#  ('김성오', 0.9244521856307983)]

# %%
model.most_similar("화남")
# Out:
# <ipython-input-13-8e46f5011476>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   model.most_similar("화남")
# [('어후', 0.8584740161895752),
#  ('뷁', 0.8551384210586548),
#  ('몬한다', 0.8515959978103638),
#  ('웩', 0.8496450185775757),
#  ('점때', 0.8485627770423889),
#  ('같다마음', 0.8484862446784973),
#  ('졸림', 0.8458834886550903),
#  ('달기', 0.8446468114852905),
#  ('ㅇㅏ', 0.8425670862197876),
#  ('껏음', 0.8424884676933289)]

# %%
model.most_similar("짜증")
# Out:
# <ipython-input-14-1b8530116189>:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   model.most_similar("짜증")
# [('신경질', 0.8334203958511353),
#  ('화도', 0.7947074174880981),
#  ('짜증나다', 0.7829620242118835),
#  ('화가', 0.766454815864563),
#  ('화나다', 0.7558843493461609),
#  ('진절머리', 0.7270655632019043),
#  ('구역질', 0.7204140424728394),
#  ('심술', 0.7198125123977661),
#  ('승질', 0.7183388471603394),
#  ('다화', 0.7179652452468872)]
