# %%
import numpy as np
import pandas as pd
from konlpy.tag import Okt

# %%
DATA_IN_PATH = './'
train_data = pd.read_csv(DATA_IN_PATH + 'ratings_train.txt', header = 0, delimiter = '\t', quoting = 3)
train_data.head()
train_data = train_data.dropna()

# %%
print('전체 학습데이터의 개수: {}'.format(len(train_data)))
# Out:
# 전체 학습데이터의 개수: 149995

# %%
train_data.iloc[28]
# Out:
# id          6091784
# document       재밋는뎅
# label             1
# Name: 28, dtype: object

# %%
import re
review_text = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]", "", train_data['document'][0])
print(review_text)
# Out:
# 아 더빙 진짜 짜증나네요 목소리

# %%
okt=Okt()
review_text = okt.morphs(review_text, stem=True)
print(review_text)
# Out:
# ['아', '더빙', '진짜', '짜증나다', '목소리']

# %%
stop_words = set(['은', '는', '이', '가', '하', '아', '것', '들', '의', '있', '되', '수', '보', '주', '등', '한'])
clean_review = [token for token in review_text if not token in stop_words]
print(clean_review)
# Out:
# ['더빙', '진짜', '짜증나다', '목소리']

# %%
def preprocessing(review, okt, remove_stopwords = False):
    review_text = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]", "", review)
    word_review = okt.morphs(review_text, stem = True)
    word_review = ' '.join(word_review)
    return word_review

# %%
print(preprocessing("재밌겠당", okt))
# Out:
# 재밌다

# %%
okt = Okt()
clean_train_review = []

for review in train_data['document']:
    if type(review) == str:
        clean_train_review.append(preprocessing(review, okt, remove_stopwords = False))
    else:
        clean_train_review.append([])

# %%
clean_train_review[28]
# Out:
# '재밋는뎅'

# %%
test_data = pd.read_csv(DATA_IN_PATH + 'ratings_test.txt', header=0, delimiter='\t', quoting=3)
test_data = test_data.dropna()

# %%
clean_test_review = []

for review in test_data['document']:
    if type(review) == str:
        clean_test_review.append(preprocessing(review, okt, remove_stopwords = False))
    else:
        clean_test_review.append([])

# %%
clean_test_review
# Out:
# ['굳다 ㅋ',
#  '',
#  '뭐 야 이 평점 들 은 나쁘다 않다 점 짜다 리 는 더 더욱 아니다',
#  '지루하다 않다 완전 막장 임 돈 주다 보기 에는',
#  '만 아니다 별 다섯 개 주다 왜 로 나오다 제 심기 를 불편하다 하다',
#  '음악 이 주가 되다 최고 의 음악 영화',
#  '진정하다 쓰레기',
#  '마치 미국 애니 에서 튀어나오다 한 창의력 없다 로봇 디자인 부터가 고개 를 젖다 하다',
#  '갈수록 개판 되다 중국영화 유치하다 내용 없다 폼 잡다 끝나다 말 도 안되다 무기 에 유치하다 남무 아 그리다 동사서독 같다 영화 가 이건 류 아 류작 이다',
#  '이별 의 아픔 뒤 에 찾아오다 새롭다 인연 의 기쁨 모든 사람 이 그렇다 않다',
#  '괜찮다 오랜 만 포켓몬스터 잼밌 어 요',
#  '한국 독립영화 의 한계 그렇게 아버지 가 되다 비교 되다',
#  '청춘 은 아름답다 그 아름답다 움 은 이성 을 흔들다 놓다 찰나 의 아름답다 움 을 자다 포착 한 섬세하다 아름답다 수채화 같다 퀴어 영화 이다',
#  '눈 에 보이다 반전 이다 영화 의 흡인 력 은 사라지다 않다',
#  '스토리 연출 연기 비주 얼 등 영화 의 기본 조차 안되다 영화 에 무슨 평 을 해 이렇다 영화 찍다 김문옥 감독 은 내 가 영화 경력 이 몇 인데 조무래기 들 이 내 영화 를 평론 하다 같다 마인드 에 빠지다',
#  '소위 ㅈ 문 가라 는 평점 은 뭐 냐',
#  '최고',
#  '발연기 도저히 못 보다 진짜 이렇게 연기 를 못 하다 상상 도 못 하다',
#  '나이스',
#  '별 재미 도 없다 우려 먹다 챔프 에서 방송 몇번 하다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '일 의 금요일 나이트메어 시리즈 와 함께 가장 많다 시리즈 를 양산 해내다 헬레 이 저 시리즈 의 첫 편 작가 의 상상력 이 돋보이다 작품 이며 갈고리 로 사지 찢다 고어씬 은 지금 보더 라도 상당하다 잔인하다 충격 적 이다',
#  '나름 교훈 돋다 하지만 어쩔 수없이 저 평점 받다 없다 저 질 섹스 코미디',
#  '꽤 재밌다 보다 영화 이다',
#  '민주화 시대 의 억눌리다 영혼 의 관음 적 인 욕구 분출 인상 적 이다',
#  '일본 천황 이 미국 으로부터 받다 면죄부 의 긴박하다 과정 을 루즈 하고 지저분하다 늘어놓다',
#  '괜히 나오다 때 어미 알 건드리다 긁다 부스 름 만들다 분 이 저 아래 보이다 영화 제대로 안 보다 알 이 딱 끄다 새끼 가 나오다 하다 그냥 가면 그 놈 한테 당하다 것임 하다 놈 두 놈 막 나오다 게 뻔하다 작살 낼 수 밖에 없다',
#  '번은 보다 어쩜 이렇게 잘 만들다',
#  '실화 라서 더욱 아름답다 찡하다 많이 울다 벌써 년 이란 시간 이 흐르다',
#  '이건 뭐 노답 이네 년대 어린이 영화 좀 보고 본받다',
#  '지금 까지 보다 영화 중 마음 이 가장 따뜻하다 영화',
#  '너무 너무 재밌다',
#  '안보 면 후회 ㅠㅠ',
#  '평점 점도 주기 싫어지다 영화 배우 나 감독 이라는 사람 이나 영 화판 에서 안 보다 하다 그리고 평점 알바생 들 너무 티 나다',
#  '정말 진짜 표현 하다 없다 영화',
#  '엉 성하다 액션 에 시나리오 는 왜그러지 막판 에 대동단결',
#  '은 못 나오다 같다',
#  '재미 가 없다 시간 이 아깝다',
#  '북괴 는 우리 의 주적 일 뿐 이다',
#  'ㅋㅋㅋ 난생처음 로그인 하고 평점 남다 개 빡치다 알바 들 속지 말다 이렇다 ㄱ ㅐ 같다 시간 낭비 가 아 놓다 진짜 평점 마이너스 별 오만 개',
#  '셰익스피어 는 셰익스피어 고 이영화 는 이영화',
#  '한국영 화 특선 하다 보다 개막 작 선정 되다 왤다 궁금 하다 보다 이율 모르다',
#  '뭐 야 라는 말 밖에는',
#  '이 게 영화 야',
#  '애니 는 일본 이 가다',
#  '롭 코헨 의 몰락 의 점',
#  '감동 적 이다',
#  '은빛 날개 의 조종사',
#  '마음 이 을 보신 분들 은 이해 하다 늘다 망 장 이다 졸작 이 죠 솔직하다 선 그 이유 는 예 를 들 면 엽기적인그녀 는 기다 시간 을 두다 코 메다 멜로 를 그 렷습 니 다 하지만 이영화 는 단시간 분안 에 모든 것 을 소화 하다 욕심 코믹 하다 분 채다 돼다 갑자기 생뚱맞 게 슬프다 음악 이 깔리다',
#  '이런 스타일 액션영화 굿굿',
#  '제임스 헷 필드 먹다 더 파워 풀다 지다 ㅋㅋㅋㅋ',
#  '돈 만 있다 내 가 이 것 보단 덥다 만들다 따다 ㅋ',
#  '레이토 와 다미앙 의 시원하다 액션 은 어디 가다 ㅁㅊ',
#  '내 차다 이딴 걸 드라마 라고 그냥 이건 세계보건기구 에서 발암 물질 로 올리다 하다',
#  '아 극장 에서 아무 기대 없이 들어가다 감탄 하다 보고 나오다 년도 이다 그 때 가',
#  '아이디어 가 아주 좋다 재밌다',
#  '난 재밌다 평점 왜케 낮다',
#  '역사 얘기 보다 영화배우 감독 들 들다 더 관심 이 간다',
#  '몇 년 만에 아메리칸 조 크보 고 웃다 보다 하아 이 맛 이야 바로',
#  '재밌다 내용 도 신선하다 의미 도 있다 연기 도 좋다 영상 도 좋다',
#  '여름 이면 한결같이 생각나다 드라마',
#  '콩콩 ㅋㄲㅈㅁ',
#  '으 뭐 의도 는 좋다 보다 전달 이 돼다',
#  '아빠 가 낚 여서 본적 있다 슈래기 영화',
#  '결혼 은 현실 이에요 징징 징 성현아 벗기다 이 정도 얘기 밖에 못 하다',
#  '엠비씨 무비 채널 에서 보다 또 보다 엄청 잼 나다',
#  '어우 이 게 진짜 무섭다 진짜 로 시간 아깝다',
#  '몇번 을 보다 볼때 마다 재밌다',
#  '재미있다 잘 보다 후 속편 을 기다리다 만 드 네 요',
#  '결말 뻔하다 알다 보다 너무 슬프다 많이 울다',
#  '한번 본적 은 업 지만 재미있다 같다',
#  '성경 에 보다 지나치다 의인 도 되다 말고 지혜롭 게 되다 말 라고 하다 주인공 의 지나치다 착하다 남자 컴플렉스 는 결국 모든 걸 엉망 으로 만들다 직장 에서 해고 되다 부인 에게 거부 당 하고 그 모든 터전 을 잃다 불륜 으로 생기다 아이 를 보다 그리다 중요하다',
#  '미치다 놈 들 집합소 네 연출 력 빵점 스토리 빵점 구성 빵점',
#  '하 작다 그림 보고 기대하다 수염 눈 색깔 도 뭐 이건 뭐 원작 비 충실 ㄹㄹ',
#  '볼 거 없다 때 보다 재미 없다 영화',
#  '관객모독 관객모독 관객모독 관객모독',
#  '이런 내용 완전 좋다 ㅠㅜㅜㅜ',
#  '쇼타 군 넘다 좋다 돈키호테 대박 재밌다',
#  '차다 대단하다 같다 천재',
#  '볼 만 함',
#  '제시카 알바 가 벗다 달려들다 쌩까다 말 이 되다',
#  '솔직하다 이건 급 그 이하 의 영화 이기다 함 ㅎㅎ',
#  '개성 있다 몬스터 들 과 귀엽다 여자아이 가 만나다 뿜어내다 매력 에 퐁당 빠지다',
#  '제목 이 찰지구나 ㅋㅋㅋ',
#  '년 작품 이라는 게 믿다 않다 정도 로 디테 이다 안소니 퀸 의 명연기 또한 물론',
#  '아찔하다 사랑 줄다리기',
#  '재미있다 또 보다 징 ㅎ',
#  '중간 에 화면 이 좀 끊기다 빼다 넘다 좋다',
#  '이 영화 를 말 하다 기다 단어 는 필요없다 재수없다 졸작 이 거 면 충분하다',
#  '최고 최고 바다 까지 차원 고양이 로봇 도라에몽 과 함께 하다 진구 와 친구 들 의 미지 탐험 이야기 우주 꺼 지 가다 좋다',
#  '완전 잼 없다',
#  '로코 굉장하다 즐기다 보다 이 영화 는 좀 별로 이다 뭔가 사랑 도 개그 도 억지스럽다 느낌',
#  '후속작 계획 은 없다 ㅜ',
#  '엔딩 때 까지 음성 넣다 것 은 오버 의 극치 다',
#  '단 두 마디 감동',
#  '뭘 만들다 건가',
#  '전기톱 은 못 들다 엔진 톱 이 겠다',
#  '완전 재밌다 엇 늘다 왜 평점 이',
#  '제임스 완 이 내 목표 임 ㄷ',
#  '점 고 아깝다 개막 장 영화 의 원조 라고 나 하다 아내 와 사별 한 지다 얼마나 지나다 따다 여자 들 만나다 다니다 결국 맥 라이언 한테 꽂히다 톰 행크스 나 약혼자 두다 톰 행크스 랑 썸 타 다가 결국 엔 약혼자 버리다 톰 행크스 한테 쪼르르 달려가다 맥 라이언 이나',
#  '가끔 문득 생각나다 다시 보다 영화 색감 이 정말 예술 이 죠 강렬하다 화려하다 츠지 야 안나 의 너무도 아름답다 리즈시절 도 볼 수 있다',
#  '걸작 은 몇 안되다 졸작 들 만 넘치다 나다',
#  '이렇게 지겹다',
#  '정말 좋다 영화 자체 도 의문 은 남지 만 ㅎㅎ',
#  '펑퍼짐하다 건빵 바지 크다 입다 오도바이 탈때 입다 잠바 같다 것 을 입다 주인 공겸 감독 이 앞 차기 옆 차기 뒷 차기 앞 돌려차기 등 의 기술 을 구사해 악당 을 소탕 하다 영화 주먹질 도 하지만 앞 차기 와 옆 차기 의 비중 이 크다',
#  '솔직하다 생각 보다 재밌다 놀라다 이 거 개봉 하고 내다 린줄 도 모르다 ㅠ ㅠ 이제 서다 보다 정말 두 사람 의 커플 댄스 는 명 장면 이다 생각 하다 아쉽다 단순 상업 영화 라고 생각 하다 두 사람 의 춤 이 너무 인상 적 이다',
#  '이 거 평점 보 니까 알바 고 용하다 제작비 보다 많이 들어가다 정말 재미 라고는 찾아보다 수 없다 특히 마지막 에 여자애 가 경상도 사람 이 들다 코웃음 칠 만큼 어색하다 사투리 로 엄마 한테 말 하다 때 는 그나마 잡히다 감정 도 깨다 버리다',
#  '시리즈 중 에는 단연 최고',
#  '글쌔슬프 지만 너무 짜이다 한',
#  '여기 서 땡 칠이 얘 낳다 안나',
#  '너무 재밌다 ㅠㅠ 뭐라다 굉장하다 따뜻하다 느낌',
#  '견자단 나오다 영화 중 에 제일 노잼',
#  '재밌다 말다 왜 이렇게 욕 을 하 셍 휴 ㅠㅠ',
#  '실제 사실 은 어떻다 모르다 의 로운 협객 으로서 김두한 이 거지 패 에서 종로 최고 의 주먹 으로 평정하다 초기 모습 을 자다 보이다 줌 배경음악 이 영상 과 자다 어울리다 느낌 참고 로 황정민 이 우미관 지배인 으로 나오다 유명하다 하다 영화',
#  '재밌다 자막 읽다 힘들다 영어권 사람 들 이 보다 더 몰입 되다 공간 이 한정 되다 상상 만으로도 충분하다 재미나 고 생각 하다 많다 영화 바이러스 가 언어 라는 게 참신하다 바 이르다 소문 괴담 선동 찌라시 언론플레이 등 과 대입 하다 생각 해보다 재밌다',
#  '괜찮다',
#  '내 가 극 장가 서 보다 영화 중 제일 쓰레기 같다',
#  '',
#  '피다 물 보다 진하다 이 한마디 로 모든 게 표현 되다 영화',
#  '이뿌다 따뜻하다 애니 이다',
#  '너무 좋다',
#  '어렷을때 보고 박준형 에 배신 감 을 ㅋㅋㅋㅋ',
#  '차인표 말투 적응 안 돼다 송선미 이쁘다',
#  '과소 평가 확실하다 재밌다 유쾌하다',
#  '훌륭하다 작가 와 뛰어나다 연 출진 이 만나다 훌륭하다 뛰어나다 하다 편의 드라마 가 만들어지다',
#  '신선하다 소재 로 식상하다 영화 를 만들다 유치하다 둘째 치고 재밋게 라도 만들다',
#  '다시 보다 정말 최고 군 요 잭 바우어 형님 이 여기 나오다 처음 볼땐 못 느끼다 또 하나 의 재미',
#  '이렇다 쓰레기 영화 좀 만들다 진짜 재미없다 ㅡㅡ',
#  '정말 가슴 아프다 영화 질리다 않다 영화 몇번 을 보다 음악 도 너무 좋다 요도 구해 들다',
#  '영화 도 못 만들다 이건 탄생 하다 말다 하다 그 자체 로 쓰레기 임',
#  '정말 재밋 어요 다 들다 연기 도 잘 하다 볼 만해 요',
#  '신기록 갱신 인가 간닷',
#  '오시 이 마모루 는 영화 를 통해 책 을 넘어서다 하다',
#  '데어데블 보다 못 한 졸작 늘다 훌륭하다 악마 인형 탈 쓰다 나오다 웃기 고 인물 관계 나 스토리 가 너무 뻔하다 시간 이 아깝다 움 짧다 러닝 타임 이 고맙다 정도',
#  '마트 라는 폐쇄된 공간 속 에서 그 안 에 갇히다 사람 들 의 심리 변화 가 인상 적다 결말 이 인상 적 이다',
#  '차인표 연기 는 너무 현 실적 이 여서 마음 에 오다 닿다 왕초 드라마 를 볼때 도 난 연기 를 하다 건지다 진짜 실제 로 그렇다 건지다 모르다 이영화 내용 이 쥐다 짜다 스토리 지만 차인표 라는 배우 때문 에 영화 가 살다 너무 현실 적 인 연기력 이다 대단하다 눈물 한 방울 흘리다 않다 마음 이 아프다',
#  '이 게 뭐 야 엉 엉 본 시리즈 말고 그냥 나오다 이 정도 는 안 주다 보다 이름 을 달 고 오다 엉엉',
#  '스토리 가 신선하다 재미있다 좋다',
#  '재밌다 저 너무 무 서버 ㅠ',
#  '아직 까지 잊다 못 하다 영화 제목 부터 마음 에 잔잔하다 오다 닿다 영화 장면 중 에 소 낙비 를 피해 놀라다 달다 가다 부분 은 정말 어느 멋진날 햇살 비추다 행복하다 빗속 을 달리다 느껴지다',
#  '지루하다 않다 가볍다 보다 코믹 스릴러 영화 네 요 저 는 잔인하다 무겁다 스릴러 영화 보다 오히려 좋다',
#  '김민 이 너무 어설프다 졸작',
#  '화면 어지럽다 엉 성함 과 지루함 의 연속 임',
#  '영화 다 보고 평점 읽다 이영화 최고 의 재미 ㅋ',
#  '정말 재밌다 잘 보다',
#  '예수 쟁이 들다 좀 제발 인터넷 에서 안 보다',
#  '작가 의 예리하다 필 력 에 박수 를 보내다 진보 한 드라마 란 바로 이렇다 것 시청률 의식 하다 말다 앞 으로도 좋다 내용 부탁드리다',
#  '작품 성 을 떠나다 보고 나다 너무 너무 찝찝하다 지다 영화',
#  '초 중학생 수준 의 단조롭다 대사 와 지루하다 재미 없다 영화',
#  '년도 에 참으로 억지스럽다 미국 을 욕 하다 뭐 이런 건가 ㅋㅋ',
#  '편이 오억만배 재밌다 영화 편도 나름 대로는 재밌다',
#  '다시 보다 수작 이다 미국 국수 주의 라 뭐라다 시점 도 있다 전쟁 물 중 에 손가락 안 에 꼽 을 정도 로 잘 만들다 지다 스토리 라인 은 뻔하다 그 뻔하다 걸 너무 자다 살리다 언제 보다 다시 보다 재미 있다 년 이 지난 영화 가',
#  '클럽 과 사건 의 연결 이 전혀 안되다 섹스 클럽 얘기 는 흥미 거리 일 뿐 스토리 연관 이 없다',
#  '다니엘 미쉘 페이퍼 마틴 스콜 세지 쵝오',
#  '탕웨이 이제껏 관심 없다 이번 영화 를 계기 로 너무 좋다 ㅠㅠ',
#  '간만 에 차다 유쾌하다 웃다',
#  '액션 이 진짜 꽤 괜찮다 ㅎ',
#  '무슨 말 이 더 필요하다 아마 이 영화 보고 법무관 또는 법조인 이 되다 라고 생각 을 품 엇 덥다 사람 이 있다',
#  '개다 진짜 돈 아깝다 움',
#  '죠스 보다 더 재밌다',
#  '두 말 하다 필요없다 이건 보다 시간 이 남다 집 에서 발 닦다 잠 이나 자라',
#  '굿',
#  '마지막 도서 카드 에 그려지다 모습 을 보고 울다 이츠키 의 모습 을 보고 저 도 울다 지금 보다 달 은 지나다 같다 아직도 그 모습 을 떠올리다 먹다 먹다 지네 요',
#  '완전하다 삶다 없다 그저 하나 씩 배우다 나가다 뿐',
#  '어르다 이즈 시리즈 중 에 그나마 나은 편 편 보다 진짜 노잼 이라 욕 밖에 안 나오다 그래도 이건 조금 이나마 볼 만 한편 극장판 주제 에 오프닝 은 부터 까지 애프터 이 펙트 만 처 바르다 바뀌다 않다 예산 이 모자라다 건지다 감독 이 미치다 건지다 모르다',
#  '이야 미키 루크 나오다 홈 보이 영화 를 다 알다 분 들 이 계시 네 이야 놀 라울 뿐',
#  '팬 이기다 이건 안 보다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 모르다 나다',
#  '케이블 에서 우연히 보다 되다 월광보합 때문 에 깔깔 거리 고 웃다 선리기연 마지막 장면 에서 일생 소 애가 흘러나오다 눈물 이 되돌리다 수 없다 시간 이 가장 아프다 오다 닿다',
#  '보다 기대 만발 싸랑 하다 키르 아',
#  '심심하다 때 보다 딱 좋다 영화',
#  '별로 재미 없다 왜 점 이지',
#  '노인 들 의 섹스 외 엔 보여주다 게 없다 영화 영활 끄다',
#  '멀다 말 하다 하다 아직도 이해 가공 포도 아니다 실망 ㅁ',
#  '역시 영화 를 볼 때 도 도덕성 을 버리다 둘 수 는 없다',
#  '그리스 의 아름답다 풍경 을 감상 하다 달달 한 로맨스 를 즐기다 수 있다 영화 보다 흐뭇하다 미소 를 지다 보다 ㅎㅎㅎ',
#  '어썸',
#  '조 쉬 나오다 바꾸다 멀다 이건 뭐병 정신 줄 을 놓다 건가 드 팔마',
#  '종교인 이 아니다 그 인간 적 인 고뇌 가 느껴지다 숭고하다 감동',
#  '수고 요 수고 수고 ㅅㄱ',
#  '한 회 한 회 보다 총 체적 으로 발연기 다 중량 급 연기자 들 도 모두 하향 평준화 되다 작가 의 생각 도 너무 어이 업슴 일일 극 치고는 최악 으로 평점 점도 아깝다',
#  '전작 에 비다 훨씬 스토리 도 고급스럽다 무엇 보다 이번 편 에서도 역시 간지나다 액션 신다 스타 뎀 성 님 이 도 맡다 하다 보고 더욱 좋다',
#  '아 희망 이란 미래 란',
#  '먼지 끼다 회색 초콜릿 같다 맛 의 영화 랄 끄다',
#  '아주 진짜 영화 를 찍다 영화 를 찍다 ㅉㅉ',
#  '이 게 뭐 가 다 들다 재밌다 ㅋㅋㅋ 마지막 반전 이 가장 최악 이다',
#  '급 액션 의 진수 깨알 같다 까메오 들 과 잔 웃음 거기 다가 엠버 허드 의 ㅎㄷㄷ 하다 몸매 어느 영화 에서나 빛 을 발 하다',
#  '어리다 때 감동 적 으로 보다 영화 라 잊다 못 하다 라스트 장면 에서 이불 뒤지다 쓰다 울다 기억 이 꼭 다시 보고 싶다 파일 좀 보내다',
#  '두 주인공 의 관계 와 로맨스 는 어색하다 요술 인지 마법 인지 뭘 하다 건지다',
#  '왜 헤라클레스 의 인물 묘사 를 저따위 로 하다',
#  '뭐 야 이 거 무섭다',
#  '오다 기리 죠 의 배 바지 가 기억 에 남다',
#  '카메라 로 이렇게 까지 아름답다',
#  '이 게 영화 냐 첫 장면 부터 역겹다 분위기 있다 척 앵글 잡다 괜찮다 영화 인거 같다 허세 덩어리',
#  '지상 최고 의 드라마 이 정도 면 되다',
#  '사랑 이 무엇 인지 알다 영화',
#  '미국 당시 의 시 대 흐름 과 개개인 들 의 인간 승리 응 보여주다 영화 좌절 하고 힘들다 때 보다 용기 를 주다 영화',
#  '점 이 제일 적다 점 주다',
#  '재미 따다 가다 모르다 ㅋㅋ',
#  '기 대 안해 서 그 런가 조카 랑 너무 재밌다 보다 아샤크 보다',
#  '소품 은 자다 만들다 연기 를 너무 못 하다 몰입 이 안되다 엑기스 만 보고 끝내다 내 가 보다 영화 중 에 최악 이다',
#  '신나다 것 없다 애니',
#  '여성성 의 한계 에 갖힌 탈출 의 덫',
#  '정말 이건 대박 임 걍 잼슴',
#  '도 가 지나치다 신앙심 의 말로 종교인 에게도 비종 교인 에게도 전하 는 메세지 가 뚜렷하다 좋다 강추',
#  'ㅋㅋ 귀엽다',
#  '내 기억 에 너무 재다 떤다',
#  '우와 신기하다 나 진심 시사회 보고 평점 쓸다 삭제 당하다',
#  '순수하다 말 하다 자연 스럽게 대화 만으로 서로 가 끌리다 사이 자연스럽다 만남 영적 소통 하루 뿐 인 아쉬움 을 공감 하다 이 들 의 반년 후의 모습 이 설레다 궁금하다',
#  '무섭다 않다 끔찍하다 하다',
#  '요요 비치 나오다 발코니 에서 아래 를 내다 보다 일행 중 한 명 으로 등장 함 상영 시간 분 쯤 초 즈음 하다 영화 는 형편 없다 야하다 않다',
#  '년 이 지나다 여전하다',
#  '남자 조 내다 찌질하다 연기 자다 함보 는 내 가 답답하다 그동안 보다 온 독립영화 중 좀글 네 요',
#  '젊음 과 열정 격정 과 두려움 그 모든 것 이 묻다 영화',
#  '어르다 게임 영화 가 아니다',
#  '엄정화 다시 보기 연기 굿',
#  '이렇게 불쾌하다 내용 을 왜 보다 한 거 냐',
#  '이 거 다운 하다 청소년 관람 불가 라고 뜸',
#  '공산 사회주의 의 잔인함 을 느끼다 해주다 영화 북한 에 비 하다 암 것 도 아니다',
#  '다시 보다',
#  '왜 이렇게 다 들다 스토리 에 불만 이지 이야기 에는 다 원형 이 있다 이 영화 는 그 원형 이 되다 스토리 안 에서 예술 을 하다 그걸 가지 고 진부하다 하다 대체 뭘 본 건 지',
#  '글쎄',
#  '역시 팀 버튼',
#  '노다메 는 유치하다 매력 인데 욕 하다 새 뀌 들 드라마 부터 보고오다',
#  '애매하다',
#  '저만 별로 이다 ㅠㅠ 그냥 그렇다',
#  'ㅡ 허접스럽다 영화 스토리 도 시 대 착오 적 인류 코미디',
#  '이 영화 를 보고 난후 극장 영 사실 을 유심 히 보다 되어다',
#  '많이 무겁다 그렇다고 가볍다 않다 진짜 보기 좋다 성장 영화',
#  '터지다 깨뜨리다 박다',
#  '매주 이 것 만 기다리다 있다 ㅠ 너무 재밌다 소변 사랑 하다',
#  '맥가이버 머리 유행 하다 때 인기 폭발',
#  '완전 쓰레기 군 하다 보다 생각 보다 생각 없이 자다 봣다 그래서 점 주다',
#  '이건 뭐 차라리 세면 노출 을 더하다 이건 뭐 망',
#  '보다 보다 나다 저 회사 에서 일 하다 잘 하다 싶다 생각 이 만들다 하다 드라마 캐스팅 도 아주 완벽하다 듯 하다',
#  '개잼남포르 는 중요 부분 만 챙기다 보지 만 이건 오직 정 주행 함 ㅋ',
#  '전 재미나 게 보다 달튼 의 능글 한 매력 과 젊다 시절 페넬로페 를 보다 것 으로도 점',
#  '공포영화 야 이 게 ㄷㄷ',
#  '농담 과 장난 끼 만으로 영화 를 만들기 엔 무리 가 있다 보이다',
#  '외계인 이 징그럽다 늘다 재밌다 ㅋㅋ',
#  '세븐 을 생각 하다 보다 큰코다치다 영화 모건 프리 멀다 연기 는 좋다',
#  '이토준지 원작 의 영화 화 는 대체',
#  '척 보기 에도 흥행 에 실패하다',
#  '나름 대중성 있다 만화 작품 을 이렇게 이렇다 태도 로 취급 하다',
#  '중년 의 나이라 면 하다 번 쯤 은 보다 하다 영화',
#  '감동',
#  '일본 스타일 공포영화 를 시도 한 듯 한 느낌 깜짝깜짝 놀래다 키 는 것 밖에 없다 일회용 공포영화',
#  '아 이 거 어리다 때 보다 자다 기억 은 안 나 짖다 재밌다 것 같다',
#  '영화 바람 을 재밌다 본 사람 이 라면 추천 하다 가볍다 마음 으로 보기 좋다 영화 에요',
#  '훌륭하다 초한지 얼른 읽다 보고 다시 보다 연출 훌륭하다 껄껄 한신 의 토사 구 팽 은 슬프다',
#  '적다 돈 으로 나름 최선 을 다해 만들다 듯 한하유 가 마음 에 들어서다 점',
#  '연애 인 더빙 도 참고 다 참다 이건 진짜 못 참다',
#  '정신 없다 여자 주인공 보다 어지럽다 스토리 도 완전 어거지',
#  '뭔가 스토리 가 이상하다',
#  '이 영화 에 별 점 하나 주다 사람 들 과 같이 살다 끔찍하다',
#  '돈 걱정 제로 인 비현실적 인 사람 들 비현실적 세상 설정',
#  '',
#  '책 으로 먼저 접 한 폭풍 의 언덕 살 이다 내다 사랑 의 그 진하다 밀도 를 알 게 해주다',
#  '서브 남다 들이다 더 빛나다 보이 고 주인공 같다 영화 벤자민 과 지지 가 나오다 때 가 더 즐겁다 특히 지지 여주 보다 더 예쁘다',
#  '편 보다는 더 짜임새 가 있다 그렇지만 개인 적 으로 로버트 쇼 에 더 눈독 이 가다',
#  '평점 점 이상은 뭐 냐 애니 보고 그런 말 이 나오다 보다',
#  '현실 은 이러하다',
#  '첫 장면 보고 영화 재미있다 하다 너무 지루하다 지난 과거 를 회상 하다 너무 지루하다 재미없다 감동 도 없다 시간 남아돌다 다른 영화 보다 좋다 같다',
#  '조금 만 집중 하다 보다 엄청 심오하다 영화 다',
#  '탕웨이 정말 매력 적 인 여자',
#  '세분 비구니 들 이 꼭 자기 자신 을 찾기 를 간절하다 바라다 약간 의 눈물 은 흘리다 잔잔하다 그 들 의 모습 에서 나 의 삶 을 뒤 돌아보다 너무나 좋다 느낌 의 다큐 이다 진심 으로 이렇다 분 들 의 삶 을 으 원하다 감독 님 의 열정 에 감사 드리다',
#  '부산 엔 언제 개봉 하다',
#  '어떻 게 든 감싸다 노력 을 하다',
#  '완전 재다 ㅋㅋㅋㅋ',
#  '이 거 끝나다 때 까지 멀다 기대하다 아무 것 도 없다',
#  '완전 대박 ㅠㅠ 후회 없다 영화 에요 꺅꺅 꺅',
#  '디박 대박 잼 쓰다',
#  '제 가 보다 애니메이션 영화 중 에 명작 이다',
#  '마 수리 와 비교 하다 하다 없이 작아지다 컴 밉다',
#  '이 젠 양동근 은 믿다 보다 배우 가 아니다 되어다 버리다',
#  '진짜 졸잼 오다 마지막 결말 너무 맘 에 들다 ㅠㅠ 진짜 재밌다',
#  '감명 깊다 재밌다 굿',
#  '나 는 다르다 생각 하다 여기 서 너구리 에서 인간 으로 변신 하다 살아가다 사람 들 은 우리 사회 의 소수자 들 을 상징 하다 것 같다',
#  '시간 이 아깝다 내용 도 단순 재미 도 감동 도 볼거리 도 없다',
#  '지금 까지 나오다 드라마 중 최고 이다 점 만점',
#  '정말 초딩 을 위해 서 만들다 스토리 쓰레기 벨 런스 쓰레기 액션 쓰레기',
#  '굿재밋다봐도봐 도 잼 따다',
#  '연기자 들 지 혼자 나르다 연기 압권',
#  '보고 울음',
#  '배우 이민호 와 김희선 의 어울리다 않다 같다 어울림 이 묘 한 매력 으로 다가오다 신의 타임스 립 드라마 의 최고봉 이라 하다 수 있다 잔잔하다 애잔하다 신의 의 매력 으로 풍덩 빠지다 보심 이 어떨 런 지 내 인생 최고 의 드라마 이다 적극 추천 하다',
#  '이딴 영화 가 평점 이 왜 이리 높다 케이블 에서도 보다 없다 영화',
#  '평점 높다 주다 ㅋㅋㅋ 정말 재미 가 없다 지루하다 너무 뻔하다',
#  '그냥 강지환 아깝다',
#  '군인 이 가다 하다 것 그것 을 모두 담다 표현 한 영화 이다 이 나라 를 위해 죽다 기쁘다',
#  '영국 에도 팍팍하다 탄광 노동자 의 삶 이 있다 자신 의 재능 을 발휘 하다 수 있다 삶 을 찾아가다 소년 은 행복하다',
#  '재미 가 없다',
#  '기 타 케이스 에서 총 나오다 씬 만 해도 이미 점 은 되다',
#  '더지니어스 보다 훨났다',
#  '이정진 님 정말 비운 의 배우 라는 생각 이',
#  '살아가다 한번 쯤 은 보다 인생 에 대한 의리 인 영화',
#  '를 그냥 보 니까 좀',
#  '진짜 재밌다 보다',
#  '글쎄 돈 주다 다시다 안 보다',
#  '삼 순 이보 다가 궁금하다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '판타스틱 협녀 둘 중 하나 만 보다 하다 고문 이 따로 없다',
#  '재미있다 ㅋ 좀 황당하다 유머러스하다 엉뚱하다 유쾌하다 보다 더불다 음악 도 좋다',
#  '볼 만하 다',
#  '재미있다',
#  '이 거 완전 재밌다 보다 평점 왜 이리 낮다 ㅠ',
#  '당신 은 지금 행복하다',
#  '빌어먹을 내 가 이제껏 본 영화 중 에 가장 루즈 한 영화 다 말 도 안 돼다 웃기다 않다 빌어먹을 내 시간 다잡다 치다 먹다',
#  '졸다 ㅠ 그냥 생물 들 소개 스토리 어지럽다 나레이션 오글오글 ㅋㅋㅋ 애기 영화',
#  '시즌 강추 사만 다 완젼 웃기다 ㅋㅋㅋ',
#  '이야기 가 전개 되다 과정 에서 흥미 를 유발 하다 못 한 채 시간 만 흘러가다',
#  '가슴 깊이 울림 을 주다 감동 적 인 영화 다 마지막 자막 이 오르다 갈다 때 까지 흐르다 눈물 이렇다 아름답다 영화 를 이제야 감상 하다 케빈 코스트 너 클린 트 이스트 우드 감독 님 존경 하다',
#  '지나다 보다 다 아무 것 도 아니다 일 인데 시간 이 준 지혜 를 전달 해주다 영화',
#  '여 주인공 이 꽤 괜찮다 얼굴',
#  '진짜 포스터 만 멋지다 보다 가끔 주연 들 은 넘다 좋다 ㅠ',
#  '히 액스멘 의 부활 이 완벽하다',
#  '재미있다',
#  '대한민국 해군 으로써 를 혐오 하다 최대 다수 의 행복 을 죽다 젊은이 들 의 목숨 과 그 들 가족 의 슬픔 보다 중하 게 여기다 때문 이다 손바닥 으로 하늘 을 가리다 하늘 이 가려지다 아니다',
#  '좀 주인공 이 짜증나다 마지막 도 그렇다',
#  '거인 만 불쌍하다 보다 속이다 불편하다 아 짜증나다',
#  '아오이 유우 맨 앞 에 하다 분 나오다 아 이 속 았 달다 느낌',
#  '이영화 를 보고 느끼다 개 나소 나 누구 나 영화감독 이 되다 원작 을 이렇게 망치다',
#  '몰입도 제로 뱀파이어 가 피 조금 흘리다 자살 하다 꼴 에 늑대인간 과 뱀파이어 라는 초자연적 인 존재 의 총 격전 은 왜 하필 소재 가 늑대인간 대 뱀파이어 인지도 모르다 작품',
#  '논스톱 뉴논스톱 논스톱 논스톱 논스톱 레인보우 로망스',
#  '댓글 들 덕분 에 영화 보다 빠르다 포기 함 댓글 에 참으로 감사하다 내 아깝다 시간 아끼다 오광록 씨 연기 연습 좀 더하다 야하다',
#  '하 감독 님 세기 는 순정 영화 도 시가 아니다 긴장감 과 메시지 가 있다 먹히다 답니 다',
#  '잔잔하다 오래 기억나다 우리 시대 보통 의 가족 의 모습 이 솔직하다 담기다 한 소녀 의 성장 기도 요',
#  '재밌다 이만 하다 최근 보다 상업 영화 중 순위 권 에 랭크될 만 하다',
#  '홍콩영화 를 어줍다 흉내내 고 있다 기절 초 풍 하다 하다 싸구려 무비',
#  '나탈리 아 와아 바람 피다 확실하다 영상 이 나왓음 하다',
#  '이상은 땜 에 극장 에서 보다 최악 의 영화 이다 로 기억 함',
#  '반딧불 의 무덤 처럼 불편하다 만들다 진정하다 이 국적 감성',
#  '존재 조차 모르다 영화 한테 맞다 나 한테 오다',
#  '후',
#  '사람 의 인생 을 하다 그림 에서 알 수 없다 것 겉 으로만 알 고 있다 것 과 진정 으로 느끼다 알 고 있다 것 은 분명하다 느낌 이 다르다 배다 애플렉 과 션 윌 은 복 받다 사람',
#  '스토리 캐릭터 표현 력 영 상미',
#  '티비 드라마 보다 못 한 영화 그 시대 엔 티비 드라마 가 한국영 화 보다 더 재미있다',
#  '힐러리 를 사랑 하다 남다 생각 이 안나 요 ㅋ',
#  '스토리 도 정말 별거 없다 엄청 지루함',
#  '쓰레기 드라마 오정세 만 빛나다',
#  '오다 포스터 도 같넼 ㅋㅋㅋ',
#  '이건 클래식 을 위 한 드라마 도 청춘 들 의 성장 드라마 도 아니다 주제 를 알 수 없다 드라마 가 되어다 버리다 클래식 계 의 현실 을 고발 하다 위 한 드라마 인가 심각하다 드라마 다 부채 도사 는 어디 로 ㅠㅠ',
#  '좋다',
#  '쾌락 의 정점 을 찍다 그 들 의 삶 을 보고 우리 는 또 다른 쾌락 을 느끼다 그 들 이 추하다 생각 하다 결국 우리 도 돈 을 추구 하고 누구 나 부유하다 삶다 한번 쯤 상상 해보다 감독 한테 엿 먹다 같다',
#  '개인 적 으로 미식축구 를 다시 생각 하다 만들다 감동 적 인 영화 군 요',
#  '의외로 재밌다 영화 지루하다 않다 사극 멜로 이다',
#  '캐릭터 들 이 하나같이 짜증 유발 매력 적 인 캐릭터 가 없다 할아버지 빼다',
#  '엔딩 임팩트 가 약하다 통쾌하다 좋다 걸',
#  '역시 박신양 마지막 이 쫌',
#  '주연 배우 너무 지겹다 너무 무리하다 압축 으 으으윽',
#  '같다 상처 를 공유 하다 부담스럽다 피 하고만 싶다 어머니 가족 이란',
#  '문 제아 라고 쏘다 부치다 아이 들 의 속 내 재빠르다 영리하다 의리 있다 시리다 다르덴 은 이렇게 엉망 인 가운데 에도 진심 의 작다 마음 이 지키다 갈다 수 있다 것 에 대해 꾸준하다 이야기 해주다 극적 이지 않다 직조 하다 능력 에 감탄',
#  '유치하다 더 사실 적 으로 만들다',
#  '흑역사 네 ㅋㅋㅋㅋㅋ',
#  '꽃 빨 아 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 진짜 짱 이다',
#  '별로 다',
#  '전라도 의 모든 것 을 보여주다 영화',
#  '뻔하다 스토리 조잡하다 효과',
#  '억천만 불 에 제작 하다 수익 은 백만불 만 먹다 망하다 전세계 위로 망하다 영화',
#  '기분 나쁘다 못 보다 두 치 때문 에 저 게 두 치 냐 ㅡㅡ',
#  '수채화 같다 영상 과 가슴 을 울리다 음악 이 조화 되다 잊다 하다 명작',
#  '가장 싫어하다 신파 스릴러 ㅠㅠㅠ',
#  '뭐 지 이영화 는',
#  '재밌다',
#  '아버지 와 소원 하다 이렇다 영화 한편 쯤 보다 괜찮다 싶다',
#  '감독 이 살다 요즘 개독 들 보다 아마 기 가 막히다 듯',
#  '말 로는 설명 하다 수 없다 놀라다 감동 적 인 영화',
#  '나가다 사오다 마사미 도 그렇다 이 시리즈 너무 좋다 그냥',
#  '기 대안 하다 너무 재다 연기 짱 내용 두 탄탄하다 강추',
#  '현실 적 이고 재밌다 꾸미다 너무 막장 은 싫다 인물 들 의 성격 행동 이 일관 되다 좋다 무조건 재미 만 추다 하다 좋다',
#  '조로아크 가 조로아 를 간절하다 바라다 느껴지다',
#  '정종철 박준형 등 이 무리 의 사람 들 이 나오다 영화 는 크게 성공 안 하다',
#  '아 진짜 바보 요괴 들 귀요미 잼잼잼 ㅋㅋ 이 바보 요괴 들 그리다 또 보다 감동 도 잇다',
#  '나름 머리 좋다 학식 이 높다 경제학자 들 이 어떻다 서민 들 의 생활 을 파괴 하 면서 까지 돈 을 벌다 대해 적나라 에게 설명 해주다 뜻 깊다 영화',
#  '간만 에 원하다 영화 가 나오다',
#  '진짜 말 이 필요없다 드라마 네 요 난 왜 작년 에 이 걸 모르다 진짜 영화 같다 색감 과 명품 연기자 들 인생 드라마 가 되다 같다',
#  '괜찮다 좋다 우리나라 만화영화 발전 을 위해 서 내용 재밌다 순수 만화',
#  '참신하다 소재 지만 어슬픈 마무리 때문 에 실화 인 줄 알다',
#  '재미있다 너무나도 재밌다',
#  '반전 에 반전 감독 도 지키다 대충 얼머 무리다 마무리 쫑났다',
#  '인생 을 다시 한번 생각 하다 하다 영화 여운 이 남다 영화',
#  '밑 에 분 그렇다 난 사람 아니다 ㅎㅎ',
#  '한채영 스탈 좋다 거 인정 그러나 언제나 느끼다 얼굴 은 그 닥 모두 들 책 을 읽다 대다 ㅋㅋㅋㅋ 내 가 보다 한국영 화중 최악 의 연기 조합 연출 수준 은 학생 영화 이 걸 개봉 하다 놀라다 같다 해 에 나오다 해변 으로 가다가 훨 나다',
#  '이 거 왜 재 방안 해주다',
#  '오다 아저씨 조인성 도 보고 능력 있다 신분 이 셨 네 아무튼 전 서울 고',
#  '툭툭 끊기다 재미 와 어울리다 않다 대사 로 멋있다 보이다 오도방정',
#  '진하다 여운 이 남다 영화',
#  '쉬리 에서 하다 년 은 퇴보하다 방화 수준 의 망작',
#  '소간 지 짱',
#  '점 정도 가 적당하다 영화 역시 안 졸리다 액숑 이다',
#  '완전 짱 임 한번 보다 폐인 되다 ㅋㅋㅋ',
#  '줄거리 만 읽다 대충 가다 스토리 와 결말 이라 기 대안 하고 보다 역시 예상 대로 이다 재밌다 보다 훈훈하다 좋다 달다',
#  '대박',
#  '조음',
#  '제발 이렇다 쓰레기 영화 만들다 국가 적 낭비 다',
#  '어줍다 예술가 의 고뇌 인양 포장 하다 입생로랑 에 대해 사다 지루하다 영화 는 차다 있다 겉멋 만 잔득 들어가다 내다 텅 비다 예술 인척 하다 더 보다 짜증나다 올드함 과 진부하다 그리고 건지다 하나 도 없다 대사 들 의 향연',
#  '오타루 에 오다 다시 보다 러브레터 학교 다니다 때 는 크다 감흥 없이 보다 지금 다시 보다 너무 좋다 지금 내리다 크다 눈 이 그 치면 밖 으로 나가다 다시 느끼다 보다 ㅎ',
#  '공포영화 인지 웃기다 하다 건지다 알다 없다',
#  '공허하다 담배 피기 빌리다 밥 숀튼',
#  '대다 여자 의 노처녀 히스테리 에 열등감 이 더하다 어떻다 되다 보여주다 영화 골 때리다 끝내주다 웃기다 주다',
#  '재밌다',
#  '대체 내용 이 왜 이렇게 이어지다 건가 싶다 ㅡㅡ',
#  '브로큰',
#  '포스터 가 약간 거북하다',
#  '유다인 이란 배우 를 알 게 해주다 영화',
#  '소설 원작 자다 재현 해내다 같다',
#  '보다 나오다 대사 가 온통 노래',
#  '은행 털 이 들이다 보여주다 몸 개그 열전',
#  '정말 오랜 만이 다 이렇다 감정 ㅠ',
#  '손현주 짱',
#  '훈훈하다 내용 이지만 스토리 가 다소 억지스럽다 부족하다',
#  '무언가 잊다 살다 느낌 을 준 영화 이제 생각 을 좀 바꾸다 하다 같다',
#  '또 뻔하다 결말 또 뻔하다 시 걸 의 영화',
#  '혼자 북 치고 장구 치다 관객 우롱 하다 끝나다',
#  '천하 의 슈렉 도 속편 이 거듭 되다 보다 힘 이 떨어지다',
#  '주군의태양 파스타 내용 은 뻔하다 재미있다',
#  '여자 주인공 이이해 가안 돼다 남자 여자 순수하다 사람 여자 는 양심 때문 에 죽음 을 평점 높다',
#  '시대 를 너무 앞서 간 영화',
#  '박중훈 은 괜찮다 근데 아직 넘다 어색하다 꽝 이다',
#  '반 담 영화 중 에 꼽는 작품 네이버 평점 의 신뢰 도 는 땅 에 떨어지다',
#  '이건 당연하다 점 주다 야하다 ㅇㅇ',
#  '보다 오래되다 기억 이 자다 안나 지만 야하다 장면 이 부족하다 걸 로 기억',
#  '주저리주저리 떠들다 결국 산 으로 가다 이야기',
#  '매력 적 인 구석 이 있다 엄청나다 자의식 과잉 에 질식 하다 것 같다',
#  '하다 잃다 봣 다 내 시간 이 아깝다',
#  '헐다',
#  '전 기세 가 아깝다',
#  '너무 지루하다 잠 오다 죽다 줄 알다 아 흠',
#  '우리 에게 행복 을 가다 주다 이 들보 다 끔찍하다 이 들 이 더 많다 게 현실 이다 우리 를 행복하다 해주다 사람 들 과 함께 하다 것 도 중요하다 그 보다 더 중요하다 것 은 나 스스로 행복하다 한다는 것 이다 스스로 행복하다 사람 이 타인 도 행복하다 만들다 수 있다',
#  '간결하다 지적 이며 몰입도 가 대단하다 영화',
#  '진짜 이병훈 사극 중 에서 제일 재미없다 드라마 이다',
#  '블랙코미디 의 진수 그러나 찌다 이 들 의 위악 이 역겹다 별 한 점 만 주다 다',
#  '가슴 찡하다 웃음 뒤 에 숨기다 찡하다 독특하다 재미 가 있다',
#  '평점 이 왜케 낮다 이 거 짱 인데',
#  '스팟 출연 진 이 화려하다 멍청하다 허영 심 만 가득 찬 아마추어 의 무 개념 자기 배설',
#  '입양 을 바라보다 냉정 하고도 따뜻하다 시선 에 감탄 하다',
#  '알바 들 아 흥 하다 ㅡㅡ',
#  '나 연기 가 현 시대 에 많이 뒤 떨어지다 흠 이지만 의 시 초로 서 슈퍼맨 의 위상 을 고려 하다 점',
#  '전 너무 재미있다 성유리 의 어색하다 연기 ㅋ',
#  '지 금보 면 삼류 영화 에요 지루함',
#  '일 본 영화 를 좋아하다 이유',
#  'ㅋ 연기 시나리오 연출 제대로 되다 하나 도 음슴다 ㅋㅋ 보다 내내 비웃음 나오다 진짜 ㅋㅋㅋㅋ 난 로멘 틱 코 메딘 줄 알다 ㅋㅋ',
#  '하얗다 노파 그냥 웃다 ㅋㅋㅋㅋㅋㅋㅋ',
#  '자극 적 이기 위해 끼울다 억지스럽다 장면 들 속 보이 는 뻔하다 계산 연출 성은 그렇다 감독 의 인격 수준 이 바닥',
#  '갠 적 으로 편 보다 더 재밌다 쏘다',
#  '이스트 우드 뿐 아니다 애드 해리스 의 연기 도 잊혀지다 않다',
#  '고은정 혼자 자 나체 한은정 혼자 자다 난체 언제 쯤 크다 재미없다 이야기',
#  '이 것 도 알바 있다 개봉 전이 야 오다 점 못 주다 점 주다',
#  '사람 들 이 일상 을 대다 하다 땐 언제나 신경 적 이고 지루하다 경향 이 심하다 삶 이란 생각 보다 길다 어렵다 난간 에 봉착 하다 마련 이 기 때문 인 것 같다 그렇게 일상 에지 내다보다 소중하다 감성 을 잊다 살아오다 같다 이영화 를 보고 도쿄 가 가지다 메트로폴리탄 이 가지다 뒷 편 잊다 지내다 감성 이 살아나다 하다',
#  '엑소시스트 의 먹다 칠하다 영화',
#  '별 반갑다 않다 감독 의 시 끌벌쩍',
#  '완전 잼잇엇어 요 정말 현재 의 나르다 보다 듯 한 느낌',
#  '이렇다 쓰레기 한 쿡 영화 는 돈 주다 보다 절댜 안되다',
#  '이 게 뭐 재밌다 마지막 이 라면 그렇다 치다 이건 첨부 터 여자 를 지키다 영화 라고 하다 그렇다 나오다 않다 반전 주의 의식 을 볼 수도 없다 결론 적 으로 애로 영화 노잼',
#  '상어 매니아 기대 를 가장 충족 시키다 영화 라고 생각 하다',
#  '이 걸 반전 이라고 미치다 내 시간 돌려주다',
#  '년 연애 여자 가 다른 남자에게 흔들리다 빼다 정말 공감 하다 제 얘기 해피엔딩 은 되다 없다',
#  '공감 불가 저런 기 들 은 다 죽이다 하다',
#  '눈물 로 마무리 짓다 되다 영화',
#  '점 으로 이 영화 를 표현 하다 턱 없이 부족하다',
#  '사이코패스',
#  '불쌍하다 펭귄 맨 맥스 의 무표정 이 제일 무섭다',
#  '점주 는 들다 흰둥이 똥구멍 이나 핧으 라지 쓰레기 들',
#  '베트남전 의 폐해 에 대해 보여주다 점 보다 미국 식 패권 주의 가 느껴지다 무조건 미국 이 전쟁 에 참여 하다 정의 의 편이 라는 점 을 부각시키다 것 은 옳다 않다 봄 전쟁영화 치고 짜릿하다 스릴 이나 감동 또는 재미 도 별로',
#  '포스터 에 있다 보지 않다 판단 하다 마르다',
#  '평보 고 만 원 결제 하고 보다 ㅡㅡ 신랑 보다 잠들다 돈 아깝다 끝 까지 보다 하다 평점 주다 알바 있다 거 첨 알다 걍 개 인기 맘 비우다 보다 고해 도 유부녀 랑 아무렇다 않다 사랑 에 빠지다 그걸 미화 시키다 ㅡㅡ 어의 없다',
#  '전 기세 가 아깝다 캬악 퉷',
#  '후반 부 에 펑펑 울다 ㅠㅠ',
#  '있다 없다 이야기 인정 하다 없다 결론',
#  '해리포터 전 시리즈 중 에 제일 인물 심리 묘사 나 구체 적 인 이야기 그리고 어리다 애 들 영화 같다 않다 진지하다 진중하다 느끼다 편 갠 적 으론 파트 의 화려하다 파트 의 느낌 이 더 좋다 것 같다',
#  '정말 이렇다 영화 가 개봉 되다 믿어지다 않다 처음 으로 영화 평점 을 매기 게 하다 영화 무슨 생각 으로 수입 하다',
#  '재미없다 진심 으로 솔직하다 재미없다',
#  '',
#  '내 생애 최악 의 공포영화 공포영화 가 무섭다 되다 웃기다',
#  '차다 좋다 영화',
#  '오리 지나다',
#  '최고 의 드라마 김태희 랑 가다 너무 좋다',
#  '너무 재미 있다',
#  '이건 뭐 그냥',
#  '최고 의 영화 다 이 영화 를 보다 후 앞 으로 영화 를 자다 선택 하다 한다는 충고 를 얻다',
#  '법 은 강 한자 에게만 평등하다 정의 는 없다',
#  '작품 성 이고 뭐 고 도무지',
#  '진짜 만나다 힘드다 명품 드라마 배우다 작가 모두 최고',
#  '별로',
#  '이 영화 를 이제 서다 보다 되다 명작 으로 불다 질 만 한데 제목 이 아쉽다',
#  '이렇게 못 만들기 가 더 어렵다 초딩 학예회 급 연기력 을 선보이다 이요원 은 모 구 게다가 황정민 딸 로 나오다 아주머니 는 모 냐 감독 이나 제 작 진 은 몰다 보구 캐스팅 들 을 한 거 냐 한심하다 영화 네 네이버 두 별 점 개 하다 수 있다 해주다',
#  '글쎄 좀 쌩뚱맞다 고 하다 이입 도 안되다 인내심 을 요한 다',
#  '발전 하다 없다',
#  '난꽤 재밌다 배우 연기 가 오지 니까',
#  '시나리오작가 상 주다 두 번 주다',
#  '감독 이 무슨 이야기 를 하다 모르다 복선 이 너무 많다 장치 가 너무 많다 목잡 하고 답답하다 여 주인공 의 감정 과잉 이 보다 하여금 실소 를 머금 게 하다',
#  '죄송하다 빨리 끝나다 다른 드라마 좀 하다 좋다 왜케 기다 넘다 재미없다',
#  '이건 퍼 킬링 타 임용 ㅋㅋ',
#  '오빠 들 더멋 잇다 졋 어 요 ㅎㅎ',
#  '영화 보다 자다 처음',
#  '어디 하나 흠잡다 곳 없다 최고 의 영화',
#  '별 점 이 굉장하다 높다 그렇다 한 가치 가 있다 영화',
#  '여기 티모시 스펄 이라는 배우 나오다 않다 배우 목록 에 없다 영화 에서 밥 으로 나오다 그 사람 없다 배우 목록 에 첨부 점 요 영화 는 좋다',
#  '평점 처음 달 아보 게 만들다 내 인생 에서 베스트 급 아 류 작다',
#  '킬링타임 용 그 이상 그 이하 도 아니다',
#  '감정이입 되다 이렇게 심하다 영화 가 제 가 되다 적다 없다 저 에게 해당 되다 이야기 는 아니다 가슴 찡하다',
#  '군인 들 도 자다 ㅎㅎㅎㅎ',
#  '캡틴 듀브 아 나오다 때 마다 너무 웃기다 줄리 안이 랑 곰 의 러브스토리 도 재밌다 무엇 보다 서커스 씬 은 노래 오다 어울리다 환상 적 이다',
#  '아오 초등학교 학년 떄 존 나다 무섭다 보다 ㄷㄷ',
#  '아 재미 때 끄다 진짜 없다',
#  '좋다 스릴러 소재 로 왜 엉 성하다 멜로 를 만들다',
#  '권선 징악 이라는 진부하다 스토리 하다 드라마 중반 부 까진 점 주어 도 괜찮다 한 연출 스토리 연기력 후반 부 갈수록 누구 나 예상 가능하다 권선 징악 결론 이겠다 왜인 지 예상 못 하다 훌륭하다 반전 하나 정도 나오다 않다 하다 개인 적 인 생각 이다 암튼 난 꿀잼 ㅋㅋ',
#  '김승우 는 연기 를 몇 년 하다 연기 가 늘다 않다 황정민 이나 송강호 한테 가다 좀 배우다 라발 연기 대단하다',
#  '',
#  '애기 때 극장 에서 엉엉 울다 기억',
#  '처음 에 이 아이 가 크리스천 베 일임 을 알아보다 매우 깜짝 놀라다 역시 명 배우 의 이르다 어리다 때 부터 재능 을 가지 고 계시다 어리다 보다 시선 으로 전쟁 이 아니다 때 묻다 않다 순수하다 호기심 을 풀다 내다 멋지다',
#  '요즘 비디오 가계 가 없다 힘들다 ㅠ',
#  '캐릭터 의 개인 기다 좋다 시나리오 를 하루 만에 써다',
#  '별 한개 도 아깝다 이런 영화 에 돈 을 쓰다 돈 이 남아도 냐',
#  '어설프다 연출 과 빗나가다 주 제 의식 이 적절하다 섞이다',
#  '빨갱이 는 빨갱이 일 뿐',
#  '공유 짱짱맨',
#  '환희 님 비롯 신인 배우 들 연기 기 대 이상 이구 요 아름답다 영상 에 콘서트 보다 것 같다 곡 들 모두 좋다',
#  '두뇌 와 가슴 이 없이 눈 으로만 보다 무지하다 사람 들 에게는 지루하다 돈 만 날리다 영화 겠다 그런 부류 는 그냥 치고받다 헐리욷 쓰레기 영화 나 보다 왜 이런 영화 를 돈 들 이고 시간 낭비하다 보다 가다 이해 가 안감 명화 를 보다 만화 만도 남도 못 한 쓰레기 라 하다 게 지',
#  '낚았다 히데 오 의 조금 그렇다 영화',
#  '다시다 보다 않다 영화',
#  '평점 에 낚 인 영화',
#  '개봉 하다 순식간 에 내려가다 망하다 영화 라고 만 알 고 있다 한번 보다 후 로는 괜찮다 영화 라고 생각 이 들다 어떤 분 은 허구 라고 하다 실제 로 있다 일 인대 무슨 허다 구입 니까',
#  '흥미 롭고 가슴 뭉클하다',
#  '평점 보고 보다 내용 도 노잼 이고 웃기다 아니다 유치하다 개그 나 치다 액션 이 쩌는것 도 아니다 년대 액션 을 보여주다 분 보다 짜증나다 넘기다 보다 끄다 버리다 지금 궁금하다 저기 나오다 딸 래미 여자애 분명하다 에서 보다 같다 누군지 기 억 이안 나',
#  '제목 도 그렇다 정말로 짜증 이 나 는 영화 이다',
#  '이렇다 찝찝하다',
#  '솔직하다 재미 는 있다',
#  '잘 만들다 보기 에는 그다지 특이하다 취향 을 가지다 사람 들 의 행복찾기',
#  '드라마 왜 이리 재미없다 이야기',
#  '점 보다 더 이하 주다',
#  '라이언 필립 이 왜 못 뜨다 확실하다 알다 준 영화',
#  '잘 보다 진자 ㅠㅠㅠ 부럽다',
#  '오다 여러 번 보다 재밌다',
#  '솔직하다 아니다 아니다',
#  '스페인 영화 기도 하다 맨 마지막 씬 은 결코 잊다 수 없다',
#  '감독 의 상상력 과 작품 성 이 우수하다 작품 이라 생각 되다 현실 과 환상 의 세계 를 헤엄 치다 미스터리 다시 한번 재 감상 을 통해 미스터리 작품 의 세계 로 빠져들다 싶다',
#  '이 거 감독 하고 출연 배우 빼다 아무 도 끝 까지 못 보다 그 유명하다 영화',
#  '이 거 에서 한 거쟎 아 요',
#  '감동 이 살다',
#  '케이블 에서 하다 때 마다 봄 조 쉬 하트넷 멋있다',
#  '좋다 다시 보고 싶다 영화',
#  '정말 정말 하다 일 없다 때 시간 때우다 재미없다',
#  '재미없다 보다',
#  '스토리 가 스릴 있다 훈훈하다',
#  '지루하다 차 대전 의 화려하다 전투씬 을 기대하다 동네 아줌마 들 의 친목 도모 라니 임팩트 와 감동 이 없다 물론 이렇다 내용 을 좋아하다 사람 도 있다 나 는 땡 점',
#  '오늘 엘지 유플러스 로 장화홍련 이란 영화 를 보다 떄 무섭다 감동 적다',
#  '색다르다 코난 시리즈 인 듯',
#  '회 부터 지금 까지 쭈욱 넘다 재다 오늘 강우 창 이 넘다 나쁘다 ㅠㅠ 순금 이 는 우짜 라 꼬 ㅠㅠ',
#  '정화 누나 전생 에 나라 를 구 하다 정화 누나 너무 좋아하다 요즘 은 너무 부럽다 요크 크크',
#  '좋다 소재 지만 연출 이 ㅈ 망 이네',
#  '망하다 싸다',
#  '티비 에서 방영 해주다 우연히 보다 돼다 평점 이 왜 점 밖에 되다 않다 의문 이네 요 스토리 가 진행 되다 느껴지다 쾌락 슬픔 그리고 사회 풍자 적 요소 정말 재밌다 보다',
#  '이건 영화 가 아니다 포르노 수준 인데',
#  '감동 첸카이거 감독 작품 은 역시',
#  '진행자 들 이랑 그 방청객 들 너무 오버 하다 보기 안좋다 그렇지만 휘성 편 은 정말 재미있다 보다',
#  '이 시대 아버지 의 모습 너무나 자다 표현 하다 영화 아버지 는 세월 이 가도 아버지 이다',
#  '너무 하다 출연자 에게만 어필 하고 송은희 씨 는 너무 끼어들다 그치다 신동엽 씨 는 역시 프로 네 요',
#  '아주 크다 교훈 을 얻다 야하다 장면 을 보고 싶다 야동 을 보라',
#  '어리다 때 보다 년 이 지난 지금 도 생각나다 인상 깊다 영화 에요 오늘 따르다 다시 보다',
#  '굳다',
#  '초반 에 엘베 안 에서 공효진 이 이선균 기습 볼뽀뽀 하다 때 왜 이리 좋다 ㅋㅋㅋㅋ 이선균 공효진 두다 표정 이 재밌다 그 런가 되게 달달 하다 ㅠ 새벽 까지 몰다 보다 꿀잼졸잼 짱 잼',
#  '',
#  '유머 들 이 기 가 막히다',
#  '재미있다 보다 음 요 추천',
#  '내 가 알다 이 게 박찬욱 감독 의 본 모습 인데',
#  '아무 것 도 모르다 대중 을 선동 하다 선동 버스',
#  '한마디 로 말 하다 핵 노잼',
#  '드라마 가 좋다 것 도 아니다 액션 이 좋다 것 도 아니다',
#  '김청기 감독 이제일 좋다',
#  '드니 라 방 소름 돋다 봉준호 도 괜찮다 미셸 공 드리다 별로',
#  '간만 에 괜찮다 스릴러물 을 만나다',
#  '지루하다 죽다 알다 유우 때문 에 끝 까지 보다 영화',
#  '아이 들 이 좋아하다 어른 이 보다 재미있다',
#  '한 개도 아깝다 쓰레기 영화',
#  '위로 가 필요하다 때 위로 가 되다 드라마 너 무 죠 으 다',
#  '재미있다 용이하다 되다',
#  '어리다 적 우주비행사 를 꿈꾸다 않다 사람 은 없다 ㅋ 이제 라도 보다 다행 ㅋ',
#  '왜 상 받다 진짜 지루하다 끝 까지 보다 욕 나오다 보다 암',
#  '재미없다 옹박 오리 지나다 편 빼다 만들다 말다 하다',
#  '오랜 만 에 영화 다 운영 화 를 보다 좋다 써다 안보 면 후회 하다',
#  '세익스피어 가 이렇게 차별 주의 적 인 사람 이다',
#  '상당하다 시 답 잖다 어설프다',
#  '평점 이 왜 이렇게 낮다 끄다 소재 도 신선하다 중간 중간 많이 웃다 ㅋㅋ',
#  '로맨틱 한 지구 종말 잔잔하다 마지막 장면 여운 이 너 무크 다 재난 블록버스터 보다 이렇다 훨씬 오다 닿다 현실 적 으로 무섭다 슬프다 같다 보다 소소하다 웃음 도 있다 감동 도 있다 배우 들 도 사랑스럽다 나다 저렇게 종말 을 맞이 하다',
#  '바이오 로 보 표절',
#  '이 정도 로 평점 끌다 올리다 보다 배급사 에서 알바 자다 뽑다 거 같다 아니다 대 보험 들어가다 정 직원 들 인가 ㅋㅋ',
#  '평점 왜 이렇게 높다 이 게 볼 만 하다 참나',
#  '진짜 희다 대의 망작 시간 은 황금 보다 귀하다 절실 하다 느껴지다',
#  '딸 하고 너무 재미있다 보다 영화 보다 뒤 로 딸 은 도라애몽 과 같다 주머니 가 있다 하다 ㅎㅎ',
#  '이 게 영화 야 월요일 국군 방송 보다 졸리다',
#  '우연 성 이 너무 심해',
#  '모든 걸 다 떠나다 공포영화 가 이 토록 지루하다 수도 있다 하다 생각 이 들다',
#  'ㅋㅋㅋㅋ 아 놓다 진짜 네이버 영화 스포 하다',
#  '이 것 다시 보고 싶다 정말 재미 있다',
#  '포스터 부터 년대 영화 다 진짜 하다 잃다 년 영화 라니',
#  '실화 여서 더 재미있다 ㅋ',
#  '이 영화 때문 에 영 화보 는 눈 이 엄청 높아지다 몇몇 만 제외 하고 거의 다 재미없다 영화로 만들다 걸작 영화관 에서 나오다 꼭 허전하다 있다 이건 걍 꽉꽉 채우다 나오다 느낌 영화관 에서 보다 정말 신의한수 이고 진짜 내 생애 최고 의 영화',
#  '샘 들다 영화 는 별로 인 듯 재다 보다 하나 도 없다',
#  '샌프란시스코 의 쟈니',
#  '그래도 액션 은 볼 만 하다 ㅎㅎ',
#  '왜케 광고 는 멋지다 하다 정말 실망',
#  '이 게뭐 냐 빨갱이 영화 냐 ㄷㄷ',
#  '재미있다',
#  'ㅇ 이승환 님 편 진짜 울면 서 듣다 보고 최고 얍',
#  '간만 에 재밌다 영화 봔 네 찰스 그로 딘 때문 에 배꼽 이',
#  '지브리스튜디오 와 비교 하다 손색 없다 명작 애니 의 탄생',
#  '정말 좋다 영화 또 보다',
#  '주말 예능 치고 너무 재미없다',
#  '수 많다 무비 꼴 라 쥬 중 유일하다 좌석 이 꽉차다 영화 어르신 분들 이 정말 많다 영화 수 많다 장면 중 저 는 포스터 와 같이 배위 에서 선우 스님 을 진심 어리다 위로 해주다 장면 이 너무 좋다 스님 들 의 또 다른 모습 을 보다',
#  '왜 마지막 장면 에 눈물 이 나다',
#  '시원 통쾌하다 복수 극',
#  'ㅈㄴ 재미없다 감독 때리다 치다',
#  '진부 하지만 마음속 에는 사랑 과 유쾌하다 남다 강추 이다',
#  '다시 보다 그립다 영화',
#  '감동 적 이고 재미있다 ㅋ',
#  '생각 보다 너무 실망하다 영화 언터쳐블 의 감동 만 생각 하다',
#  '연기 가 완전 어색하다 재미없다 베컴 나오다 점주 늘다 고맙다 여기다',
#  '슈퍼스타 허각 보다 유일하다 온몸 에 소름 이 돋다 닭살 돋다 허각 씨 뿐이다',
#  '답 이 없다 문제 를 내놓다 관객 들 헛 고생 시키다 영화 염정아 연기 가 그나마 살리다',
#  '최고 의 바이올린 영화 죠 소장 하고 싶다 찾다 다시 보고 싶다',
#  '반 전 스릴러 영화 의 교과서 라 보다 되다 하지만 그 이상 그 이하 도 없다 걍 요즘 사람 이 보기 엔 지루하다 고전 영화 공포영화 의 역사 가 궁금하다 하다 궂 이 보다 예상 하다 그대로 를 보다 되다 임',
#  '점 은 스파 키 의 귀 여 움 에 ㅋ 오랜 만 에 짜증나다 영화',
#  '같다 값 이 면 머리 들 도 좀 써다 예산 타령 만 하다 말고',
#  '신의 존재 와 필연 적 인 죽음 에 관 한 질문 종교 의 구원 과 사후세계 에 대해 진지하다 묻다 있다 영화 다 영화 도 충분하다 철학 적 인 도구 가 되다 수 있다 음 을 증명 하다 불후 의 걸작',
#  '아 ㅠㅠ 시간 아깝다 뭐 이렇다 거지같다 영화 가 다 있다 뭘 전하 고 싶다 건지다',
#  '이렇다 드라마 또 없다 정말 사 람사 는 얘기 에요',
#  '마지막 장면 이 평생 잊혀지다 않다 것 같다 눈물 이',
#  '내 가 보다 최고 의 만화',
#  '예전 엔 재밌다 보다 내용 을 다 알다 좀',
#  '동방불패 와 같다 졸작 수박 겉 핥다 식 영화',
#  '누구 나 하다 번 쯤 들다 보다 그레이스 켈리 에 대한 이 영화 는 왕비 여배우 로서 주인공 이 느끼다 갈등 과 모나코 와 프랑스 간의 문제 사이 에서 중심 을 잡지 못 하다 채 난잡하다 진행 되다',
#  '개 쩐다 는 말 밖에 나오다 않다',
#  '감동 깊다 본 영화',
#  '간만 에 영화 보다 원 없이 졸다 스릴러 좋아하다',
#  '감동 이 있다 영화 굿',
#  '주인공 이 하나 하나 알 아 가다 장면 들 주인공 의 시점 관점 이며 하나 씩 달라지다 때 마다 왠지 대단하다 장면 들 이 아니다 나 는 정말 기분 좋다 소름 을 느끼다 수 있다 소설 은 이렇게 써다 ㅎㅎ 정말 명작 이다',
#  '이 거 후속작 도 나오다 왠지 또 나오다 같다 느낌 이',
#  '토 하다',
#  '진짜 명품 드라마 다',
#  '마지막 어째서 소지섭 이 그렇게 가다 하다 생각 에 계속 생각 해봤다 결국 은 배우 로써 재미 는 다 보다 이제 조폭 으로서의 인생 을 마감 하고프다 생각 에 그렇다 생각 되다 자기 자신 의 끝 은 그렇다 모습 으로 가다 나다 같다 생각 에서',
#  '오래전 영화 지만 참으로 매력 있다 컨셉 의 영화',
#  '년전 주말 의 영화 에서 본 영화 최고 이다 이 젠 어디서 보지 ㅜㅜ',
#  '평점 이 점 대 라니',
#  '왠지 수상한',
#  '편 을 보다 보다 편 에 점 만점 을 주다 모자라다',
#  '힘 도 없다 편이 나 가르다 못 난 짓다 세기 도 별 다르다 없다',
#  '너무 도식 적 이다 한계 는 어쩔 수 없다 뿐더러 이현우 영화 에 몰입 하다 수 없다',
#  '간만 에 보다 한국영 화 중 수작 중 의 수작',
#  '견자단 을 데리 고 이 것 밖에 못 만들다 진짜 게다가 머리스타일 어쩔 끼다 정말',
#  '열왕기하 읽다 보다',
#  '감동 ㅠ',
#  '막다 들다 군 바리 들 을 어떻다 괴롭히다',
#  '니 들 이 이제 는 아주 막다',
#  '내 인생 의 영화 라고까지 해주다 있다 무인도 에 가져가다 단 한편 의 영화',
#  '지나치다 비현실적 이라 괴리감 크다 결정 적 한 방 은 대체 언제 하다 끝나다',
#  '선정 적 이 거나 자극 적 인 내용 이 아니다 가슴 따뜻하다 정감 가다 드라마 여서 좋다',
#  '편 수준 을 기대하다 보다 스토리 도 난잡하다 재미 가 없다 결정 적 다음 편 은 안 보다',
#  '빨리 돌리다 액션 만 보다 되다 스케일 만 크다 아무 것 도 없다',
#  '숨기다 명화',
#  '점 인데 점 줌 재밌다 봄',
#  '이 거 어리다 때 보고 오늘 사서 엄마 하고 보다 역시 명화 덥다',
#  '외치다 갓 토르 그냥 노잼 이어도 점 주다',
#  '어거지 로 빠뜨리다 마무리 짓다 한심하다 역량 의 작품',
#  '보다 뭐 지 하다',
#  '다큐멘터리 인 줄 알다 영화 네 요 정말 자다 보다 눈물 이 멈추다 않다 ㅠㅠ',
#  '어른 이 보기 에는 좀 잔잔하다 그런데 우리 아들 은 재미있다 집 에 돌아오다 양 인형 까맣다 칠하다 블랭키 만들다 자다 ㅎㅎ 역시 아이 들 의 상상력 은 어른 과는 차이 가 있다 느끼다',
#  '어떻다 오락 영화 던 그 이상 의 것 을 보여주다 그것 도 년도 에',
#  '소장 하다 비디오테잎 누가 빌리다 가다 행불 보다 ㅡㅡ',
#  '감동 ㅠㅠ',
#  '그저 그렇다',
#  '재밌다 마음 이 훈훈하다 영화 ㅎ',
#  '뭐라다 결국 은 가족 이 랄 끄다 감동 적 이다 안타깝다 기도 하고 아릿하다 느낌 이다',
#  '이 정도 로 물 고 빨다 교만하다 나태하다 런던 올림픽 에서 죽 쑤다 버리다 대한민국 대표팀 미달 이 처럼 팬 들 의 관심 과 사랑 이 부담스럽다 그렇다 김연아 는 어째서 팬 들 의 관심 과 사랑 을 즐기다 알다 거지 뭐 가 그렇게 부담스럽다 누님 들 결국 정신 력 의 문제',
#  '평점 이 낮다 왠만하다 올려주다 하다 이건 아니다 ㅡㅡ',
#  '보다 어떻다 찍다 이 생각 만 ㅋ',
#  '제 가 보다 최고 의 액션영화 다섯손가락 에 들어가다 액션영화 하다 이 영화 가 제 일 먼저 생각나다 최고 의 영화',
#  '획기 적 인 영화',
#  '호화 캐스팅 지루하다 전개 한마디 루 별 루 이다',
#  '홍보 만 잘 되다 인기 는 능가 하다 껀데',
#  '너무 감동 있다 자다 봣습니 다',
#  '모 가 재밌다 건지다 걍 그럭저럭',
#  '점수 가 너무 높다',
#  '최악',
#  '아 정말 소름끼치다',
#  '청춘 시트콤 의 표본 이자 스타 등용문 의 서막',
#  'ㅠㅠ 로빈 윌리엄스 역시 명품 배우다',
#  '좋다 나다 재미없다 유치 찬란하다 뭔 지 모르다 보다 짜증나다 채널 돌리다',
#  '한숨 만 으 휴',
#  '누군가 에게는 잔인하다 느낌 으로 다가오다 좋다 오늘 방송',
#  '소 피 마르 소가 아니다 평점 점 짜다 영화',
#  '빈약하다 스토리 빈약하다 각본 빈약하다 연출 빈약하다 그래픽 보다 정신 도 빈약',
#  '징편 인데 단편 스럽다 생명 가지 고 장난',
#  '최고다 배트맨 비긴즈 랑 바교 는 아니다 배트맨 에는 내 가 알다 론 그렇게 크다 늘다 없다 는걸 로 알다 케릭 터 하나 하나 다쨋 든 베트맨 도 잼슴',
#  '성우 가 어린이 라는 게 아 쉬다 리얼리티 를 살리다 위해 서 라도 이 건아 님',
#  '시간 만 아깝다 지루함 의 극치 절대 보지 말다 일 점도 아깝다',
#  '정말 소름끼치다 영화 다 강추',
#  '제이크 질렌할 에 몰입 되다 봄',
#  '아이엠 도 그렇다 내 가 좋아하다 가수 보다 케이팝 의 대 단 함덕 에 소름 이 정말 쫙쫙 돋다 감동 적다 다큐멘터리 식이 고 상영 관 에 사람 도 별로 없다 보기 좋다 이 이런 걸 로 도 돈버는건 이 젠 뭐라다 할기다 없다 그저 난 좋다 에 셈 한테 봉사',
#  '점 으 헤헤 시내 ㅓ 헤세 헤',
#  '산티아고 오랜 만 에다 시 보다 짜릿하다 영화',
#  '가슴 따뜻하다 영화',
#  '주인공 도 매력 적 이지 않다 스토리 도 어디서 많이 본 듯 하 다',
#  '약간 의 비약 이 있다 정말 좋다 영화 이다',
#  '잊혀지다 하다 떠오르다 영화 분명 이 영화 가 날 홀린 게 분명하다 볼 때 마다 한 동안 은 그 여운 이 갈다 않다',
#  '이 거 정글 의 법칙 처럼 탐험 다니다 거 라 내 가 보고 있다 이제 무슨 먹방 을 찍다 집밥 먹다 돌아다니다 재미없다',
#  '오래되다 낡다 공포 기법 에 조악하다 새 룰 을 적용 해봤다',
#  '짐 캐리 만의 영화',
#  '이 게 아바타 보다 아래 라니 말 도 안되다 나다 당시 광고 보다 땐 아 류 작다 알다 지금 와 서 보 니 마케팅 업체 가 엉망 인 듯 싶다 비슷하다 영화 아바타 는 전개 가 억지스럽다 있다 이 영화 는 짜임새 까지도 치밀하다 적극 추천',
#  '뻔하다 악당 에 뻔하다 결과 대체 왜 아버지 친구 들 은 항상 배신자 인거 지 슈 레더 는 그냥 인간 인데 이상하다 쎄다 뿐 이고',
#  '당시 세대 의 좋다 향수 를 일으키다 있다 추억 으로만 남다 기념 이라니',
#  '내용 이 너무 진부하다 참고 보기 힘들다 그냥 감독 이 만들다 영화 같다 한마디 로 아무 내용 이 없다 뜻',
#  '점도 아깝다 네이버 평점 사기 위로 꼽 고 싶다 영화 류 순정만화 보다 더 허다 접 한 영화',
#  '재미있다 영화 소소하다 감동 있다 영화',
#  '김정훈 연기 진짜 하 새다 ㅋ',
#  '완전 쓰레기 영화 이다 스릴러 는 말 뿐 초 절정 저 예산 허다 접 시나리오 영화 정말 시간 아깝다',
#  '',
#  '한정 되다 공간 때문 에 비행기 를 선택 하다 시간 동안 뭘 한 건지다 위급하다 긴장감 은 개뿔 신사 다운 머피 후반 은 나 홀로 집 에를 연상 시키다 결투 씬머 저리 같이 약하다 머피 제이슨 보다 같다 레이첼 ㅋㅋ 정말 후반 부 개 웃기다',
#  '진짜 영화 별 로안 좋아하다 티비 보다 없다 채널 돌리다 우연히 보다 댐 근데 진짜 재밌다 보다 개쩌 는 영화',
#  '내 인생 최악 에서 두번째 에 있다 영화',
#  '평점 조절 위원회',
#  '미국 의 휴머니즘 이 세계 로 뻗다 나가다 시작 하다 증거 뻔하다 감동 은 어쩔 수 없다',
#  '따뜻하다 영화',
#  '인내 가 필요하다 영화',
#  '도공 끌 고간 게 아니다 도공 이 가르치다 가다 거기 에 남다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '일베 가 평점 억지로 높이다 영화 의 공통점 남자 평점 이 를 차지 한다는 것',
#  '이 영화 진짜 재다 옛날 학교 에서 보다 영 화표 값 이 아깝다 느껴지다',
#  '놈놈놈 따위 와는 비교 를 불허 하다 최고 의 서부 영화',
#  '이은주 가 출연 한 영화 중 가장 해피엔딩 한 영화 다 따뜻하다 영화',
#  '안타깝다 연출 이 조금 만 더 나다 나름 잔잔하다 명작 이 되다 있다',
#  '베드씬 만 기억 에 남다 영화',
#  '피해자 의 아픔 과 가해자 의 심리 묘사 가 남 의 일 같다 않다 감동 의 영화',
#  '약간 병맛 스럽지 만 재미있다 제목 을 다른 걸 로 지다 더 인기 있다 같다',
#  '아 놓다 ㅋㅋㅋ 쓰레기',
#  '정말 킹왕짱 영화 이다',
#  '닭살 내용 도 없다 감동 도 없다',
#  '헐다 이 걸 영화 라고 ㄱ 장난 치 나',
#  '재미 감동 멋지다 댄스 까지',
#  '천국 의 분',
#  '쓰리다 디 로 보다 하다 영화 볼 만 해 요 동굴 안 벽화 가 생생하다 보이다',
#  '이 것 도 영화 라고',
#  '쓰레기 만들다 고생 하다',
#  '성인 으로선 점수 를 주다 없다 그만큼 유치하다 만 아이 들 눈높이 에선 어떻다 모르다 난 이미 순수하다 잃다 아무튼 성인 입장 에선 유치 뽕짝 영화 임',
#  '낯선 자신 들',
#  '다르다 모르다 연기 정말 못 한 다스 텔론 형 못 지 않다',
#  '일만 에다 보다 ㅠㅠ 정말 좋다 드라마 고 박시후 가 너무 멋있다 ㅠㅠ 박시후 나오다 거의 다 보다 청담동앨리스 랑 이 게 짱 인 것 같다',
#  '그냥 꼭 보다 진짜 로 짱',
#  '',
#  '관객 을 조롱 하 는 영화 정말 기분 나 빳 다',
#  '아이 와 아빠 와 잘봣어 요',
#  '다문화 가족 을 바라보다 우리 의 시선 이 바뀌다 하다 바꾸다 수 없다 유전자 를 가지다 가문 화 가정 아이 들 을 차갑다 눈 으로 바라보다 서다 안되다 영 화보 는 내내 가슴 이 먹다 먹다 하다',
#  '극장 에서 안 보다 잘 하다',
#  'ㅜㅜ 내 용이 너무 지루하다',
#  '노래 가 종 아',
#  '더럽다 재미없다 드라마 언제 끝나다 배우 들 이 불쌍타',
#  '세대 간의 이해만이 아니다 사랑 과 이해 가족 애등 을 아우르다',
#  '설정 자체 가 황당하다 영화 어설프다 로맥 틱 에스에프 영화',
#  '나름 볼 만 하다',
#  '영 삼 아',
#  '잔잔하다 음악 과 후반 부 에서 크다 재미 를 드러내다 영화 좋다',
#  '장동민 이 젤 웃기다 같다 ㅋㅋ',
#  '별로 다',
#  '하 명작 이다',
#  '시각 에 따르다 다르다 역겹다 혐오 스러운 영화 풍자 는 좋다 하지만 꼭 이렇다 식 으로 년대 수준 으로 표현 되다 역겹다 인간 들 의 얼굴 은 절 대악 으로서의 표현 인가 성우 들 의 오버리엑팅 과 시도 때 도 없이 나오다 노래 도 눈살 을 찌푸리다 만들다',
#  '너무 재밌다 잘 보다 ㅋㅋ 몸 이 간질간질 ㅋ',
#  'ㄹ 점도 많다 일본인 에서 미국인 으로 바뀌다 또 있다',
#  '재미 도 업다 왜케 길다 상영 시간 이 길다 더 공포',
#  '영화 는 다큐멘터리 가 아니다 그래도 이건 좀 아니다 감정 과잉 에 억 지 웃음 에 뭔가 집중 도 안 돼다 별 두 개 는 그나마 배우 들 때문 에 줌',
#  '미스김 가다 박다 따라가다 당연하다 아니다 ㅋㅋㅋㅋ 아 짱',
#  '짧다 런닝타임 에 담기다 기다 여운',
#  '사회 상 을 담다 노력 한 드라마',
#  '그냥 답답하다 영 화보 는 내내 우울하다 분위기',
#  '최고 최고 최고 최고 한 번만 더 틀어주다 삼',
#  '힐링 받다 싶다 때 마다 정주 행해 요',
#  '너무 좋다 코믹 한 것 도 있다 생각 해보다 되다 있다 편위점 알바 를 해보다 적다 공감 가다 있다',
#  'ㅡㅡ 나 이영화 보다 봣는데 쓰례기 네 멀다 갑자기 예언 이 치다 나오다 멀다 재난영화 냐 ㅡㅡ 아 욕 나오다 진짜 리뷰 처음 써다 보다',
#  '웃기 고 재밌다 감동 ㅜㅜ 그 와중 에 송승헌 너무 잘생기다 엄정화 너무 예쁘다',
#  'ㅋㅋ 머 이르다 우주선 안 에서 중력 이 해제 되다 상태 에서 빨갛다 불 이 나다 크다',
#  '감독 의 진지하다 연출 력 이 배우 들 의 열연 으로 플러스 되다 결말 에서 자폭 김민준 의 카리스마 는 멋있다 허세 의 기운 도 ㅋ 조연 들 연기 가 깨알 같다 별 점 상승 요 ㅎㅎ 아 물론 영화 는 안 보다',
#  '이런 것 도 영화 라고',
#  '블랙코미디 존나 꿀잼 ㅋㅋㅋ 배우 들 완전 초 호화 캐스팅 임 ㅋㅋㅋ',
#  '정말 어지간하다 좀 하다 자중 나서다 점점 보기 시르다 다른 방송사 드라마 보다 정말 스토리 전개 가 뻔하다 무슨 미리 예상 한 데 로 보다 드라마 인지',
#  '딸 연기 가 오버 연기 니 어쩌 니 하다 분 들 은 뭐 지 난 진짜 현 실감 있다 정말 리얼 하다 연기 잘 하다 생각 하다 당신 들 은 저 상황 에 놓이다 저러다 않다 생각 하나 더하다 더하다 덜하다 않다',
#  '별 점 반개 도 아깝다 내용 도 없다 약간 중간 에서 갈팡질팡 하다 그렇다 스릴 이 있다 저스틴 연기 가 아직 부족하다 각본 연기 연출 력 다 망하다 영화',
#  '톰크루즈 와 잭 니콜슨 의 명연기 잭니콜슨 의 말 내 가 범죄 자라다 나오다 내 부하 들 이 지키다 덕분 에 너희 들 이 편하다',
#  '정말 의미 있다 영화 좋다 주제 를 자다 찍다',
#  '대단하다 이렇다 영화 가 점 이라니',
#  '이렇다 영화 죠 최고 의 영화 이다',
#  '총알 탄사 나이 의 재미 를 느끼다 힘들다',
#  '완전 내 스타일 아 샤를 리즈 테론 아직도 여신 급 으로 아름답다 스토리 도 아주 꿀잼 이다 왜 이리 평가 가 낮다 ㅎㅎㅎㅎ',
#  '난 재미없다 걍 여주 가 이쁘다',
#  '다 걍 넘어가다 남자 주인공 그 어리다 버리다 미그 적 거리 는 거 왜 화나다',
#  '하나 도 아깝다 홍진호 때문 에 주다',
#  '영화 가 왜 이렇게 잡음 이 심하다 건지다 내용 에 비다 너무 부실하다 하다',
#  '불륜 은 싫다 이 영화 는 도대체 싫어하다 없다',
#  '좋다 열자',
#  '지나가다 여자 랑 버스 는 잡다 아니다',
#  '반전 을 만들다 관객 을 놀래다 키 려고 많이 노력 하다 하지만 다 리얼리티 가 떨어지다',
#  '우리나라 적국 의 이야기 가 아니다 전쟁 의 고통 을 알다 준 영화 라고 생각 되다 중국군 이야기 가 아니다 그냥 군인 의 이야기 라고 생각 되다',
#  '이 것 이 사과 여 사과 자 나 ㅋㅋㅋ',
#  '개연 성 없다 결말 이다',
#  '역시 아따 마마 가 진 ㄹㅣㅎㅎ',
#  '스토리 는 평이하다 세 자동차 이 동 씬 은 화려하다',
#  '마이너스 별 점 은 왜 없다',
#  '너무 슬프다 쌀밥 을 찾다',
#  '짱 임 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 웃기다 감동 적 인',
#  '감독 이 말 하다 하다 것 이 무엇 인지 알 수 없다 영화 귀신 이 등장 하다 설정 이 산만하다',
#  '별 점 을 주다 야하다 내 가 창피해',
#  '캐릭터 를 처음 부터 잘 못자다 원작 만 따라가다 이 지경 은 아니다',
#  '정말 불편하다 안좋다 면 을 다루다 그래서 불편하다',
#  '좋다 마무리 가 조금 아쉽다 기분 이 좋아지다 영화',
#  'ㅅㅂ 내 돈',
#  '투니버스 에서 보다 만족하다 ㅡㅡ',
#  '액션 영화 가 지루하다 얘기 는 끝나다 것 아니다 도입 부 만 흥미롭다',
#  '제목 때문 에 삼류 에로 영화 타이틀 같다 내용 은 알차다 스릴러 물 그리고 요즘 덱스터 에 나오다 데스몬드 의 리즈시절 모습 을 보다 있다',
#  '이건 아니다 그토록 딸 을 찾기 위해 모든 것 을 버리다 미아 찾기 운동 까지 하다 열성 인 엄마 는 딸도 못 보다 죽다 만들다 엄마 죽다 급 몰입도 떨어지다 범인 은 여기저기 나 여기다 단서 남기다 못자다 현실 성 이 너무 떨어지다',
#  '이렇다 애니 는 처음 그리고 반갑다 오인용 식구 들 목소리',
#  '안 보다 약인 영화 다 이렇다 영화 보다 뭔가 를 알다 느끼다 싶다 않다 하지만 느끼다 속이다 울렁거리다 영화 다 내 가 보다 느낌 을 표현 하다 길가 다 많다 양 에 구토 물 을 보다 느낌 인데 구토 한 사람 이 뭘 먹다 궁금하다 않다',
#  '',
#  '평점 이 너무 낮다 놀라다 개봉 당시 영화관 에서 번 보고 까지 소장 한 작품 인데 이 영화로 김지운 감독 주목 받다 헐리우드 진출 까지 하다 대작 이다 한국 에서 이렇다 영화 가 나오다 감사하다 작품',
#  '잠도 아깝다 제대로 되다 하나 도 없다 기대다 안 하다 이 정도 면 뭐 대체 피시 셍긱 이 잇다 건지다 한 심 김대희 분량 이 없다 병풍 이라 하다 분 들 계시다 전 김대희 주먹 쥐 며 몇번 째 손가락 올리다 모르다 욕 하다 막말 한 모습 이 너무 싫엇어 요',
#  '전작 보고 기대하다 실망 가득하다 영화 다',
#  '어리다 애 들 이 나오다 공포물 은 거의 다 재미 가 없다',
#  '명작 이다 꼭 보다 공백 자',
#  '정말 이 것 도 영화 라고 만들다 색 히 지도 영화감독 이라고 어디가 서 떠들다 다니다 평점 최 소가 이라서 점 은 주다 이건 정말 쓰레기 로 도 못 쓴다 에이 퉤퉤',
#  '이딴 게 영화 라니 ㅗ',
#  '이영화 는 점 대가 적정하다 생각 하다 연 기도 좋다 스토리 도 좋다 몰입 감 이 떨어지다 뭔가 억지 스럽게 끌다 느낌 이다',
#  '평점 보고 보다 정말 큰코다치다 최고 지루함 헉',
#  '어쩌다 생각 이 나서다 처음 으로 네이버 영화 평 을 올리다 정말 어리다 배우 들 유명 세 에 기대다 흥행 은 하다 모르다 나중 에 이 친구 들 이 연기 에 대해 눈 을 조금 이라도 뜨다 되어다 때 자신 의 흑역사 로 기억 하다 영화 가 아니다 싶다',
#  '재다',
#  '이 게 영화 냐 야동 이지',
#  '영화 가 끝 난후 텅 비어 버리다 가슴 진실 이 왜곡 되다 정치 적 이념 의 송가',
#  '이렇다 영화 는 그냥 점임 ㅜㅜ 저 위 포스터 는 도대체 누가 만들다 파스텔 톤 의 사랑 영화 아니다 ㅜㅜ',
#  '이렇다 영화 를 만들다 이유 를 모르다',
#  '그래서 결론 은 뭐 지',
#  '누구 나 겪다 삶 에 대한 많다 이슈 들 을 일상 적 이면 서 유머러스하다 전개 하 여 편안하다 감동 을 만들다 영화 같다 기분 이 좋아지다',
#  '행복 을 아메바 같이 단순화 시킴 또한 여행 도 작위 적',
#  '최고 의 연기력 과 기획 이영애 최고',
#  '내 용이 없다',
#  '자토이치 짝퉁 이군 어이 가 없다',
#  '쓰레 ㅐ 기 영화 전작 에 제대로 먹다 칠',
#  '호주 에서 살다 만들다 영화',
#  '다 보고 느끼다 점수',
#  '비디오 로 보지 말고 그냥 오씨 엔 으로 보다 나다',
#  '지금 보다 웃음 만 격 세지 감',
#  '심심하다 때 볼 만',
#  '년대 우리나라 는 영화 도 후진국 이다 어떻다 저런 연기 를 동시 대 에 나오다 영화 가 이다 로',
#  '평점 조작 단아 장난 치 지 말다',
#  '첨 볼 땐 다슬 이 차다 사랑스럽다 두번째 볼땐 다슬 이 가족 들 차다 좋다 분 들 이다 세번 째 볼땐 내 가족 들 도 있다 그대로 의 모습 을 보다 생각 이 들다 다슬이 가 계속 보다',
#  '시작 은 좋다 끝 은 흐리다 멍텅 반전 에만 집착 하다 샤말란',
#  '숨막히다 사랑 정말 너무 슬프다 아름답다',
#  '왜 박하선 이 복수 를 하다 이해 가 안되다 오히려 권상우 가 더 피해자 같다 그만큼 남편 한테 믿음 이 없다 생각 도 드네 요',
#  '이르다 저러다 않다 오락가락 스릴러',
#  '후세 에 걸작 의 재 조명 을 시키다',
#  '난 보다 그냥 에로영화 인 줄 알다 이 게 네이버 에 올라오다',
#  '감정 의 골 이 패 여 생기다 마음속 주름 이던 세월 의 흔적 이 보이다 얼굴 위 주름 이던 과 하다 인위 적 으로 펴다 부자연스럽다 움 을 피 하다 수 없다',
#  '기 대감 이 너무 크다 타다 명성 을 먹다 칠하다 영화',
#  '최고',
#  '아',
#  '내 가 왜 이 걸 년도 더 지나다 보다 되다 걸다 ㅋㅋㅋ 그 땐 초등학교 학년었 지 차다',
#  '진짜 추억 돋다',
#  '',
#  '영국영화 도 상당하다 독특하다 스토리 야 있다 영화 로서 의 재미 는 장편 독립영화 도 아니다',
#  '쓰레기 네 여',
#  '정의 를 위해 일단 보다 신선하다 충격 이다 이렇다 영화 평생 보기 힘들다',
#  '정말 제 인생 최고 의 영화',
#  '나 저 거 다운 잘 못 받다 ㅋ 세기 전 반대 영화인 줄',
#  '평 남기다 것 들 보다 영화 가 하나같이 똑같다 ㅋㅋㅋ 알바 도 좀 티 안나 게 하자',
#  '산뜻하다 그 들 만의 반란 우리 에게는 빵 도 필요하다 장미 도 원하다',
#  '무슨 말 이 더 필요하다 믿다 보다 일본 애니 아니다',
#  '이 영화 를 내 가 검색 한 이유 는 감독 이 또 만들다 맨 데이트 때문',
#  '야구 란 이런 거 다 하다',
#  '무엇 보다 쇼킹 한 건 이영화 의 네이버 평점 아버지 의 원수 이지만 아버지 와 같다 마음 을 품다 되다 영화 전반 부의 암스테르담 의 고뇌 는 참으로 훌륭하다 심리전 개 영화 전체 적 으로도 지루하다 않다 영 화전 개 와 스케일 고루 만족스럽다 영화',
#  '홍번구 에 비다 액션 이 약하다 성룡 은 역시 우리 를 즐겁다 해주다',
#  '정말 재밌다 자',
#  '서정 적 인 세계 에 빠져들다 싶다',
#  '고스 터 버스터 즈 느낌 의 수작 이다',
#  'ㅇㅇ 좋다',
#  '죽음 을 통한 소녀 의 성장 을 다루다 블랙 코미디',
#  '진심 개 거지 울 나라 에서 개봉 왜 한 거임',
#  '영화 이보 다 더 자다 만들다 수 있다 않다 유덜 보다 캐롤 성격 이 더 이상 해보다 참신하다 것 도 없다 흔하다 빠지다 로맨스 물 에 왠 평점 을 이리 높이 들 주다',
#  '감독 의 연출 이 부재 니 좋다 소재 를 말 아버 린다',
#  '',
#  '상 받다 왠지 좋다 하다 하다 것 같다 압박 감 에서 벗어나다 아무 것 도 없다',
#  '별로 안 무섭다',
#  '',
#  '영구 맹구 나 람보 코만도 를 만들다 게 더 낫다',
#  '어설프다 스릴러 어설프다 코 메다 어설프다 데미 무어',
#  '어린이 채널 용 드라마 같다 것 이 응응씬 을 너무 남발 하다',
#  '',
#  '평이하다 로맨틱 코 메다 행크스 많이 늙다',
#  '끄다 끄다 울면 서 보다 영화 정말 다시 한번 보고 싶다 정말 진심 으로 다시 한번',
#  '닥터 호의 아픔 이 절실 히 느껴지다 그런 영화 이다',
#  '무법자 의 천상천 하 유아 독쫑 이란 제목 이 더 잘 어울리다 영화',
#  '이 괴상하다 심심하다 영화 는 갑자기 뭐 지기 대 이하 자 나 뭐 하 나 제대로 하다 없다 영화 베네치아 의 풍경 만 볼 만 함',
#  '지금 까지 보다 한국 공포영화 중 에서 내용 이 꽤 신선하다 재미있다 영화 이다 참고 로 내용 이해 하다 싫어하다 무조건 피터지다 때리다 잡다 좀비 영화 같다 좋아하다 사람 들 은 별로 안 좋아하다 스토리 위주 의 영화 를 보시 는 분 들 은 재미있다 같다',
#  '뭐 가 이렇게 허다 접다',
#  '장정일 님 의 원작 에 로티 시 즘 만 가득',
#  '만화 다 보다 유치하다 하다 한동안 차다 재미있다 보다 드라마 이기 에',
#  '궁극 의 러브 스토리 내 생애 최고 의 드라마 다모 폐인 들 은 영원하다 잊다 않다 이다',
#  '쓸데없다 사 개연 성 없다 시퀀스 콘티 를 촬영 하다 짜다',
#  '평점 점 짜다 개 알바 들 은 좀 가라',
#  '음악 쌤 이 보여주다 진짜 짱 인 영화',
#  '오랜 만 에 감동 적 인 영 화이자 부모 의 이기심 이 섞이다 잘 못 되다 사랑 에 대해 다시 생각 해보다 그리고 꼭 자신 이 낳다 아이 가 아니다 아이 가 원하다 부모 의 사랑 을 주다 정말 감동 적 이다',
#  '쓰레기 영화 이다',
#  '백인 우월 주의 떄문 에 중간 에 보다 껏 다 미국 은 꼭 이렇다 성향 이 있다',
#  '정말 재미있다 학교 에서 보다 가족 모두 보여주다 싶다',
#  '영화 보다 중간 에 끄다 버리다 건 처음 온갖 흥행 요소 짜깁다 기해 서 난잡하다 내용 없다',
#  '점 짜다 영화',
#  '이렇다 영화 가 있다 사실 이 감사하다',
#  '재 밋엇 어 요 오오오오 몽 으',
#  '그렇다 딱 점 이다',
#  '기 대 만발 ㅎㅎㅎ',
#  '쇼 밉다 더 멀다 ㅡㅡ 왜 하다 가요 힙합 보여주다 하다 아니다 롹 하고 ㅡㅡ 롹 이 힙합 은 아니다 자다 ㅡㅡ 아 점점 더 산 으로 가다 쇼 밉다 더 멀다 ㅡㅡ',
#  '좋다 저 밑 에 우리나라 사형제 도 폐지 돼다 하다 폐지 된거 아니다 다만 형 의 집행 을 계속 시행 하다 않다 있다 뿐',
#  '너무 좋다 우마 소 사랑스럽다',
#  '아 진짜 문채원 이렇다 연기 까지도 맘 에드 네 요 이런 영화 한편 더 찍다 뭉클하다 영화 이다',
#  '넘다 재밌다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '화려하다 휴가 에서 웃기다 ㅋㅋㅋ',
#  '독일 왕실 보석 을 둘러싸다 소소하다 두뇌 싸움',
#  '동화 같다 내용 이다 트리스탄 도 멋있다 난 개인 적 으로 셰익스피어 선장 이 굉장하다 좋다',
#  '아니다 왜 우리나라 얘기 는 없다',
#  '진짜 내용 유치하다 작가 발 로 쓰다 연기자 들 대본 보고 손발 오그라들다 초반 스토리 에서 가면 갈수록 진부하다',
#  '최오 이렇게 재다 애니 는 첨 이예 요',
#  '년 원작 에 비다 캐릭터 도 이야기 도 따뜻하다 가슴 도 모두 부족하다',
#  '꿀잼 진짜 개잼 꿀잼 핵잼',
#  '바보 연기 를 정말 리얼 하다 해내다 홍금보 에게 박수 를',
#  '송지효 짱 ㅋ',
#  '예전 이나 지금 이나 별로 인 영화 신선하다 좋다 음향 이 엉망 볼륨 조절 에 실패 송학 림 이 얘기 하다 땐 볼륨 최대로 맞추다 변희봉 이나 장량 이 말 하다 땐 볼륨 프로 면 되다 사운드 볼륨 은 엄청 크다 한국영 화 인데 한국말 자막 이 필요하다 실패 작',
#  '흐 하하 재밌다 제시카 알바 는 왜 이리 예쁘다',
#  '소재 만 신선하다 연출 연기 각본 모두 기 대 이하 맥 아리 없다 영화',
#  '별 달 가치 가업 네',
#  '상상 의 공간 하다 별다르다 없다',
#  '진짜 김신 아나운서 하고 나 미래 하고 엮지 말고 세 주랑 나 미래 랑 엮이 게 해주다',
#  '시간 아깝다',
#  '에 로 틱 환타 지는 무슨 난쟁이 똥 자루 만 한 여배우 하 나나 와 서다 눌 보다 반의 반 도안 섹시',
#  '꼭 한번 쯤 보다 하다 영화인 듯 현 우리 나라 상황 과 보다 오버 랩 되다',
#  '부활 마니아 가 이렇다 많다 하지만 그거 에 비다 재방송 은 거의 안 하다 듯살 인생 전무후무 최고 의 걸작',
#  '진짜 손가락 안 에 들다 영화',
#  '긴장감 도 떨어지다 반전 의 힘 도 약하다 듯',
#  '잘만 든 드라마',
#  '약하다 주제 의식 반전 보다는 법정씬 을 더 스릴 있다 하다 것 이지',
#  '',
#  '과장 되다 연기 와 장황하다 서술 에 점점 지치다 만가 는 여정',
#  '작가 분 이 돌아가다 친구 분 뜻 이어서 작품 이다 받다 쓰다 계시다 취지 는 높다 살다 이 작품 을 통해 서 다시 한번 깨달 은 건 요 남 의 작품 은 받다 쓰다 아니다 거대 부분 다망 치다 버리다 아예 다른 드라마 가 되다 끝 으로 갈수록 뭘말 하다 모르다 재미 도 없어지다',
#  '키티 적 이고 사소설 적 인 일 본 영화 의 편견 을 또다시 강하다 만들다 준 영화 다 들다 쉬다 긍정 적 으로 변하다 쉬다 희망 을 찾다 희망 을 강요 받다 괴롭다 하다',
#  '결말 에 다 침몰 하다 점 주다',
#  '외계인 너무 바보 같이 나오다 기술 은 종 나 좋다 머리 는 멍청이',
#  '그 어떻다 영화 보다도 쇼크 이다 일생 동안 두 번 다시 보고 싶다 않다 저주 받다 걸작',
#  '최고 에요',
#  '보다 언제 개봉 이 죠',
#  '평점 에 속 았음 그냥 점 정도 의 애니',
#  '현실 성 있다 영화 나 자신 을 알라',
#  '나 에게 동심 따윈 없다 ㅜ',
#  '그래도 이준기 실컷 보다 좋다',
#  '이다 박치기 다',
#  '볼 만 한 코미디 영화 싸다 티나 는 포스터 와 제목 때문 에 안보 게 돼다',
#  '이렇게 명화 가 평점 점 이라니 ㅠㅠ 제 가 점 올려주다 가다',
#  '영 상미 한 여자 의 성장 크리스마스',
#  '뭐 야 이 게 끝 이야 조금 지루하다 하지만 곧 절정 에서 재밌다 하다 절정 이 없다',
#  '재미있다',
#  '영화 니까 ㅋ 나쁘다 않다',
#  '나오다 신기하다 영화 볼때 자다 아무리 수년 이지 나다 이정 도 도급 영활 못 만들다 그래서 믿다 보다 베이 감독 이고 나쁘다 녀석 들 같다 영환 알라 나 줫 만 한 초딩 들 ㅉㅉ',
#  '예전 에 우울하다 힘들다 때 새벽 에 이 영화 보다 정말 마음 이 따다 해지 고 완전 힐링 되다 느끼다 뜻밖 의 장소 에서 뜻밖 의 인연 대리 만족 제대로 하다 아주 재밌다 영화 ㅋㅋ',
#  '찰리채플린 이 생각나다 하다 영화 ㅎㅎㅎ',
#  '이건 뭐 생략 이 심하다 영화인 것 같다',
#  '재밋 게 보다 자기 주관 대로 매 기다 평점 따라가다 아니다 에 휴 ㅉㅉ',
#  '지금 무슨 내용 인지 몰다 여자 들 섹시하다 과격하다 싸우다 그 뿐',
#  '영화 가 를 못 따라가다',
#  '진짜 개 졸작 이다 뭐 이딴 영화 가 있다 이야기 도 허무맹랑 하다 하다 뿐',
#  '음 안습 무플',
#  '무간도 나 신세계 나 각각 의 장점 이 있다 뭘 무간도 에 비 하다 쓰레기 네 찌끄레기 네 난리 를 치다 그렇게 보다 대부 에 비 하다 역시 이 것 도 찌꺼기 에 불과하다 점 주다 간다 이 영화 의 최대 단점 은 삼합회 보다 덜 떨어지다 빠들 을 양산 한다는 것',
#  'ㅜㅜ 안습',
#  '다시 한번 되새기다 하다 여전하다 좋다 쿠보즈카 의 눈빛',
#  '솔직하다 쓰다 호러 공포 매니아 로 안 보다 거의 없다 점 대가 맞다 같다 우선 너무 흔하다 소재 와 너무 흔하다 귀신 과 너무 흔하다 구성 으로 색다르다 전혀 없다 귀신 찍다 사람 들 이 귀신 이 귓 바람 한번 불다 패닉 에 빠지다 허둥대다 꼴 부터 망',
#  '이 게 영화 냐 옛날 에 비디오 영화 랑 비슷하다 연기 꽝 필름 아깝다 제대로 만들다 언플 좀 해 라 짜증 눈 버리다',
#  '익숙하다 모든 걸 잊다 살다 사람 들 에게 보여주다 야하다 영화 다',
#  '더빙 배우 를 잘 못 써다 괜찮다 영화 를 망치다',
#  '극장 에서 보다 꼭 이번 에도 안 나오다 네 압니 다 일판 사다 보다 분 들 을 위해 스포일러 는 자제 하다 극장 에서 꼭 보다',
#  '우연히 보다 되다 영화 부모님 의 사랑 이만 든 기적 을 보다 누구 든지 꼭꼭 보다 하다 짱짱',
#  '정말 재밌다 보다',
#  '두번째 에피소드 만 약간 부족함',
#  '어리다 적 추억 이 담기다 만화 어느새다 어리다 적 꿈 을 실어 준 추억 이 되다 버리다',
#  '영 문모 를 감독 의 의도 영 재미 를 느끼다 수 없다 나',
#  '웬만하다 선 점 은 안 주다',
#  '교복 찢다 하다 너무하다 고 인데 참살 하얗다 애 를',
#  '편 에 비 하다 위엄 이 너무 떨어지다 편 은 간지 좔좔 이 이다 편 은 개그 영화 같다',
#  '비틀 쥬스 를 보다 느낌 이런 영화 좋다',
#  '마음 이 따뜻하다 영화 네 요 ㅠ 강추',
#  '점도 아깝다',
#  '웃다 웃다 아니다 아니다 웃 을 수 없다 영화 역시 킬 리언',
#  '재미없다 별로',
#  '왠만하다 재주 로는 이 영화 에 명함 도 못 내미다',
#  '요 근래 영화 중 에서 제일 자다 만들다 같다 그래픽 도 화려하다 내용 도 탄탄하다',
#  '정말 지루하다 쉬다 만들다 영화',
#  '난 재밌다 ㅋㅋ',
#  '객관 적 이고 관련 없다 사람 이 감동 받다 잘 만들다 이건 도통 그 들 만의 잔치',
#  '베컴 지단 피구 를 볼 수 있다 즐겁다 특히 두번째 이야기 에서 나오다 여자 축구선수 정말 너무 너무 아름답다 이 여성 도 실제 축구선수 이다 로 기억 하다 ㅎㅎ 그나저나 평점 은 바셀팬 들 이 깍 고 간 걸다',
#  '장난 안 끄다 동네 양 아치 고삐 리 들 한테 비디오 카메라 주다 영화 하나 찍다 오다 이 거 보단 나다 이 게 영화 냐 영화 여 ㅉㅉ',
#  '긴박하다 사람 이 저 래서 자살 을 택하 는 것 이란 걸 알다 그 무게 를 견디다 스스로 목숨 을 끊다 않다 주인공 이 대단하다 생각 마저 들다 나다 어땟을까 라는 생각 이 들다 그만큼 몰입 되다 수 있다 잘만 든 세기 마지막 하다 영화 다',
#  '어색 유치 소재 는 좋다 결정 적 으로 재미 가 없다',
#  '디젤 개똥폼 만 잡고 디아블로 란 존재도 멋지다 않다',
#  '밋밋하다 하다 없다',
#  '에로 용 으로도 못 쓰다 영화',
#  ...]

# %%
preprocessed_data = pd.DataFrame({'context' : clean_train_review + clean_test_review})

print(preprocessed_data.shape)
# Out:
# (199992, 1)

# %%
preprocessed_data.head(30)
# Out:
#                                               context
# 0                                    아 더빙 진짜 짜증나다 목소리
# 1                    흠 포스터 보고 초딩 영화 줄 오버 연기 조차 가볍다 않다
# 2                             너 무재 밓었 다그 래서 보다 추천 한 다
# 3                       교도소 이야기 구먼 솔직하다 재미 는 없다 평점 조정
# 4   사이 몬페 그 의 익살스럽다 연기 가 돋보이다 영화 스파이더맨 에서 늙다 보이다 하...
# 5    막 걸음 마 떼다 세 부터 초등학교 학년 생인 살다 영화 ㅋㅋㅋ 별 반개 도 아깝다 움
# 6                               원작 의 긴장감 을 제대로 살리다 하다
# 7   별 반개 도 아깝다 욕 나오다 이응경 길용우 연 기 생활 이 몇 년 인지 정말 발 ...
# 8                              액션 이 없다 재미 있다 몇 안되다 영화
# 9         왜케 평점 이 낮다 꽤 볼 만 한 데 헐리우드 식 화려하다 너무 길들이다 있다
# 10                              걍 인피니트 가 짱 이다 진짜 짱 이다
# 11   볼때 마다 눈물나다 죽다 년대 의 향수 자 극 허진호 는 감성 절제 멜로 의 달인 이다
# 12    울면 서 손 들 고 횡단보도 건너다 때 뛰다 치다 올 뻔 이범수 연기 드럽다 못 하다
# 13  담백하다 깔끔하다 좋다 신 문 기 사 로만 보다 보다 자꾸 잊어버리다 그 들 도 사...
# 14  취향 은 존중 한 다지 만 진짜 내생 에 극장 에서 보다 영화 중 가장 노잼 노 감...
# 15                                ㄱ 냥 매번 긴장 되다 재밋음 ㅠㅠ
# 16  차다 사람 들 웃기다 바스코 가 이기 면 락스 코 라고 끄다 바비 가 이기 면 아이...
# 17            굿바이 레닌 표절 인 것 은 이해 하다 왜 뒤 로 갈수록 재미 없어지다
# 18  이건 정말 깨알 캐스팅 과 질퍽 하 지 않다 산뜻하다 내 용구성 이 자다 버무러진 ...
# 19       약탈 자 를 위 한 변명 이르다 저 놈 들 은 착하다 놈 들 절대 아니다 걸 요
# 20       나름 심오하다 뜻 도 있다 듯 그냥 학생 이 선생 과 놀다 영화 는 절대 아니다
# 21                                   보다 웃다 않다 건 불가능하다
# 22  재미없다 지루하다 같다 음식 영화 인데 도 바베트 의 만찬 하고 넘다 차이 남바 베...
# 23                    절대 평범하다 영화 가 아니다 수작 이라 는걸 말씀드리다
# 24                                 주제 는 좋다 중반 부터 지루하다
# 25               다 짤랐을꺼 야 그래서 납득 하다 수 없다 그렇다 꼭 그렇다 끄다
# 26                                     고추 를 털다 버리다 하다
# 27                                          카밀라 벨 발연기
# 28                                               재밋는뎅
# 29                  센스 있다 연출 력 탁월하다 캐스팅 년대 의 향수 그래서 점

# %%
sentences = []
for context in preprocessed_data["context"] :
    sentence = ' '.join(context)
    sentences.append([sentence])

preprocessed_data_df = pd.DataFrame(sentences, columns=['context'])
preprocessed_data_df.head(50)

# %%
preprocessed_data_df.to_csv('./preprocess/naverReview_preprocess_Okt.csv', index = False)

# %%
train_labels = list(train_data['label'])
test_labels = list(test_data['label'])

# %%
label_data = train_labels + test_labels

# %%
label_data_df = pd.DataFrame({'label' : train_labels + test_labels})

# %%
label_data_df
# Out:
#         label
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# ...       ...
# 199987      1
# 199988      0
# 199989      0
# 199990      0
# 199991      0
#
# [199992 rows x 1 columns]

# %%
label_data_df.to_csv('./naverReview_label.csv', index=False)

# %%
test_data
# Out:
#             id                                           document  label
# 0      6270596                                                굳 ㅋ      1
# 1      9274899                               GDNTOPCLASSINTHECLUB      0
# 2      8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3      6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4      6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0
# ...        ...                                                ...    ...
# 49995  4608761          오랜만에 평점 로긴했네ㅋㅋ 킹왕짱 쌈뽕한 영화를 만났습니다 강렬하게 육쾌함      1
# 49996  5308387       의지 박약들이나 하는거다 탈영은 일단 주인공 김대희 닮았고 이등병 찐따 OOOO      0
# 49997  9072549                 그림도 좋고 완성도도 높았지만... 보는 내내 불안하게 만든다      0
# 49998  5802125     절대 봐서는 안 될 영화.. 재미도 없고 기분만 잡치고.. 한 세트장에서 다 해먹네      0
# 49999  6070594                                         마무리는 또 왜이래      0
#
# [50000 rows x 3 columns]

# %%
test_data.dropna()
# Out:
#             id                                           document  label
# 0      6270596                                                굳 ㅋ      1
# 1      9274899                               GDNTOPCLASSINTHECLUB      0
# 2      8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3      6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4      6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0
# ...        ...                                                ...    ...
# 49995  4608761          오랜만에 평점 로긴했네ㅋㅋ 킹왕짱 쌈뽕한 영화를 만났습니다 강렬하게 육쾌함      1
# 49996  5308387       의지 박약들이나 하는거다 탈영은 일단 주인공 김대희 닮았고 이등병 찐따 OOOO      0
# 49997  9072549                 그림도 좋고 완성도도 높았지만... 보는 내내 불안하게 만든다      0
# 49998  5802125     절대 봐서는 안 될 영화.. 재미도 없고 기분만 잡치고.. 한 세트장에서 다 해먹네      0
# 49999  6070594                                         마무리는 또 왜이래      0
#
# [49997 rows x 3 columns]

# %%
train_data.dropna()
# Out:
#               id                                           document  label
# 0        9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1        3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 149995   6222902                                인간이 문제지.. 소는 뭔죄인가..      0
# 149996   8549745                                      평점이 너무 낮아서...      1
# 149997   9311800                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149998   2376369                        청춘 영화의 최고봉.방황과 우울했던 날들의 자화상      1
# 149999   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
# [149995 rows x 3 columns]
